# %%
#
#  tsne.py
#
# Implementation of t-SNE in Python. The implementation was tested on Python
# 2.7.10, and it requires a working installation of NumPy. The implementation
# comes with an example on the MNIST dataset. In order to plot the
# results of this example, a working installation of matplotlib is required.
#
# The example can be run by executing: `ipython tsne.py`
#
#
#  Created by Laurens van der Maaten on 20-12-08.
#  Copyright (c) 2008 Tilburg University. All rights reserved.
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %%
def Hbeta(D=np.array([]), beta=1.0):
    """
        Compute the perplexity and the P-row for a specific value of the
        precision of a Gaussian distribution.
    """

    # Compute P-row and corresponding perplexity
    P = np.exp(-D.copy() * beta)
    sumP = sum(P)
    H = np.log(sumP) + beta * np.sum(D * P) / sumP
    P = P / sumP
    return H, P

# %%
def x2p(X=np.array([]), tol=1e-5, perplexity=30.0):
    """
        Performs a binary search to get P-values in such a way that each
        conditional Gaussian has the same perplexity.
    """

    # Initialize some variables
    print("Computing pairwise distances...")
    (n, d) = X.shape
    sum_X = np.sum(np.square(X), 1)
    D = np.add(np.add(-2 * np.dot(X, X.T), sum_X).T, sum_X)
    P = np.zeros((n, n))
    beta = np.ones((n, 1))
    logU = np.log(perplexity)

    # Loop over all datapoints
    for i in range(n):

        # Print progress
        if i % 500 == 0:
            print("Computing P-values for point %d of %d..." % (i, n))

        # Compute the Gaussian kernel and entropy for the current precision
        betamin = -np.inf
        betamax = np.inf
        Di = D[i, np.concatenate((np.r_[0:i], np.r_[i+1:n]))]
        (H, thisP) = Hbeta(Di, beta[i])

        # Evaluate whether the perplexity is within tolerance
        Hdiff = H - logU
        tries = 0
        while np.abs(Hdiff) > tol and tries < 50:

            # If not, increase or decrease precision
            if Hdiff > 0:
                betamin = beta[i].copy()
                if betamax == np.inf or betamax == -np.inf:
                    beta[i] = beta[i] * 2.
                else:
                    beta[i] = (beta[i] + betamax) / 2.
            else:
                betamax = beta[i].copy()
                if betamin == np.inf or betamin == -np.inf:
                    beta[i] = beta[i] / 2.
                else:
                    beta[i] = (beta[i] + betamin) / 2.

            # Recompute the values
            (H, thisP) = Hbeta(Di, beta[i])
            Hdiff = H - logU
            tries += 1

        # Set the final row of P
        P[i, np.concatenate((np.r_[0:i], np.r_[i+1:n]))] = thisP

    # Return final P-matrix
    print("Mean value of sigma: %f" % np.mean(np.sqrt(1 / beta)))
    return P

# %%
def pca(X=np.array([]), no_dims=50):
    """
        Runs PCA on the NxD array X in order to reduce its dimensionality to
        no_dims dimensions.
    """

    print("Preprocessing the data using PCA...")
    (n, d) = X.shape
    X = X - np.tile(np.mean(X, 0), (n, 1))
    (l, M) = np.linalg.eig(np.dot(X.T, X))
    Y = np.dot(X, M[:, 0:no_dims])
    return Y

# %%
def tsne(X=np.array([]), no_dims=2, initial_dims=50, perplexity=30.0):
    """
        Runs t-SNE on the dataset in the NxD array X to reduce its
        dimensionality to no_dims dimensions. The syntaxis of the function is
        `Y = tsne.tsne(X, no_dims, perplexity), where X is an NxD NumPy array.
    """

    # Check inputs
    if isinstance(no_dims, float):
        print("Error: array X should have type float.")
        return -1
    if round(no_dims) != no_dims:
        print("Error: number of dimensions should be an integer.")
        return -1

    # Initialize variables
    X = pca(X, initial_dims).real
    (n, d) = X.shape
    max_iter = 1000
    initial_momentum = 0.5
    final_momentum = 0.8
    eta = 500
    min_gain = 0.01
    Y = np.random.randn(n, no_dims)
    dY = np.zeros((n, no_dims))
    iY = np.zeros((n, no_dims))
    gains = np.ones((n, no_dims))

    # Compute P-values
    P = x2p(X, 1e-5, perplexity)
    P = P + np.transpose(P)
    P = P / np.sum(P)
    P = P * 4.									# early exaggeration
    P = np.maximum(P, 1e-12)

    # Run iterations
    for iter in range(max_iter):

        # Compute pairwise affinities
        sum_Y = np.sum(np.square(Y), 1)
        num = -2. * np.dot(Y, Y.T)
        num = 1. / (1. + np.add(np.add(num, sum_Y).T, sum_Y))
        num[range(n), range(n)] = 0.
        Q = num / np.sum(num)
        Q = np.maximum(Q, 1e-12)

        # Compute gradient
        PQ = P - Q
        for i in range(n):
            dY[i, :] = np.sum(np.tile(PQ[:, i] * num[:, i], (no_dims, 1)).T * (Y[i, :] - Y), 0)

        # Perform the update
        if iter < 20:
            momentum = initial_momentum
        else:
            momentum = final_momentum
        gains = (gains + 0.2) * ((dY > 0.) != (iY > 0.)) + \
                (gains * 0.8) * ((dY > 0.) == (iY > 0.))
        gains[gains < min_gain] = min_gain
        iY = momentum * iY - eta * (gains * dY)
        Y = Y + iY
        Y = Y - np.tile(np.mean(Y, 0), (n, 1))

        # Compute current value of cost function
        if (iter + 1) % 10 == 0:
            C = np.sum(P * np.log(P / Q))
            print("Iteration %d: error is %f" % (iter + 1, C))

        # Stop lying about P-values
        if iter == 100:
            P = P / 4.
        #plt.scatter(Y[:, 0], Y[:, 1], 20, labels)
        #plt.title('t-SNE, Iter{}'.format(iter+1))
        #plt.savefig('png/tsne/tsne-iter{}.png'.format(iter+1))
        #plt.show()

    # Return solution
    return Y,P,Q

# %%
def ssne(X=np.array([]), no_dims=2, initial_dims=50, perplexity=30.0):
    """
        Runs t-SNE on the dataset in the NxD array X to reduce its
        dimensionality to no_dims dimensions. The syntaxis of the function is
        `Y = tsne.tsne(X, no_dims, perplexity), where X is an NxD NumPy array.
    """

    # Check inputs
    if isinstance(no_dims, float):
        print("Error: array X should have type float.")
        return -1
    if round(no_dims) != no_dims:
        print("Error: number of dimensions should be an integer.")
        return -1

    # Initialize variables
    X = pca(X, initial_dims).real
    (n, d) = X.shape
    max_iter = 1000
    initial_momentum = 0.5
    final_momentum = 0.8
    eta = 500
    min_gain = 0.01
    Y = np.random.randn(n, no_dims)
    dY = np.zeros((n, no_dims))
    iY = np.zeros((n, no_dims))
    gains = np.ones((n, no_dims))

    # Compute P-values
    P = x2p(X, 1e-5, perplexity)
    P = P + np.transpose(P)
    P = P / np.sum(P)
    P = P * 4.									# early exaggeration
    P = np.maximum(P, 1e-12)

    # Run iterations
    for iter in range(max_iter):

        # Compute pairwise affinities
        sum_Y = np.sum(np.square(Y), 1)
        num = -2. * np.dot(Y, Y.T)
        #num = 1. / (1. + np.add(np.add(num, sum_Y).T, sum_Y))
        num = np.exp(-1*np.add(np.add(num, sum_Y).T, sum_Y))
        num[range(n), range(n)] = 0.
        Q = num / np.sum(num)
        Q = np.maximum(Q, 1e-12)

        # Compute gradient
        PQ = P - Q
        for i in range(n):
            #dY[i, :] = np.sum(np.tile(PQ[:, i] * num[:, i], (no_dims, 1)).T * (Y[i, :] - Y), 0)
            dY[i, :] = np.sum(np.tile(PQ[:, i], (no_dims, 1)).T * (Y[i, :] - Y), 0)

        # Perform the update
        if iter < 20:
            momentum = initial_momentum
        else:
            momentum = final_momentum
        gains = (gains + 0.2) * ((dY > 0.) != (iY > 0.)) + \
                (gains * 0.8) * ((dY > 0.) == (iY > 0.))
        gains[gains < min_gain] = min_gain
        iY = momentum * iY - eta * (gains * dY)
        Y = Y + iY
        Y = Y - np.tile(np.mean(Y, 0), (n, 1))

        # Compute current value of cost function
        if (iter + 1) % 10 == 0:
            C = np.sum(P * np.log(P / Q))
            print("Iteration %d: error is %f" % (iter + 1, C))

        # Stop lying about P-values
        if iter == 100:
            P = P / 4.
        
        #plt.scatter(Y[:, 0], Y[:, 1], 20, labels)
        #plt.title('S-SNE, Iter{}'.format(iter+1))
        #plt.savefig('png/ssne/ssne-iter{}.png'.format(iter+1))
        #plt.show()
    # Return solution
    return Y,P,Q

# %%
if __name__ == "__main__":
    print("Run Y = tsne.tsne(X, no_dims, perplexity) to perform t-SNE on your dataset.")
    print("Running example on 2,500 MNIST digits...")
    X = np.loadtxt("mnist2500_X.txt")
    labels = np.loadtxt("mnist2500_labels.txt")
    Y1,P1,Q1 = tsne(X,2,50,20.0)
    Y2,P2,Q2 = ssne(X, 2, 50, 20.0)
    #pylab.scatter(Y1[:, 0], Y1[:, 1], 20, labels)
    #pylab.show()
    #plt.scatter(Y1[:, 0], Y1[:, 1], 20, labels)
    #plt.show()
# Out:
# Run Y = tsne.tsne(X, no_dims, perplexity) to perform t-SNE on your dataset.
# Running example on 2,500 MNIST digits...

# %%
plt.title('tSNE,High-D similarity')
plt.imshow(P1,cmap='hot')
plt.savefig('png/tSNE High-D similarity')
plt.title('tSNE,Low-D similarity')
plt.imshow(Q1,cmap='hot')
plt.savefig('png/tSNE Low-D similarity')

# %%
plt.title('SSNE,High-D similarity')
plt.imshow(P2,cmap='hot')
plt.savefig('png/SSNE High-D similarity')
plt.title('SSNE,Low-D similarity')
plt.imshow(Q2,cmap='hot')
plt.savefig('png/SSNE Low-D similarity')

# %%
for i in [3,5,20,50,100]:
    Y3,P3,Q3 = ssne(X,2,50,i)
    pylab.scatter(Y3[:, 0], Y3[:, 1], 10, labels)
    plt.title('s-SNE, perplexity {}'.format(i))
    plt.savefig('png/ssne-per{}.png'.format(i))
    plt.show()
    Y3,P3,Q3 = tsne(X,2,50,i)
    pylab.scatter(Y3[:, 0], Y3[:, 1], 10, labels)
    plt.title('t-SNE, perplexity {}'.format(i))
    plt.savefig('png/tsne-per{}.png'.format(i))
    plt.show()
# Out:
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 2500...
# Computing P-values for point 500 of 2500...
# Computing P-values for point 1000 of 2500...
# Computing P-values for point 1500 of 2500...
# Computing P-values for point 2000 of 2500...
# Mean value of sigma: 1.499815
# Iteration 10: error is 28.770710
# Iteration 20: error is 24.834811
# Iteration 30: error is 21.274108
# Iteration 40: error is 20.110636
# Iteration 50: error is 19.793849
# Iteration 60: error is 19.562428
# Iteration 70: error is 19.305593
# Iteration 80: error is 19.084471
# Iteration 90: error is 18.949829
# Iteration 100: error is 18.821723
# Iteration 110: error is 2.975732
# Iteration 120: error is 2.586181
# Iteration 130: error is 2.431133
# Iteration 140: error is 2.386407
# Iteration 150: error is 2.372518
# Iteration 160: error is 2.365258
# Iteration 170: error is 2.363729
# Iteration 180: error is 2.364368
# Iteration 190: error is 2.365236
# Iteration 200: error is 2.364741
# Iteration 210: error is 2.363587
# Iteration 220: error is 2.361878
# Iteration 230: error is 2.360869
# Iteration 240: error is 2.360080
# Iteration 250: error is 2.359454
# Iteration 260: error is 2.358987
# Iteration 270: error is 2.357235
# Iteration 280: error is 2.353216
# Iteration 290: error is 2.349080
# Iteration 300: error is 2.347638
# Iteration 310: error is 2.347337
# Iteration 320: error is 2.347479
# Iteration 330: error is 2.347971
# Iteration 340: error is 2.348325
# Iteration 350: error is 2.347901
# Iteration 360: error is 2.347223
# Iteration 370: error is 2.347020
# Iteration 380: error is 2.346803
# Iteration 390: error is 2.346651
# Iteration 400: error is 2.346147
# Iteration 410: error is 2.345487
# Iteration 420: error is 2.345643
# Iteration 430: error is 2.345727
# Iteration 440: error is 2.345721
# Iteration 450: error is 2.345783
# Iteration 460: error is 2.345754
# Iteration 470: error is 2.345660
# Iteration 480: error is 2.345634
# Iteration 490: error is 2.345613
# Iteration 500: error is 2.345491
# Iteration 510: error is 2.345139
# Iteration 520: error is 2.344361
# Iteration 530: error is 2.343687
# Iteration 540: error is 2.343655
# Iteration 550: error is 2.343634
# Iteration 560: error is 2.343741
# Iteration 570: error is 2.343551
# Iteration 580: error is 2.343342
# Iteration 590: error is 2.343307
# Iteration 600: error is 2.343310
# Iteration 610: error is 2.342982
# Iteration 620: error is 2.340998
# Iteration 630: error is 2.339221
# Iteration 640: error is 2.338104
# Iteration 650: error is 2.337742
# Iteration 660: error is 2.337760
# Iteration 670: error is 2.337825
# Iteration 680: error is 2.337801
# Iteration 690: error is 2.337448
# Iteration 700: error is 2.336839
# Iteration 710: error is 2.336649
# Iteration 720: error is 2.336629
# Iteration 730: error is 2.336582
# Iteration 740: error is 2.336406
# Iteration 750: error is 2.336253
# Iteration 760: error is 2.336208
# Iteration 770: error is 2.336143
# Iteration 780: error is 2.336087
# Iteration 790: error is 2.336054
# Iteration 800: error is 2.336049
# Iteration 810: error is 2.336064
# Iteration 820: error is 2.336076
# Iteration 830: error is 2.336081
# Iteration 840: error is 2.336076
# Iteration 850: error is 2.336070
# Iteration 860: error is 2.336065
# Iteration 870: error is 2.336061
# Iteration 880: error is 2.336058
# Iteration 890: error is 2.336055
# Iteration 900: error is 2.336053
# Iteration 910: error is 2.336051
# Iteration 920: error is 2.336049
# Iteration 930: error is 2.336048
# Iteration 940: error is 2.336046
# Iteration 950: error is 2.336046
# Iteration 960: error is 2.336045
# Iteration 970: error is 2.336044
# Iteration 980: error is 2.336043
# Iteration 990: error is 2.336043
# Iteration 1000: error is 2.336042
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 2500...
# Computing P-values for point 500 of 2500...
# Computing P-values for point 1000 of 2500...
# Computing P-values for point 1500 of 2500...
# Computing P-values for point 2000 of 2500...
# Mean value of sigma: 1.499815
# Iteration 10: error is 29.424353
# Iteration 20: error is 27.394892
# Iteration 30: error is 24.000670
# Iteration 40: error is 21.863337
# Iteration 50: error is 20.830084
# Iteration 60: error is 20.166613
# Iteration 70: error is 19.641211
# Iteration 80: error is 19.200479
# Iteration 90: error is 18.857067
# Iteration 100: error is 18.566827
# Iteration 110: error is 3.098219
# Iteration 120: error is 2.929501
# Iteration 130: error is 2.748703
# Iteration 140: error is 2.569763
# Iteration 150: error is 2.406414
# Iteration 160: error is 2.269484
# Iteration 170: error is 2.165249
# Iteration 180: error is 2.080822
# Iteration 190: error is 2.005551
# Iteration 200: error is 1.938432
# Iteration 210: error is 1.880169
# Iteration 220: error is 1.829030
# Iteration 230: error is 1.783807
# Iteration 240: error is 1.743349
# Iteration 250: error is 1.706775
# Iteration 260: error is 1.673631
# Iteration 270: error is 1.643373
# Iteration 280: error is 1.615644
# Iteration 290: error is 1.590019
# Iteration 300: error is 1.566528
# Iteration 310: error is 1.544836
# Iteration 320: error is 1.524350
# Iteration 330: error is 1.505203
# Iteration 340: error is 1.487428
# Iteration 350: error is 1.470733
# Iteration 360: error is 1.455061
# Iteration 370: error is 1.440254
# Iteration 380: error is 1.426105
# Iteration 390: error is 1.412624
# Iteration 400: error is 1.399972
# Iteration 410: error is 1.387973
# Iteration 420: error is 1.376501
# Iteration 430: error is 1.365572
# Iteration 440: error is 1.355116
# Iteration 450: error is 1.345113
# Iteration 460: error is 1.335540
# Iteration 470: error is 1.326364
# Iteration 480: error is 1.317587
# Iteration 490: error is 1.309173
# Iteration 500: error is 1.301043
# Iteration 510: error is 1.293173
# Iteration 520: error is 1.285589
# Iteration 530: error is 1.278271
# Iteration 540: error is 1.271218
# Iteration 550: error is 1.264369
# Iteration 560: error is 1.257722
# Iteration 570: error is 1.251278
# Iteration 580: error is 1.245086
# Iteration 590: error is 1.239125
# Iteration 600: error is 1.233213
# Iteration 610: error is 1.227504
# Iteration 620: error is 1.222017
# Iteration 630: error is 1.216761
# Iteration 640: error is 1.211725
# Iteration 650: error is 1.206796
# Iteration 660: error is 1.201943
# Iteration 670: error is 1.197226
# Iteration 680: error is 1.192648
# Iteration 690: error is 1.188202
# Iteration 700: error is 1.183856
# Iteration 710: error is 1.179627
# Iteration 720: error is 1.175542
# Iteration 730: error is 1.171605
# Iteration 740: error is 1.167738
# Iteration 750: error is 1.163911
# Iteration 760: error is 1.160164
# Iteration 770: error is 1.156515
# Iteration 780: error is 1.152982
# Iteration 790: error is 1.149535
# Iteration 800: error is 1.146159
# Iteration 810: error is 1.142858
# Iteration 820: error is 1.139636
# Iteration 830: error is 1.136503
# Iteration 840: error is 1.133436
# Iteration 850: error is 1.130408
# Iteration 860: error is 1.127442
# Iteration 870: error is 1.124549
# Iteration 880: error is 1.121724
# Iteration 890: error is 1.118974
# Iteration 900: error is 1.116270
# Iteration 910: error is 1.113621
# Iteration 920: error is 1.111021
# Iteration 930: error is 1.108471
# Iteration 940: error is 1.105978
# Iteration 950: error is 1.103542
# Iteration 960: error is 1.101151
# Iteration 970: error is 1.098806
# Iteration 980: error is 1.096493
# Iteration 990: error is 1.094216
# Iteration 1000: error is 1.091995
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 2500...
# Computing P-values for point 500 of 2500...
# Computing P-values for point 1000 of 2500...
# Computing P-values for point 1500 of 2500...
# Computing P-values for point 2000 of 2500...
# Mean value of sigma: 1.760057
# Iteration 10: error is 27.752506
# Iteration 20: error is 23.095242
# Iteration 30: error is 19.838030
# Iteration 40: error is 19.580062
# Iteration 50: error is 19.359035
# Iteration 60: error is 18.918451
# Iteration 70: error is 18.669958
# Iteration 80: error is 18.535836
# Iteration 90: error is 18.480445
# Iteration 100: error is 18.446796
# Iteration 110: error is 2.834801
# Iteration 120: error is 2.476059
# Iteration 130: error is 2.393884
# Iteration 140: error is 2.382952
# Iteration 150: error is 2.381137
# Iteration 160: error is 2.375014
# Iteration 170: error is 2.368127
# Iteration 180: error is 2.361141
# Iteration 190: error is 2.357190
# Iteration 200: error is 2.354574
# Iteration 210: error is 2.352467
# Iteration 220: error is 2.352062
# Iteration 230: error is 2.351436
# Iteration 240: error is 2.350200
# Iteration 250: error is 2.348697
# Iteration 260: error is 2.347659
# Iteration 270: error is 2.346888
# Iteration 280: error is 2.346493
# Iteration 290: error is 2.346002
# Iteration 300: error is 2.345775
# Iteration 310: error is 2.345645
# Iteration 320: error is 2.345431
# Iteration 330: error is 2.345215
# Iteration 340: error is 2.345080
# Iteration 350: error is 2.345013
# Iteration 360: error is 2.344997
# Iteration 370: error is 2.344985
# Iteration 380: error is 2.344964
# Iteration 390: error is 2.344944
# Iteration 400: error is 2.344926
# Iteration 410: error is 2.344914
# Iteration 420: error is 2.344904
# Iteration 430: error is 2.344897
# Iteration 440: error is 2.344891
# Iteration 450: error is 2.344887
# Iteration 460: error is 2.344884
# Iteration 470: error is 2.344881
# Iteration 480: error is 2.344880
# Iteration 490: error is 2.344878
# Iteration 500: error is 2.344877
# Iteration 510: error is 2.344877
# Iteration 520: error is 2.344876
# Iteration 530: error is 2.344876
# Iteration 540: error is 2.344875
# Iteration 550: error is 2.344875
# Iteration 560: error is 2.344875
# Iteration 570: error is 2.344875
# Iteration 580: error is 2.344875
# Iteration 590: error is 2.344875
# Iteration 600: error is 2.344875
# Iteration 610: error is 2.344875
# Iteration 620: error is 2.344875
# Iteration 630: error is 2.344875
# Iteration 640: error is 2.344875
# Iteration 650: error is 2.344875
# Iteration 660: error is 2.344875
# Iteration 670: error is 2.344875
# Iteration 680: error is 2.344875
# Iteration 690: error is 2.344875
# Iteration 700: error is 2.344875
# Iteration 710: error is 2.344875
# Iteration 720: error is 2.344874
# Iteration 730: error is 2.344874
# Iteration 740: error is 2.344874
# Iteration 750: error is 2.344874
# Iteration 760: error is 2.344874
# Iteration 770: error is 2.344874
# Iteration 780: error is 2.344874
# Iteration 790: error is 2.344874
# Iteration 800: error is 2.344874
# Iteration 810: error is 2.344874
# Iteration 820: error is 2.344874
# Iteration 830: error is 2.344874
# Iteration 840: error is 2.344874
# Iteration 850: error is 2.344874
# Iteration 860: error is 2.344874
# Iteration 870: error is 2.344874
# Iteration 880: error is 2.344874
# Iteration 890: error is 2.344874
# Iteration 900: error is 2.344874
# Iteration 910: error is 2.344874
# Iteration 920: error is 2.344874
# Iteration 930: error is 2.344874
# Iteration 940: error is 2.344874
# Iteration 950: error is 2.344874
# Iteration 960: error is 2.344874
# Iteration 970: error is 2.344874
# Iteration 980: error is 2.344874
# Iteration 990: error is 2.344874
# Iteration 1000: error is 2.344874
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 2500...
# Computing P-values for point 500 of 2500...
# Computing P-values for point 1000 of 2500...
# Computing P-values for point 1500 of 2500...
# Computing P-values for point 2000 of 2500...
# Mean value of sigma: 1.760057
# Iteration 10: error is 28.174037
# Iteration 20: error is 26.087094
# Iteration 30: error is 22.557624
# Iteration 40: error is 20.602978
# Iteration 50: error is 19.671124
# Iteration 60: error is 19.134685
# Iteration 70: error is 18.741934
# Iteration 80: error is 18.415934
# Iteration 90: error is 18.142399
# Iteration 100: error is 17.925152
# Iteration 110: error is 2.899668
# Iteration 120: error is 2.720789
# Iteration 130: error is 2.545338
# Iteration 140: error is 2.377535
# Iteration 150: error is 2.227136
# Iteration 160: error is 2.098093
# Iteration 170: error is 1.991571
# Iteration 180: error is 1.907331
# Iteration 190: error is 1.839238
# Iteration 200: error is 1.780168
# Iteration 210: error is 1.727793
# Iteration 220: error is 1.681500
# Iteration 230: error is 1.641097
# Iteration 240: error is 1.605234
# Iteration 250: error is 1.573134
# Iteration 260: error is 1.544284
# Iteration 270: error is 1.518330
# Iteration 280: error is 1.494674
# Iteration 290: error is 1.473005
# Iteration 300: error is 1.453245
# Iteration 310: error is 1.435029
# Iteration 320: error is 1.418065
# Iteration 330: error is 1.402239
# Iteration 340: error is 1.387498
# Iteration 350: error is 1.373740
# Iteration 360: error is 1.360846
# Iteration 370: error is 1.348788
# Iteration 380: error is 1.337447
# Iteration 390: error is 1.326804
# Iteration 400: error is 1.316700
# Iteration 410: error is 1.307032
# Iteration 420: error is 1.297853
# Iteration 430: error is 1.289217
# Iteration 440: error is 1.281038
# Iteration 450: error is 1.273220
# Iteration 460: error is 1.265708
# Iteration 470: error is 1.258546
# Iteration 480: error is 1.251733
# Iteration 490: error is 1.245193
# Iteration 500: error is 1.238910
# Iteration 510: error is 1.232884
# Iteration 520: error is 1.227095
# Iteration 530: error is 1.221554
# Iteration 540: error is 1.216229
# Iteration 550: error is 1.211120
# Iteration 560: error is 1.206175
# Iteration 570: error is 1.201396
# Iteration 580: error is 1.196810
# Iteration 590: error is 1.192389
# Iteration 600: error is 1.188086
# Iteration 610: error is 1.183943
# Iteration 620: error is 1.179962
# Iteration 630: error is 1.176106
# Iteration 640: error is 1.172358
# Iteration 650: error is 1.168705
# Iteration 660: error is 1.165162
# Iteration 670: error is 1.161756
# Iteration 680: error is 1.158472
# Iteration 690: error is 1.155285
# Iteration 700: error is 1.152191
# Iteration 710: error is 1.149166
# Iteration 720: error is 1.146202
# Iteration 730: error is 1.143328
# Iteration 740: error is 1.140563
# Iteration 750: error is 1.137896
# Iteration 760: error is 1.135287
# Iteration 770: error is 1.132711
# Iteration 780: error is 1.130198
# Iteration 790: error is 1.127763
# Iteration 800: error is 1.125396
# Iteration 810: error is 1.123091
# Iteration 820: error is 1.120840
# Iteration 830: error is 1.118646
# Iteration 840: error is 1.116501
# Iteration 850: error is 1.114399
# Iteration 860: error is 1.112353
# Iteration 870: error is 1.110357
# Iteration 880: error is 1.108405
# Iteration 890: error is 1.106491
# Iteration 900: error is 1.104618
# Iteration 910: error is 1.102788
# Iteration 920: error is 1.101004
# Iteration 930: error is 1.099259
# Iteration 940: error is 1.097551
# Iteration 950: error is 1.095872
# Iteration 960: error is 1.094221
# Iteration 970: error is 1.092610
# Iteration 980: error is 1.091045
# Iteration 990: error is 1.089511
# Iteration 1000: error is 1.088007
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 2500...
# Computing P-values for point 500 of 2500...
# Computing P-values for point 1000 of 2500...
# Computing P-values for point 1500 of 2500...
# Computing P-values for point 2000 of 2500...
# Mean value of sigma: 2.386597
# Iteration 10: error is 23.288643
# Iteration 20: error is 18.802821
# Iteration 30: error is 17.392249
# Iteration 40: error is 17.306023
# Iteration 50: error is 17.269098
# Iteration 60: error is 16.870073
# Iteration 70: error is 16.902695
# Iteration 80: error is 16.887604
# Iteration 90: error is 16.846291
# Iteration 100: error is 16.855944
# Iteration 110: error is 2.276671
# Iteration 120: error is 2.102594
# Iteration 130: error is 2.102660
# Iteration 140: error is 2.115412
# Iteration 150: error is 2.123844
# Iteration 160: error is 2.122086
# Iteration 170: error is 2.118734
# Iteration 180: error is 2.117902
# Iteration 190: error is 2.118162
# Iteration 200: error is 2.118450
# Iteration 210: error is 2.118492
# Iteration 220: error is 2.118457
# Iteration 230: error is 2.118442
# Iteration 240: error is 2.118440
# Iteration 250: error is 2.118441
# Iteration 260: error is 2.118441
# Iteration 270: error is 2.118440
# Iteration 280: error is 2.118440
# Iteration 290: error is 2.118440
# Iteration 300: error is 2.118440
# Iteration 310: error is 2.118440
# Iteration 320: error is 2.118440
# Iteration 330: error is 2.118440
# Iteration 340: error is 2.118440
# Iteration 350: error is 2.118440
# Iteration 360: error is 2.118440
# Iteration 370: error is 2.118440
# Iteration 380: error is 2.118440
# Iteration 390: error is 2.118440
# Iteration 400: error is 2.118440
# Iteration 410: error is 2.118440
# Iteration 420: error is 2.118440
# Iteration 430: error is 2.118440
# Iteration 440: error is 2.118440
# Iteration 450: error is 2.118440
# Iteration 460: error is 2.118440
# Iteration 470: error is 2.118440
# Iteration 480: error is 2.118440
# Iteration 490: error is 2.118440
# Iteration 500: error is 2.118440
# Iteration 510: error is 2.118440
# Iteration 520: error is 2.118440
# Iteration 530: error is 2.118440
# Iteration 540: error is 2.118440
# Iteration 550: error is 2.118440
# Iteration 560: error is 2.118440
# Iteration 570: error is 2.118440
# Iteration 580: error is 2.118440
# Iteration 590: error is 2.118440
# Iteration 600: error is 2.118440
# Iteration 610: error is 2.118440
# Iteration 620: error is 2.118440
# Iteration 630: error is 2.118440
# Iteration 640: error is 2.118440
# Iteration 650: error is 2.118440
# Iteration 660: error is 2.118440
# Iteration 670: error is 2.118440
# Iteration 680: error is 2.118440
# Iteration 690: error is 2.118440
# Iteration 700: error is 2.118440
# Iteration 710: error is 2.118440
# Iteration 720: error is 2.118440
# Iteration 730: error is 2.118440
# Iteration 740: error is 2.118440
# Iteration 750: error is 2.118440
# Iteration 760: error is 2.118440
# Iteration 770: error is 2.118440
# Iteration 780: error is 2.118440
# Iteration 790: error is 2.118440
# Iteration 800: error is 2.118440
# Iteration 810: error is 2.118440
# Iteration 820: error is 2.118440
# Iteration 830: error is 2.118440
# Iteration 840: error is 2.118440
# Iteration 850: error is 2.118440
# Iteration 860: error is 2.118440
# Iteration 870: error is 2.118440
# Iteration 880: error is 2.118440
# Iteration 890: error is 2.118440
# Iteration 900: error is 2.118440
# Iteration 910: error is 2.118440
# Iteration 920: error is 2.118440
# Iteration 930: error is 2.118440
# Iteration 940: error is 2.118440
# Iteration 950: error is 2.118440
# Iteration 960: error is 2.118440
# Iteration 970: error is 2.118440
# Iteration 980: error is 2.118440
# Iteration 990: error is 2.118440
# Iteration 1000: error is 2.118440
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 2500...
# Computing P-values for point 500 of 2500...
# Computing P-values for point 1000 of 2500...
# Computing P-values for point 1500 of 2500...
# Computing P-values for point 2000 of 2500...
# Mean value of sigma: 2.386597
# Iteration 10: error is 23.576482
# Iteration 20: error is 20.832417
# Iteration 30: error is 17.671951
# Iteration 40: error is 16.628326
# Iteration 50: error is 16.324660
# Iteration 60: error is 16.188415
# Iteration 70: error is 16.087181
# Iteration 80: error is 16.003140
# Iteration 90: error is 15.947544
# Iteration 100: error is 15.907536
# Iteration 110: error is 2.310186
# Iteration 120: error is 2.070657
# Iteration 130: error is 1.887381
# Iteration 140: error is 1.749485
# Iteration 150: error is 1.643768
# Iteration 160: error is 1.560776
# Iteration 170: error is 1.493868
# Iteration 180: error is 1.439097
# Iteration 190: error is 1.393630
# Iteration 200: error is 1.355521
# Iteration 210: error is 1.323175
# Iteration 220: error is 1.295418
# Iteration 230: error is 1.271562
# Iteration 240: error is 1.251003
# Iteration 250: error is 1.232947
# Iteration 260: error is 1.216864
# Iteration 270: error is 1.202450
# Iteration 280: error is 1.189448
# Iteration 290: error is 1.177711
# Iteration 300: error is 1.167069
# Iteration 310: error is 1.157377
# Iteration 320: error is 1.148552
# Iteration 330: error is 1.140508
# Iteration 340: error is 1.133140
# Iteration 350: error is 1.126312
# Iteration 360: error is 1.119956
# Iteration 370: error is 1.114078
# Iteration 380: error is 1.108613
# Iteration 390: error is 1.103520
# Iteration 400: error is 1.098802
# Iteration 410: error is 1.094405
# Iteration 420: error is 1.090280
# Iteration 430: error is 1.086405
# Iteration 440: error is 1.082756
# Iteration 450: error is 1.079317
# Iteration 460: error is 1.076075
# Iteration 470: error is 1.073028
# Iteration 480: error is 1.070151
# Iteration 490: error is 1.067438
# Iteration 500: error is 1.064869
# Iteration 510: error is 1.062418
# Iteration 520: error is 1.060091
# Iteration 530: error is 1.057877
# Iteration 540: error is 1.055763
# Iteration 550: error is 1.053753
# Iteration 560: error is 1.051835
# Iteration 570: error is 1.049989
# Iteration 580: error is 1.048233
# Iteration 590: error is 1.046578
# Iteration 600: error is 1.044989
# Iteration 610: error is 1.043473
# Iteration 620: error is 1.042025
# Iteration 630: error is 1.040638
# Iteration 640: error is 1.039309
# Iteration 650: error is 1.038032
# Iteration 660: error is 1.036809
# Iteration 670: error is 1.035631
# Iteration 680: error is 1.034485
# Iteration 690: error is 1.033372
# Iteration 700: error is 1.032307
# Iteration 710: error is 1.031289
# Iteration 720: error is 1.030310
# Iteration 730: error is 1.029367
# Iteration 740: error is 1.028458
# Iteration 750: error is 1.027576
# Iteration 760: error is 1.026718
# Iteration 770: error is 1.025887
# Iteration 780: error is 1.025082
# Iteration 790: error is 1.024304
# Iteration 800: error is 1.023553
# Iteration 810: error is 1.022825
# Iteration 820: error is 1.022116
# Iteration 830: error is 1.021429
# Iteration 840: error is 1.020761
# Iteration 850: error is 1.020115
# Iteration 860: error is 1.019489
# Iteration 870: error is 1.018877
# Iteration 880: error is 1.018279
# Iteration 890: error is 1.017698
# Iteration 900: error is 1.017135
# Iteration 910: error is 1.016584
# Iteration 920: error is 1.016044
# Iteration 930: error is 1.015513
# Iteration 940: error is 1.014990
# Iteration 950: error is 1.014484
# Iteration 960: error is 1.014004
# Iteration 970: error is 1.013539
# Iteration 980: error is 1.013088
# Iteration 990: error is 1.012648
# Iteration 1000: error is 1.012218
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 2500...
# Computing P-values for point 500 of 2500...
# Computing P-values for point 1000 of 2500...
# Computing P-values for point 1500 of 2500...
# Computing P-values for point 2000 of 2500...
# Mean value of sigma: 2.822817
# Iteration 10: error is 20.188395
# Iteration 20: error is 16.729053
# Iteration 30: error is 15.681097
# Iteration 40: error is 15.523372
# Iteration 50: error is 15.392456
# Iteration 60: error is 15.396359
# Iteration 70: error is 15.312283
# Iteration 80: error is 15.339744
# Iteration 90: error is 15.345956
# Iteration 100: error is 15.342288
# Iteration 110: error is 1.844043
# Iteration 120: error is 1.781785
# Iteration 130: error is 1.788240
# Iteration 140: error is 1.797677
# Iteration 150: error is 1.793810
# Iteration 160: error is 1.790792
# Iteration 170: error is 1.790774
# Iteration 180: error is 1.791112
# Iteration 190: error is 1.791072
# Iteration 200: error is 1.790957
# Iteration 210: error is 1.790927
# Iteration 220: error is 1.790922
# Iteration 230: error is 1.790924
# Iteration 240: error is 1.790926
# Iteration 250: error is 1.790926
# Iteration 260: error is 1.790927
# Iteration 270: error is 1.790927
# Iteration 280: error is 1.790927
# Iteration 290: error is 1.790927
# Iteration 300: error is 1.790927
# Iteration 310: error is 1.790927
# Iteration 320: error is 1.790927
# Iteration 330: error is 1.790927
# Iteration 340: error is 1.790927
# Iteration 350: error is 1.790927
# Iteration 360: error is 1.790927
# Iteration 370: error is 1.790927
# Iteration 380: error is 1.790927
# Iteration 390: error is 1.790927
# Iteration 400: error is 1.790927
# Iteration 410: error is 1.790927
# Iteration 420: error is 1.790927
# Iteration 430: error is 1.790927
# Iteration 440: error is 1.790927
# Iteration 450: error is 1.790927
# Iteration 460: error is 1.790927
# Iteration 470: error is 1.790927
# Iteration 480: error is 1.790927
# Iteration 490: error is 1.790927
# Iteration 500: error is 1.790927
# Iteration 510: error is 1.790927
# Iteration 520: error is 1.790927
# Iteration 530: error is 1.790927
# Iteration 540: error is 1.790927
# Iteration 550: error is 1.790927
# Iteration 560: error is 1.790927
# Iteration 570: error is 1.790927
# Iteration 580: error is 1.790927
# Iteration 590: error is 1.790927
# Iteration 600: error is 1.790927
# Iteration 610: error is 1.790927
# Iteration 620: error is 1.790927
# Iteration 630: error is 1.790927
# Iteration 640: error is 1.790927
# Iteration 650: error is 1.790927
# Iteration 660: error is 1.790927
# Iteration 670: error is 1.790927
# Iteration 680: error is 1.790927
# Iteration 690: error is 1.790927
# Iteration 700: error is 1.790927
# Iteration 710: error is 1.790927
# Iteration 720: error is 1.790927
# Iteration 730: error is 1.790927
# Iteration 740: error is 1.790927
# Iteration 750: error is 1.790927
# Iteration 760: error is 1.790927
# Iteration 770: error is 1.790927
# Iteration 780: error is 1.790927
# Iteration 790: error is 1.790927
# Iteration 800: error is 1.790927
# Iteration 810: error is 1.790927
# Iteration 820: error is 1.790927
# Iteration 830: error is 1.790927
# Iteration 840: error is 1.790927
# Iteration 850: error is 1.790927
# Iteration 860: error is 1.790927
# Iteration 870: error is 1.790927
# Iteration 880: error is 1.790927
# Iteration 890: error is 1.790927
# Iteration 900: error is 1.790927
# Iteration 910: error is 1.790927
# Iteration 920: error is 1.790927
# Iteration 930: error is 1.790927
# Iteration 940: error is 1.790927
# Iteration 950: error is 1.790927
# Iteration 960: error is 1.790927
# Iteration 970: error is 1.790927
# Iteration 980: error is 1.790927
# Iteration 990: error is 1.790927
# Iteration 1000: error is 1.790927
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 2500...
# Computing P-values for point 500 of 2500...
# Computing P-values for point 1000 of 2500...
# Computing P-values for point 1500 of 2500...
# Computing P-values for point 2000 of 2500...
# Mean value of sigma: 2.822817
# Iteration 10: error is 20.343673
# Iteration 20: error is 18.333642
# Iteration 30: error is 15.852758
# Iteration 40: error is 15.243812
# Iteration 50: error is 15.136431
# Iteration 60: error is 15.082856
# Iteration 70: error is 15.101816
# Iteration 80: error is 15.154068
# Iteration 90: error is 15.172043
# Iteration 100: error is 15.152017
# Iteration 110: error is 2.010141
# Iteration 120: error is 1.649446
# Iteration 130: error is 1.460622
# Iteration 140: error is 1.346208
# Iteration 150: error is 1.268368
# Iteration 160: error is 1.211522
# Iteration 170: error is 1.168367
# Iteration 180: error is 1.134439
# Iteration 190: error is 1.107167
# Iteration 200: error is 1.084699
# Iteration 210: error is 1.065917
# Iteration 220: error is 1.050034
# Iteration 230: error is 1.036449
# Iteration 240: error is 1.024735
# Iteration 250: error is 1.014547
# Iteration 260: error is 1.005624
# Iteration 270: error is 0.997765
# Iteration 280: error is 0.990815
# Iteration 290: error is 0.984640
# Iteration 300: error is 0.979111
# Iteration 310: error is 0.974123
# Iteration 320: error is 0.969604
# Iteration 330: error is 0.965498
# Iteration 340: error is 0.961745
# Iteration 350: error is 0.958288
# Iteration 360: error is 0.955121
# Iteration 370: error is 0.952262
# Iteration 380: error is 0.949652
# Iteration 390: error is 0.947258
# Iteration 400: error is 0.945050
# Iteration 410: error is 0.943005
# Iteration 420: error is 0.941104
# Iteration 430: error is 0.939333
# Iteration 440: error is 0.937685
# Iteration 450: error is 0.936152
# Iteration 460: error is 0.934723
# Iteration 470: error is 0.933388
# Iteration 480: error is 0.932140
# Iteration 490: error is 0.930972
# Iteration 500: error is 0.929877
# Iteration 510: error is 0.928841
# Iteration 520: error is 0.927868
# Iteration 530: error is 0.926957
# Iteration 540: error is 0.926097
# Iteration 550: error is 0.925281
# Iteration 560: error is 0.924514
# Iteration 570: error is 0.923795
# Iteration 580: error is 0.923119
# Iteration 590: error is 0.922483
# Iteration 600: error is 0.921882
# Iteration 610: error is 0.921313
# Iteration 620: error is 0.920770
# Iteration 630: error is 0.920254
# Iteration 640: error is 0.919762
# Iteration 650: error is 0.919295
# Iteration 660: error is 0.918851
# Iteration 670: error is 0.918429
# Iteration 680: error is 0.918028
# Iteration 690: error is 0.917646
# Iteration 700: error is 0.917279
# Iteration 710: error is 0.916885
# Iteration 720: error is 0.916548
# Iteration 730: error is 0.916232
# Iteration 740: error is 0.915933
# Iteration 750: error is 0.915642
# Iteration 760: error is 0.915354
# Iteration 770: error is 0.915067
# Iteration 780: error is 0.914792
# Iteration 790: error is 0.914546
# Iteration 800: error is 0.914314
# Iteration 810: error is 0.914091
# Iteration 820: error is 0.913876
# Iteration 830: error is 0.913670
# Iteration 840: error is 0.913473
# Iteration 850: error is 0.913282
# Iteration 860: error is 0.913099
# Iteration 870: error is 0.912922
# Iteration 880: error is 0.912750
# Iteration 890: error is 0.912584
# Iteration 900: error is 0.912425
# Iteration 910: error is 0.912272
# Iteration 920: error is 0.912125
# Iteration 930: error is 0.911982
# Iteration 940: error is 0.911844
# Iteration 950: error is 0.911710
# Iteration 960: error is 0.911581
# Iteration 970: error is 0.911458
# Iteration 980: error is 0.911338
# Iteration 990: error is 0.911221
# Iteration 1000: error is 0.911107
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 2500...
# Computing P-values for point 500 of 2500...
# Computing P-values for point 1000 of 2500...
# Computing P-values for point 1500 of 2500...
# Computing P-values for point 2000 of 2500...
# Mean value of sigma: 3.194475
# Iteration 10: error is 17.932950
# Iteration 20: error is 16.121495
# Iteration 30: error is 14.453624
# Iteration 40: error is 14.273035
# Iteration 50: error is 14.347467
# Iteration 60: error is 14.308852
# Iteration 70: error is 14.324099
# Iteration 80: error is 14.322083
# Iteration 90: error is 14.318263
# Iteration 100: error is 14.319719
# Iteration 110: error is 1.606142
# Iteration 120: error is 1.566706
# Iteration 130: error is 1.570390
# Iteration 140: error is 1.568056
# Iteration 150: error is 1.563370
# Iteration 160: error is 1.563600
# Iteration 170: error is 1.564131
# Iteration 180: error is 1.563896
# Iteration 190: error is 1.563826
# Iteration 200: error is 1.563860
# Iteration 210: error is 1.563857
# Iteration 220: error is 1.563854
# Iteration 230: error is 1.563854
# Iteration 240: error is 1.563854
# Iteration 250: error is 1.563854
# Iteration 260: error is 1.563854
# Iteration 270: error is 1.563854
# Iteration 280: error is 1.563854
# Iteration 290: error is 1.563854
# Iteration 300: error is 1.563854
# Iteration 310: error is 1.563854
# Iteration 320: error is 1.563854
# Iteration 330: error is 1.563854
# Iteration 340: error is 1.563854
# Iteration 350: error is 1.563854
# Iteration 360: error is 1.563854
# Iteration 370: error is 1.563854
# Iteration 380: error is 1.563854
# Iteration 390: error is 1.563854
# Iteration 400: error is 1.563854
# Iteration 410: error is 1.563854
# Iteration 420: error is 1.563854
# Iteration 430: error is 1.563854
# Iteration 440: error is 1.563854
# Iteration 450: error is 1.563854
# Iteration 460: error is 1.563854
# Iteration 470: error is 1.563854
# Iteration 480: error is 1.563854
# Iteration 490: error is 1.563854
# Iteration 500: error is 1.563854
# Iteration 510: error is 1.563854
# Iteration 520: error is 1.563854
# Iteration 530: error is 1.563854
# Iteration 540: error is 1.563854
# Iteration 550: error is 1.563854
# Iteration 560: error is 1.563854
# Iteration 570: error is 1.563854
# Iteration 580: error is 1.563854
# Iteration 590: error is 1.563854
# Iteration 600: error is 1.563854
# Iteration 610: error is 1.563854
# Iteration 620: error is 1.563854
# Iteration 630: error is 1.563854
# Iteration 640: error is 1.563854
# Iteration 650: error is 1.563854
# Iteration 660: error is 1.563854
# Iteration 670: error is 1.563854
# Iteration 680: error is 1.563854
# Iteration 690: error is 1.563854
# Iteration 700: error is 1.563854
# Iteration 710: error is 1.563854
# Iteration 720: error is 1.563854
# Iteration 730: error is 1.563854
# Iteration 740: error is 1.563854
# Iteration 750: error is 1.563854
# Iteration 760: error is 1.563854
# Iteration 770: error is 1.563854
# Iteration 780: error is 1.563854
# Iteration 790: error is 1.563854
# Iteration 800: error is 1.563854
# Iteration 810: error is 1.563854
# Iteration 820: error is 1.563854
# Iteration 830: error is 1.563854
# Iteration 840: error is 1.563854
# Iteration 850: error is 1.563854
# Iteration 860: error is 1.563854
# Iteration 870: error is 1.563854
# Iteration 880: error is 1.563854
# Iteration 890: error is 1.563854
# Iteration 900: error is 1.563854
# Iteration 910: error is 1.563854
# Iteration 920: error is 1.563854
# Iteration 930: error is 1.563854
# Iteration 940: error is 1.563854
# Iteration 950: error is 1.563854
# Iteration 960: error is 1.563854
# Iteration 970: error is 1.563854
# Iteration 980: error is 1.563854
# Iteration 990: error is 1.563854
# Iteration 1000: error is 1.563854
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 2500...
# Computing P-values for point 500 of 2500...
# Computing P-values for point 1000 of 2500...
# Computing P-values for point 1500 of 2500...
# Computing P-values for point 2000 of 2500...
# Mean value of sigma: 3.194475
# Iteration 10: error is 17.768318
# Iteration 20: error is 16.403639
# Iteration 30: error is 14.797307
# Iteration 40: error is 14.479419
# Iteration 50: error is 14.664911
# Iteration 60: error is 14.821155
# Iteration 70: error is 14.819975
# Iteration 80: error is 14.796038
# Iteration 90: error is 14.783819
# Iteration 100: error is 14.784449
# Iteration 110: error is 1.673270
# Iteration 120: error is 1.302888
# Iteration 130: error is 1.160139
# Iteration 140: error is 1.084625
# Iteration 150: error is 1.035614
# Iteration 160: error is 1.000282
# Iteration 170: error is 0.974060
# Iteration 180: error is 0.953888
# Iteration 190: error is 0.937883
# Iteration 200: error is 0.924880
# Iteration 210: error is 0.914146
# Iteration 220: error is 0.905410
# Iteration 230: error is 0.898115
# Iteration 240: error is 0.891955
# Iteration 250: error is 0.886695
# Iteration 260: error is 0.882206
# Iteration 270: error is 0.878358
# Iteration 280: error is 0.875019
# Iteration 290: error is 0.872093
# Iteration 300: error is 0.869505
# Iteration 310: error is 0.867211
# Iteration 320: error is 0.865202
# Iteration 330: error is 0.863426
# Iteration 340: error is 0.861845
# Iteration 350: error is 0.860444
# Iteration 360: error is 0.859207
# Iteration 370: error is 0.858106
# Iteration 380: error is 0.857123
# Iteration 390: error is 0.856241
# Iteration 400: error is 0.855447
# Iteration 410: error is 0.854733
# Iteration 420: error is 0.854089
# Iteration 430: error is 0.853507
# Iteration 440: error is 0.852981
# Iteration 450: error is 0.852503
# Iteration 460: error is 0.852071
# Iteration 470: error is 0.851679
# Iteration 480: error is 0.851322
# Iteration 490: error is 0.850996
# Iteration 500: error is 0.850696
# Iteration 510: error is 0.850423
# Iteration 520: error is 0.850176
# Iteration 530: error is 0.849950
# Iteration 540: error is 0.849725
# Iteration 550: error is 0.849453
# Iteration 560: error is 0.849268
# Iteration 570: error is 0.849102
# Iteration 580: error is 0.848948
# Iteration 590: error is 0.848812
# Iteration 600: error is 0.848671
# Iteration 610: error is 0.848494
# Iteration 620: error is 0.848291
# Iteration 630: error is 0.847848
# Iteration 640: error is 0.847664
# Iteration 650: error is 0.847582
# Iteration 660: error is 0.847519
# Iteration 670: error is 0.847467
# Iteration 680: error is 0.847419
# Iteration 690: error is 0.847374
# Iteration 700: error is 0.847332
# Iteration 710: error is 0.847288
# Iteration 720: error is 0.847236
# Iteration 730: error is 0.847197
# Iteration 740: error is 0.847162
# Iteration 750: error is 0.847129
# Iteration 760: error is 0.847099
# Iteration 770: error is 0.847071
# Iteration 780: error is 0.847043
# Iteration 790: error is 0.847018
# Iteration 800: error is 0.846993
# Iteration 810: error is 0.846971
# Iteration 820: error is 0.846949
# Iteration 830: error is 0.846929
# Iteration 840: error is 0.846910
# Iteration 850: error is 0.846892
# Iteration 860: error is 0.846875
# Iteration 870: error is 0.846859
# Iteration 880: error is 0.846844
# Iteration 890: error is 0.846830
# Iteration 900: error is 0.846817
# Iteration 910: error is 0.846804
# Iteration 920: error is 0.846793
# Iteration 930: error is 0.846782
# Iteration 940: error is 0.846772
# Iteration 950: error is 0.846762
# Iteration 960: error is 0.846753
# Iteration 970: error is 0.846745
# Iteration 980: error is 0.846737
# Iteration 990: error is 0.846729
# Iteration 1000: error is 0.846722
