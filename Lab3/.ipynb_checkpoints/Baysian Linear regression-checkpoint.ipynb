# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
b = float(input("Precision for initial prior: "))
n = int(input("Basis number: "))
error_gen = float(input("Varience for error(generator): "))
W = np.array([float(s) for s in input("{}X1 W vector: ".format(n)).split(",")])
# Out:
# Precision for initial prior: 1
# Basis number: 3
# Varience for error(generator): 3
# 3X1 W vector: 1,2,3

# %%
W
# Out:
# array([1., 2., 3.])

# %%
def univariate_gaussian_data_generator():
    temp = np.sum(np.random.uniform(0,1,12))-6
    temp = 0 + temp*np.sqrt(error_gen)
    return temp

# %%
def polynomial_basis_linear_model_generator():
    x = float(np.random.uniform(-1,1,1))
    y = 0
    for i in range(len(W)):
        y += W[i]*(x**i)
    return x, y + univariate_gaussian_data_generator()

# %%
N = 0
x = []
y = []
data_mean = 0
prev_data_mean = 0
a = 0
prev_m = np.zeros((n,1))
prev_S = np.zeros((n,n))
while(1):
    N += 1
    new_x, new_y = polynomial_basis_linear_model_generator()
    x.append(new_x)
    y.append(new_y)
    print("Add data point ({:.5f}, {:.5f})\n".format(new_x, new_y))
    
    data_mean = ((N-1)*data_mean+new_y)/N
    a = ((N-1)*(a+prev_data_mean**2)+new_y**2)/N - data_mean**2
    if a == 0:
        a = 0.001
    
    A = np.array([[new_x**j for j in range(n)]])
    if N == 1:
        S_inv = np.linalg.inv(a*np.transpose(A)*A+b*np.identity(n))
        m = a*np.dot(S_inv,np.transpose(A))*new_y
    else:
        S = np.linalg.inv(S_inv)
        S_inv = np.linalg.inv(a*np.dot(np.transpose(A),A)+S)
        m = np.dot(S_inv, (a*np.transpose(A)*new_y+np.dot(S,m)))
    
    print("Posterior mean:")
    for i in range(m.shape[0]):
        print("{:16.10f}".format(m[i][0]))
    print("")
    
    print("Posterior varience:")
    for i in range(S_inv.shape[0]):
        for j in range(S_inv.shape[1]):
            if j == S_inv.shape[1]-1:
                print("{:16.10f}".format(S_inv[i][j]))
            else:
                print("{:16.10f},".format(S_inv[i][j]), end="")
    print("")
    
    predictive_distribution_mean = np.dot(A,m)[0][0]
    predictive_distribution_varience = 1/a + np.dot(A,np.dot(S_inv,np.transpose(A)))[0][0]
    print("Predictive distribution ~ N({:.5f}, {:.5f})".format(predictive_distribution_mean,predictive_distribution_varience))
    print("--------------------------------------------------")
    
    if (N!=0 and np.linalg.norm(m-prev_m)<0.0001 and np.linalg.norm(S_inv-prev_S)<0.0001):
        break
    
    prev_data_mean = data_mean
    prev_m = m
    prev_S = S_inv
    
    if (N==10):
        m_10 = m
        S_10 = S_inv
        a_10 = a
    if (N==50):
        m_50 = m
        S_50 = S_inv
        a_50 = a
# Out:
# Add data point (-0.67506, 0.45121)
#
# Posterior mean:
#     0.0004504618
#    -0.0003040895
#     0.0002052791
#
# Posterior varience:
#     0.9990016606,    0.0006739405,   -0.0004549513
#     0.0006739405,    0.9995450487,    0.0003071202
#    -0.0004549513,    0.0003071202,    0.9997926750
#
# Predictive distribution ~ N(0.00075, 1001.66062)
# --------------------------------------------------
# Add data point (0.41847, 2.62978)
#
# Posterior mean:
#     1.2835907160
#     0.5377674997
#     0.2246167339
#
# Posterior varience:
#     0.5113967832,   -0.2037981196,   -0.0857333296
#    -0.2037981196,    0.9138018059,   -0.0354534854
#    -0.0857333296,   -0.0354534854,    0.9848781363
#
# Predictive distribution ~ N(1.54796, 1.33826)
# --------------------------------------------------
# Add data point (-0.10242, -0.45320)
#
# Posterior mean:
#     0.5109951165
#     0.9707068417
#     0.3289682664
#
# Posterior varience:
#     0.2676204443,   -0.0671931897,   -0.0528073919
#    -0.0671931897,    0.8372525108,   -0.0539041908
#    -0.0528073919,   -0.0539041908,    0.9804309559
#
# Predictive distribution ~ N(0.41502, 0.88642)
# --------------------------------------------------
# Add data point (0.09094, 0.32028)
#
# Posterior mean:
#     0.4390682744
#     0.9683654067
#     0.3426336943
#
# Posterior varience:
#     0.2009636016,   -0.0693630704,   -0.0401432147
#    -0.0693630704,    0.8371818747,   -0.0534919337
#    -0.0401432147,   -0.0534919337,    0.9780248805
#
# Predictive distribution ~ N(0.52996, 0.95570)
# --------------------------------------------------
# Add data point (0.51098, 2.35245)
#
# Posterior mean:
#     0.6332831189
#     1.3998563502
#     0.5779957090
#
# Posterior varience:
#     0.1783085735,   -0.1196961924,   -0.0675980319
#    -0.1196961924,    0.7253557866,   -0.1144888417
#    -0.0675980319,   -0.1144888417,    0.9447533707
#
# Predictive distribution ~ N(1.49950, 0.92483)
# --------------------------------------------------
# Add data point (0.98015, 3.77526)
#
# Posterior mean:
#     0.6303045224
#     1.7625266152
#     1.1264440010
#
# Posterior varience:
#     0.1782988805,   -0.1185159874,   -0.0658132664
#    -0.1185159874,    0.5816554777,   -0.3317997067
#    -0.0658132664,   -0.3317997067,    0.6161249051
#
# Predictive distribution ~ N(3.44001, 0.76698)
# --------------------------------------------------
# Add data point (0.63747, 2.18823)
#
# Posterior mean:
#     0.6275466409
#     1.7582652271
#     1.1274219902
#
# Posterior varience:
#     0.1693333598,   -0.1323692164,   -0.0626339481
#    -0.1323692164,    0.5602499222,   -0.3268871282
#    -0.0626339481,   -0.3268871282,    0.6149974675
#
# Predictive distribution ~ N(2.20654, 0.61393)
# --------------------------------------------------
# Add data point (0.72151, 5.15364)
#
# Posterior mean:
#     0.8735403346
#     2.3650692426
#     1.2567023710
#
# Posterior varience:
#     0.1655362298,   -0.1417357724,   -0.0646295050
#    -0.1417357724,    0.5371450056,   -0.3318096606
#    -0.0646295050,   -0.3318096606,    0.6139487156
#
# Predictive distribution ~ N(3.23415, 0.41213)
# --------------------------------------------------
# Add data point (0.04939, 1.62223)
#
# Posterior mean:
#     1.0680691634
#     2.2225741005
#     1.1590302792
#
# Posterior varience:
#     0.1165399556,   -0.1058453026,   -0.0400286855
#    -0.1058453026,    0.5108547245,   -0.3498301118
#    -0.0400286855,   -0.3498301118,    0.6015967495
#
# Predictive distribution ~ N(1.18068, 0.46655)
# --------------------------------------------------
# Add data point (0.87276, 5.72404)
#
# Posterior mean:
#     1.0398125245
#     2.5509197621
#     1.6631157366
#
# Posterior varience:
#     0.1164424155,   -0.1047118745,   -0.0382886150
#    -0.1047118745,    0.4976841491,   -0.3700499480
#    -0.0382886150,   -0.3700499480,    0.5705546906
#
# Predictive distribution ~ N(4.53299, 0.36021)
# --------------------------------------------------
# Add data point (0.56484, 4.51677)
#
# Posterior mean:
#     1.2510480096
#     2.8242682270
#     1.3572561096
#
# Posterior varience:
#     0.1101170510,   -0.1128971880,   -0.0291297674
#    -0.1128971880,    0.4870919757,   -0.3581979765
#    -0.0291297674,   -0.3581979765,    0.5572930849
#
# Predictive distribution ~ N(3.27932, 0.31112)
# --------------------------------------------------
# Add data point (0.35924, 3.10180)
#
# Posterior mean:
#     1.3764878534
#     2.8545001052
#     1.1935224815
#
# Posterior varience:
#     0.0976300128,   -0.1159066514,   -0.0128307350
#    -0.1159066514,    0.4863666741,   -0.3542697959
#    -0.0128307350,   -0.3542697959,    0.5360183476
#
# Predictive distribution ~ N(2.55596, 0.33621)
# --------------------------------------------------
# Add data point (-0.03459, -1.08159)
#
# Posterior mean:
#     0.6803908175
#     3.7665602669
#     1.1930892171
#
# Posterior varience:
#     0.0676653934,   -0.0766455511,   -0.0128493855
#    -0.0766455511,    0.4349248726,   -0.3542453590
#    -0.0128493855,   -0.3542453590,    0.5360183360
#
# Predictive distribution ~ N(0.55155, 0.31191)
# --------------------------------------------------
# Add data point (0.64444, 3.80756)
#
# Posterior mean:
#     0.6895292865
#     3.8064893063
#     1.1799995221
#
# Posterior varience:
#     0.0670868960,   -0.0791732004,   -0.0120207616
#    -0.0791732004,    0.4238807242,   -0.3506248228
#    -0.0120207616,   -0.3506248228,    0.5348314375
#
# Predictive distribution ~ N(3.63266, 0.28323)
# --------------------------------------------------
# Add data point (0.88016, 3.67267)
#
# Posterior mean:
#     0.7345460610
#     3.7222573495
#     0.8258628432
#
# Posterior varience:
#     0.0666684329,   -0.0783902041,   -0.0087288078
#    -0.0783902041,    0.4224156412,   -0.3567844757
#    -0.0087288078,   -0.3567844757,    0.5089343895
#
# Predictive distribution ~ N(4.65052, 0.32000)
# --------------------------------------------------
# Add data point (-0.14584, 2.61670)
#
# Posterior mean:
#     1.2327303723
#     2.7786167791
#     1.1719616669
#
# Posterior varience:
#     0.0505450252,   -0.0478498974,   -0.0199300687
#    -0.0478498974,    0.3645674277,   -0.3355675004
#    -0.0199300687,   -0.3355675004,    0.5011526446
#
# Predictive distribution ~ N(0.85242, 0.34965)
# --------------------------------------------------
# Add data point (-0.37271, -0.01949)
#
# Posterior mean:
#     1.1762893086
#     2.9767673650
#     1.0216290480
#
# Posterior varience:
#     0.0407844764,   -0.0135830297,   -0.0459276096
#    -0.0135830297,    0.2442649483,   -0.2442965778
#    -0.0459276096,   -0.2442965778,    0.4319073443
#
# Predictive distribution ~ N(0.20873, 0.37101)
# --------------------------------------------------
# Add data point (0.71074, 3.70453)
#
# Posterior mean:
#     1.1736150870
#     2.9644185181
#     1.0220945866
#
# Posterior varience:
#     0.0405796563,   -0.0145288349,   -0.0458919537
#    -0.0145288349,    0.2398974708,   -0.2441319285
#    -0.0458919537,   -0.2441319285,    0.4319011372
#
# Predictive distribution ~ N(3.79686, 0.30343)
# --------------------------------------------------
# Add data point (-0.68859, 6.76996)
#
# Posterior mean:
#     1.5088326028
#    -0.4719014986
#     4.8250652286
#
# Posterior varience:
#     0.0392288416,   -0.0006816123,   -0.0612166559
#    -0.0006816123,    0.0979493755,   -0.0870381664
#    -0.0612166559,   -0.0870381664,    0.2580456865
#
# Predictive distribution ~ N(4.12161, 0.37113)
# --------------------------------------------------
# Add data point (-0.96642, 0.74939)
#
# Posterior mean:
#     1.6658729416
#     1.1326794529
#     2.4276728495
#
# Posterior varience:
#     0.0387543949,   -0.0055293361,   -0.0539737081
#    -0.0055293361,    0.0484171009,   -0.0130323660
#    -0.0539737081,   -0.0130323660,    0.1474741745
#
# Predictive distribution ~ N(2.83861, 0.37599)
# --------------------------------------------------
# Add data point (-0.39412, 0.99956)
#
# Posterior mean:
#     1.5949708345
#     1.1906989341
#     2.4841558313
#
# Posterior varience:
#     0.0348886134,   -0.0023659515,   -0.0508940978
#    -0.0023659515,    0.0458284905,   -0.0155524236
#    -0.0508940978,   -0.0155524236,    0.1450208543
#
# Predictive distribution ~ N(1.51156, 0.26852)
# --------------------------------------------------
# Add data point (-0.85842, 0.81508)
#
# Posterior mean:
#     1.5977377442
#     1.4427054383
#     2.1555791281
#
# Posterior varience:
#     0.0348875965,   -0.0024585700,   -0.0507733379
#    -0.0024585700,    0.0373929200,   -0.0045537712
#    -0.0507733379,   -0.0045537712,    0.1306803476
#
# Predictive distribution ~ N(1.94771, 0.30751)
# --------------------------------------------------
# Add data point (-0.29084, -0.84078)
#
# Posterior mean:
#     1.3294799430
#     1.5602577733
#     2.4845606205
#
# Posterior varience:
#     0.0310722629,   -0.0007866657,   -0.0460943532
#    -0.0007866657,    0.0366602805,   -0.0066041331
#    -0.0460943532,   -0.0066041331,    0.1249422130
#
# Predictive distribution ~ N(1.08586, 0.25291)
# --------------------------------------------------
# Add data point (-0.58718, 0.66449)
#
# Posterior mean:
#     1.2929659684
#     1.6176610542
#     2.4825493076
#
# Posterior varience:
#     0.0301289724,    0.0006962726,   -0.0461463128
#     0.0006962726,    0.0343289671,   -0.0065224479
#    -0.0461463128,   -0.0065224479,    0.1249393509
#
# Predictive distribution ~ N(1.19905, 0.25581)
# --------------------------------------------------
# Add data point (-0.70269, 1.32813)
#
# Posterior mean:
#     1.2916084454
#     1.6229391476
#     2.4785622077
#
# Posterior varience:
#     0.0299564896,    0.0013668911,   -0.0466529016
#     0.0013668911,    0.0317215804,   -0.0045528141
#    -0.0466529016,   -0.0045528141,    0.1234514790
#
# Predictive distribution ~ N(1.37504, 0.26770)
# --------------------------------------------------
# Add data point (0.83642, 4.25480)
#
# Posterior mean:
#     1.2923103248
#     1.6116667092
#     2.4621850324
#
# Posterior varience:
#     0.0299480705,    0.0015021056,   -0.0464564552
#     0.0015021056,    0.0295499876,   -0.0077078152
#    -0.0464564552,   -0.0077078152,    0.1188677319
#
# Predictive distribution ~ N(4.36291, 0.27431)
# --------------------------------------------------
# Add data point (-0.43000, -2.79171)
#
# Posterior mean:
#     0.9355114152
#     1.8292248281
#     2.8267582721
#
# Posterior varience:
#     0.0280266737,    0.0026736772,   -0.0444931929
#     0.0026736772,    0.0288356219,   -0.0089049143
#    -0.0444931929,   -0.0089049143,    0.1168616918
#
# Predictive distribution ~ N(0.67161, 0.22107)
# --------------------------------------------------
# Add data point (0.32311, 4.12635)
#
# Posterior mean:
#     1.1821794301
#     1.9417589035
#     2.4689465559
#
# Posterior varience:
#     0.0254316957,    0.0014898048,   -0.0407289694
#     0.0014898048,    0.0282955195,   -0.0071876126
#    -0.0407289694,   -0.0071876126,    0.1114013841
#
# Predictive distribution ~ N(2.06735, 0.22396)
# --------------------------------------------------
# Add data point (0.08989, -0.85970)
#
# Posterior mean:
#     0.9284393499
#     1.9017897511
#     2.8759008061
#
# Posterior varience:
#     0.0225683509,    0.0010387705,   -0.0361366703
#     0.0010387705,    0.0282244726,   -0.0064642333
#    -0.0361366703,   -0.0064642333,    0.1040361478
#
# Predictive distribution ~ N(1.12263, 0.21956)
# --------------------------------------------------
# Add data point (-0.04247, 0.79073)
#
# Posterior mean:
#     0.9222178097
#     1.9018372866
#     2.8857832439
#
# Posterior varience:
#     0.0203192660,    0.0010559546,   -0.0325641721
#     0.0010559546,    0.0282243413,   -0.0064915289
#    -0.0325641721,   -0.0064915289,    0.0983615093
#
# Predictive distribution ~ N(0.84665, 0.22204)
# --------------------------------------------------
# Add data point (0.26350, 1.27333)
#
# Posterior mean:
#     0.8938429369
#     1.8893920890
#     2.9282534010
#
# Posterior varience:
#     0.0188343580,    0.0004046751,   -0.0303416325
#     0.0004046751,    0.0279386906,   -0.0055167247
#    -0.0303416325,   -0.0055167247,    0.0950349180
#
# Predictive distribution ~ N(1.59502, 0.22491)
# --------------------------------------------------
# Add data point (-0.03413, 0.23195)
#
# Posterior mean:
#     0.8445955440
#     1.8908479598
#     3.0070133392
#
# Posterior varience:
#     0.0172945930,    0.0004501942,   -0.0278791307
#     0.0004501942,    0.0279373449,   -0.0055895222
#    -0.0278791307,   -0.0055895222,    0.0910967098
#
# Predictive distribution ~ N(0.78356, 0.22764)
# --------------------------------------------------
# Add data point (-0.30700, -0.20159)
#
# Posterior mean:
#     0.7965304595
#     1.9194754445
#     3.0651640407
#
# Posterior varience:
#     0.0163623740,    0.0010054223,   -0.0267513019
#     0.0010054223,    0.0276066520,   -0.0062612552
#    -0.0267513019,   -0.0062612552,    0.0897322258
#
# Predictive distribution ~ N(0.49614, 0.22537)
# --------------------------------------------------
# Add data point (0.43325, 0.96581)
#
# Posterior mean:
#     0.7333610799
#     1.8562303261
#     3.1328614445
#
# Posterior varience:
#     0.0157613133,    0.0004036409,   -0.0261071567
#     0.0004036409,    0.0270041491,   -0.0056163377
#    -0.0261071567,   -0.0056163377,    0.0890419079
#
# Predictive distribution ~ N(2.12563, 0.22983)
# --------------------------------------------------
# Add data point (0.75819, 4.43030)
#
# Posterior mean:
#     0.7355172155
#     1.8921484240
#     3.1752338108
#
# Posterior varience:
#     0.0157566381,    0.0003257585,   -0.0261990342
#     0.0003257585,    0.0257067409,   -0.0071468824
#    -0.0261990342,   -0.0071468824,    0.0872363334
#
# Predictive distribution ~ N(3.99543, 0.23719)
# --------------------------------------------------
# Add data point (0.29029, 2.67824)
#
# Posterior mean:
#     0.8014486478
#     1.9268736046
#     3.0741266382
#
# Posterior varience:
#     0.0149576841,   -0.0000950396,   -0.0249738222
#    -0.0000950396,    0.0254851123,   -0.0065015800
#    -0.0249738222,   -0.0065015800,    0.0853574463
#
# Predictive distribution ~ N(1.61984, 0.23215)
# --------------------------------------------------
# Add data point (0.24532, 0.25828)
#
# Posterior mean:
#     0.7328114157
#     1.8974090606
#     3.1836473003
#
# Posterior varience:
#     0.0141900137,   -0.0004245846,   -0.0237488927
#    -0.0004245846,    0.0253436454,   -0.0059757432
#    -0.0237488927,   -0.0059757432,    0.0834028936
#
# Predictive distribution ~ N(1.38990, 0.23422)
# --------------------------------------------------
# Add data point (-0.49895, -0.49517)
#
# Posterior mean:
#     0.6941684713
#     1.9636731145
#     3.1836644927
#
# Posterior varience:
#     0.0138845156,    0.0000992766,   -0.0237487568
#     0.0000992766,    0.0244453399,   -0.0059759762
#    -0.0237487568,   -0.0059759762,    0.0834028936
#
# Predictive distribution ~ N(0.50697, 0.23486)
# --------------------------------------------------
# Add data point (0.86191, 5.19494)
#
# Posterior mean:
#     0.6875959416
#     1.9936117849
#     3.2428274811
#
# Posterior varience:
#     0.0138300438,    0.0003474023,   -0.0232584258
#     0.0003474023,    0.0233150973,   -0.0082094933
#    -0.0232584258,   -0.0082094933,    0.0789891524
#
# Predictive distribution ~ N(4.81498, 0.24259)
# --------------------------------------------------
# Add data point (-0.15808, 0.66180)
#
# Posterior mean:
#     0.6995862486
#     1.9903915683
#     3.2246640276
#
# Posterior varience:
#     0.0130706552,    0.0005513500,   -0.0221080700
#     0.0005513500,    0.0232603234,   -0.0085184424
#    -0.0221080700,   -0.0085184424,    0.0772465418
#
# Predictive distribution ~ N(0.46552, 0.22847)
# --------------------------------------------------
# Add data point (0.40431, 1.11064)
#
# Posterior mean:
#     0.6611222774
#     1.9563635102
#     3.2760235355
#
# Posterior varience:
#     0.0126663220,    0.0001936472,   -0.0215681790
#     0.0001936472,    0.0229438731,   -0.0080408151
#    -0.0215681790,   -0.0080408151,    0.0765256454
#
# Predictive distribution ~ N(1.98763, 0.23120)
# --------------------------------------------------
# Add data point (0.85998, 5.98574)
#
# Posterior mean:
#     0.6450930197
#     2.0282206831
#     3.4205393791
#
# Posterior varience:
#     0.0126253324,    0.0003773984,   -0.0211986270
#     0.0003773984,    0.0221201392,   -0.0096974708
#    -0.0211986270,   -0.0096974708,    0.0731938556
#
# Predictive distribution ~ N(4.91901, 0.23348)
# --------------------------------------------------
# Add data point (0.16448, 0.62696)
#
# Posterior mean:
#     0.6209390667
#     2.0207367762
#     3.4620394779
#
# Posterior varience:
#     0.0119667378,    0.0001733381,   -0.0200670630
#     0.0001733381,    0.0220569128,   -0.0093468649
#    -0.0200670630,   -0.0093468649,    0.0712496597
#
# Predictive distribution ~ N(1.04698, 0.22215)
# --------------------------------------------------
# Add data point (0.99976, 6.38828)
#
# Posterior mean:
#     0.6116189127
#     2.0359015283
#     3.5112494391
#
# Posterior varience:
#     0.0117093295,    0.0005921652,   -0.0187079599
#     0.0005921652,    0.0213754425,   -0.0115582512
#    -0.0187079599,   -0.0115582512,    0.0640736612
#
# Predictive distribution ~ N(6.15663, 0.23456)
# --------------------------------------------------
# Add data point (0.78343, 6.93674)
#
# Posterior mean:
#     0.6206095557
#     2.1692100417
#     3.6617216640
#
# Posterior varience:
#     0.0117069173,    0.0005563975,   -0.0187483327
#     0.0005563975,    0.0208450981,   -0.0121568785
#    -0.0187483327,   -0.0121568785,    0.0633979596
#
# Predictive distribution ~ N(4.56749, 0.19662)
# --------------------------------------------------
# Add data point (0.45907, 0.42394)
#
# Posterior mean:
#     0.5391425213
#     2.0922931423
#     3.7732601073
#
# Posterior varience:
#     0.0113746425,    0.0002426810,   -0.0182934074
#     0.0002426810,    0.0205489035,   -0.0117273619
#    -0.0182934074,   -0.0117273619,    0.0627751107
#
# Predictive distribution ~ N(2.29485, 0.19272)
# --------------------------------------------------
# Add data point (-0.44952, 1.42104)
#
# Posterior mean:
#     0.5792065213
#     2.0321397402
#     3.7714783456
#
# Posterior varience:
#     0.0110885546,    0.0006722226,   -0.0182806843
#     0.0006722226,    0.0199039756,   -0.0117464648
#    -0.0182806843,   -0.0117464648,    0.0627745448
#
# Predictive distribution ~ N(0.42782, 0.19946)
# --------------------------------------------------
# Add data point (-0.31662, -1.30846)
#
# Posterior mean:
#     0.5034857248
#     2.0891403151
#     3.8407122726
#
# Posterior varience:
#     0.0106664773,    0.0009899511,   -0.0178947656
#     0.0009899511,    0.0196647982,   -0.0120369740
#    -0.0178947656,   -0.0120369740,    0.0624216871
#
# Predictive distribution ~ N(0.22705, 0.19319)
# --------------------------------------------------
# Add data point (0.69713, 1.29165)
#
# Posterior mean:
#     0.4693700367
#     1.9756458175
#     3.7887667825
#
# Posterior varience:
#     0.0106306768,    0.0008708516,   -0.0179492764
#     0.0008708516,    0.0192685836,   -0.0122183182
#    -0.0179492764,   -0.0122183182,    0.0623386874
#
# Predictive distribution ~ N(3.68795, 0.19704)
# --------------------------------------------------
# Add data point (-0.03534, -1.81986)
#
# Posterior mean:
#     0.3464195803
#     1.9736152986
#     3.9914816855
#
# Posterior varience:
#     0.0100459553,    0.0008611950,   -0.0169852152
#     0.0008611950,    0.0192684241,   -0.0122023968
#    -0.0169852152,   -0.0122023968,    0.0607491889
#
# Predictive distribution ~ N(0.28166, 0.19076)
# --------------------------------------------------
# Add data point (0.14158, -1.57243)
#
# Posterior mean:
#     0.2265008008
#     1.9328031680
#     4.2049653369
#
# Posterior varience:
#     0.0095286803,    0.0006851500,   -0.0160643440
#     0.0006851500,    0.0192085105,   -0.0118889953
#    -0.0160643440,   -0.0118889953,    0.0591098213
#
# Predictive distribution ~ N(0.58443, 0.18618)
# --------------------------------------------------
# Add data point (-0.48873, 0.92924)
#
# Posterior mean:
#     0.2444747397
#     1.8940731946
#     4.2179347541
#
# Posterior varience:
#     0.0093789354,    0.0010078180,   -0.0161723951
#     0.0010078180,    0.0185132304,   -0.0116561685
#    -0.0161723951,   -0.0116561685,    0.0590318551
#
# Predictive distribution ~ N(0.32628, 0.19088)
# --------------------------------------------------
# Add data point (0.70754, 4.57805)
#
# Posterior mean:
#     0.2537871604
#     1.9326650797
#     4.2418807340
#
# Posterior varience:
#     0.0093578596,    0.0009204768,   -0.0162265896
#     0.0009204768,    0.0181512771,   -0.0118807578
#    -0.0162265896,   -0.0118807578,    0.0588924991
#
# Predictive distribution ~ N(3.74475, 0.18845)
# --------------------------------------------------
# Add data point (0.14753, -0.03730)
#
# Posterior mean:
#     0.2214622420
#     1.9208544779
#     4.3009308789
#
# Posterior varience:
#     0.0089158918,    0.0007589944,   -0.0154192168
#     0.0007589944,    0.0180922761,   -0.0115857668
#    -0.0154192168,   -0.0115857668,    0.0574176158
#
# Predictive distribution ~ N(0.59844, 0.18858)
# --------------------------------------------------
# Add data point (-0.45325, 1.66476)
#
# Posterior mean:
#     0.2614579598
#     1.8481658007
#     4.3129790100
#
# Posterior varience:
#     0.0087647797,    0.0010336274,   -0.0154647372
#     0.0010336274,    0.0175931550,   -0.0115030376
#    -0.0154647372,   -0.0115030376,    0.0574039035
#
# Predictive distribution ~ N(0.30982, 0.19273)
# --------------------------------------------------
# Add data point (0.86997, 6.90170)
#
# Posterior mean:
#     0.2424945012
#     1.9191047212
#     4.4800232469
#
# Posterior varience:
#     0.0087428949,    0.0011154942,   -0.0152719602
#     0.0011154942,    0.0172869056,   -0.0122241819
#    -0.0152719602,   -0.0122241819,    0.0557057808
#
# Predictive distribution ~ N(5.30277, 0.18851)
# --------------------------------------------------
# Add data point (-0.41029, 4.72506)
#
# Posterior mean:
#     0.3858750286
#     1.7174957354
#     4.4579682688
#
# Posterior varience:
#     0.0085614596,    0.0013706125,   -0.0152440516
#     0.0013706125,    0.0169281809,   -0.0122634245
#    -0.0152440516,   -0.0122634245,    0.0557014879
#
# Predictive distribution ~ N(0.43165, 0.17954)
# --------------------------------------------------
# Add data point (-0.97460, 3.90729)
#
# Posterior mean:
#     0.3566146343
#     1.6094880980
#     4.6581062795
#
# Posterior varience:
#     0.0083405668,    0.0005552406,   -0.0137331685
#     0.0005552406,    0.0139184334,   -0.0066863664
#    -0.0137331685,   -0.0066863664,    0.0453672065
#
# Predictive distribution ~ N(3.21251, 0.21994)
# --------------------------------------------------
# Add data point (0.33753, -0.21599)
#
# Posterior mean:
#     0.2928938217
#     1.5683879543
#     4.7571314170
#
# Posterior varience:
#     0.0080710874,    0.0003814254,   -0.0133143847
#     0.0003814254,    0.0138063220,   -0.0064162494
#    -0.0133143847,   -0.0064162494,    0.0447163968
#
# Predictive distribution ~ N(1.36425, 0.17964)
# --------------------------------------------------
# Add data point (0.06745, 1.29667)
#
# Posterior mean:
#     0.3312851002
#     1.5745196741
#     4.6924293665
#
# Posterior varience:
#     0.0077190279,    0.0003251957,   -0.0127210475
#     0.0003251957,    0.0137973412,   -0.0063214837
#    -0.0127210475,   -0.0063214837,    0.0437164268
#
# Predictive distribution ~ N(0.45884, 0.18308)
# --------------------------------------------------
# Add data point (-0.33181, 0.23843)
#
# Posterior mean:
#     0.3283472280
#     1.5768606637
#     4.6951780130
#
# Posterior varience:
#     0.0075093830,    0.0004922474,   -0.0125249057
#     0.0004922474,    0.0136642291,   -0.0064777757
#    -0.0125249057,   -0.0064777757,    0.0435329182
#
# Predictive distribution ~ N(0.32205, 0.18370)
# --------------------------------------------------
# Add data point (0.22557, 2.95724)
#
# Posterior mean:
#     0.4046155445
#     1.6123003515
#     4.5666167511
#
# Posterior varience:
#     0.0072475778,    0.0003705941,   -0.0120835953
#     0.0003705941,    0.0136077003,   -0.0062727115
#    -0.0120835953,   -0.0062727115,    0.0427890259
#
# Predictive distribution ~ N(1.00065, 0.18599)
# --------------------------------------------------
# Add data point (0.73209, 2.92520)
#
# Posterior mean:
#     0.3985726968
#     1.5719021909
#     4.5303551937
#
# Posterior varience:
#     0.0072418872,    0.0003325503,   -0.0121177436
#     0.0003325503,    0.0133533670,   -0.0065010022
#    -0.0121177436,   -0.0065010022,    0.0425841113
#
# Predictive distribution ~ N(3.97738, 0.19058)
# --------------------------------------------------
# Add data point (-0.47329, -3.05957)
#
# Posterior mean:
#     0.3080727304
#     1.7260518710
#     4.5200426187
#
# Posterior varience:
#     0.0071358275,    0.0005132030,   -0.0121298292
#     0.0005132030,    0.0130456592,   -0.0064804166
#    -0.0121298292,   -0.0064804166,    0.0425827341
#
# Predictive distribution ~ N(0.50365, 0.17971)
# --------------------------------------------------
# Add data point (-0.43905, 2.85072)
#
# Posterior mean:
#     0.3692563379
#     1.6395590021
#     4.5056421862
#
# Posterior varience:
#     0.0070206645,    0.0006760044,   -0.0121027239
#     0.0006760044,    0.0128155132,   -0.0065187342
#    -0.0121027239,   -0.0065187342,    0.0425763545
#
# Predictive distribution ~ N(0.51794, 0.18125)
# --------------------------------------------------
# Add data point (0.89739, 3.62075)
#
# Posterior mean:
#     0.3895602054
#     1.5731914581
#     4.3491383037
#
# Posterior varience:
#     0.0069973849,    0.0007520988,   -0.0119232828
#     0.0007520988,    0.0125667823,   -0.0071052762
#    -0.0119232828,   -0.0071052762,    0.0411932072
#
# Predictive distribution ~ N(5.30374, 0.19137)
# --------------------------------------------------
# Add data point (-0.12145, 1.53516)
#
# Posterior mean:
#     0.4358721049
#     1.5671430973
#     4.2772106536
#
# Posterior varience:
#     0.0067524479,    0.0007840878,   -0.0115428677
#     0.0007840878,    0.0125626045,   -0.0071549586
#    -0.0115428677,   -0.0071549586,    0.0406023793
#
# Predictive distribution ~ N(0.30863, 0.18468)
# --------------------------------------------------
# Add data point (0.11684, 2.53969)
#
# Posterior mean:
#     0.5022834141
#     1.5885390898
#     4.1597670116
#
# Posterior varience:
#     0.0065140053,    0.0007072678,   -0.0111211991
#     0.0007072678,    0.0125378551,   -0.0070191080
#    -0.0111211991,   -0.0070191080,    0.0398566886
#
# Predictive distribution ~ N(0.74467, 0.18726)
# --------------------------------------------------
# Add data point (0.51052, 4.29416)
#
# Posterior mean:
#     0.5427682968
#     1.6422800920
#     4.1158179513
#
# Posterior varience:
#     0.0064291279,    0.0005945987,   -0.0110290590
#     0.0005945987,    0.0123882944,   -0.0068967981
#    -0.0110290590,   -0.0068967981,    0.0397566644
#
# Predictive distribution ~ N(2.45387, 0.18614)
# --------------------------------------------------
# Add data point (-0.06444, 0.26779)
#
# Posterior mean:
#     0.5364938872
#     1.6425098862
#     4.1261215227
#
# Posterior varience:
#     0.0062153586,    0.0006024278,   -0.0106780160
#     0.0006024278,    0.0123880076,   -0.0069096547
#    -0.0106780160,   -0.0069096547,    0.0391801963
#
# Predictive distribution ~ N(0.44778, 0.18812)
# --------------------------------------------------
# Add data point (-0.99548, 4.17629)
#
# Posterior mean:
#     0.5109464192
#     1.5469433468
#     4.3063151030
#
# Posterior varience:
#     0.0061083798,    0.0002022474,   -0.0099234637
#     0.0002022474,    0.0108910350,   -0.0040870679
#    -0.0099234637,   -0.0040870679,    0.0338581240
#
# Predictive distribution ~ N(3.23849, 0.22044)
# --------------------------------------------------
# Add data point (0.36251, 2.25744)
#
# Posterior mean:
#     0.5268494524
#     1.5587240374
#     4.2836368204
#
# Posterior varience:
#     0.0059832301,    0.0001095386,   -0.0097449959
#     0.0001095386,    0.0108223580,   -0.0039548620
#    -0.0097449959,   -0.0039548620,    0.0336036226
#
# Predictive distribution ~ N(1.65483, 0.18996)
# --------------------------------------------------
# Add data point (-0.87603, 2.24216)
#
# Posterior mean:
#     0.5284027279
#     1.5708341802
#     4.2645946038
#
# Posterior varience:
#     0.0059712645,    0.0000162487,   -0.0095983050
#     0.0000162487,    0.0100950208,   -0.0028111833
#    -0.0095983050,   -0.0028111833,    0.0318052807
#
# Predictive distribution ~ N(2.42505, 0.20883)
# --------------------------------------------------
# Add data point (0.42248, 3.00486)
#
# Posterior mean:
#     0.5514765812
#     1.5912811245
#     4.2369536226
#
# Posterior varience:
#     0.0058776880,   -0.0000666743,   -0.0094862064
#    -0.0000666743,    0.0100215385,   -0.0027118470
#    -0.0094862064,   -0.0027118470,    0.0316709939
#
# Predictive distribution ~ N(1.98000, 0.19426)
# --------------------------------------------------
# Add data point (0.36778, -0.50784)
#
# Posterior mean:
#     0.4992126286
#     1.5540877198
#     4.3078543698
#
# Posterior varience:
#     0.0057699852,   -0.0001433205,   -0.0093400979
#    -0.0001433205,    0.0099669935,   -0.0026078695
#    -0.0093400979,   -0.0026078695,    0.0314727846
#
# Predictive distribution ~ N(1.65347, 0.19379)
# --------------------------------------------------
# Add data point (0.03398, 0.65051)
#
# Posterior mean:
#     0.5019521660
#     1.5541792871
#     4.3033828241
#
# Posterior varience:
#     0.0056014175,   -0.0001489548,   -0.0090649573
#    -0.0001489548,    0.0099668052,   -0.0025986731
#    -0.0090649573,   -0.0025986731,    0.0310236927
#
# Predictive distribution ~ N(0.55973, 0.19627)
# --------------------------------------------------
# Add data point (-0.60431, 0.22041)
#
# Posterior mean:
#     0.4910643765
#     1.5867412251
#     4.2858473084
#
# Posterior varience:
#     0.0055730500,   -0.0000641164,   -0.0091106451
#    -0.0000641164,    0.0097130805,   -0.0024620353
#    -0.0091106451,   -0.0024620353,    0.0309501094
#
# Predictive distribution ~ N(1.09732, 0.19953)
# --------------------------------------------------
# Add data point (0.59356, 2.37359)
#
# Posterior mean:
#     0.4844288179
#     1.5729468688
#     4.2848996296
#
# Posterior varience:
#     0.0055459462,   -0.0001204613,   -0.0091145160
#    -0.0001204613,    0.0095959479,   -0.0024700823
#    -0.0091145160,   -0.0024700823,    0.0309495566
#
# Predictive distribution ~ N(2.92769, 0.19934)
# --------------------------------------------------
# Add data point (0.60149, 0.42314)
#
# Posterior mean:
#     0.4567147526
#     1.5123492206
#     4.2772955657
#
# Posterior varience:
#     0.0055223682,   -0.0001720154,   -0.0091209852
#    -0.0001720154,    0.0094832232,   -0.0024842275
#    -0.0091209852,   -0.0024842275,    0.0309477816
#
# Predictive distribution ~ N(2.91387, 0.20067)
# --------------------------------------------------
# Add data point (-0.50928, 2.13867)
#
# Posterior mean:
#     0.4780516946
#     1.4752172975
#     4.2784199520
#
# Posterior varience:
#     0.0054708160,   -0.0000823010,   -0.0091237019
#    -0.0000823010,    0.0093270964,   -0.0024794999
#    -0.0091237019,   -0.0024794999,    0.0309476384
#
# Predictive distribution ~ N(0.83643, 0.20399)
# --------------------------------------------------
# Add data point (-0.44788, 1.87286)
#
# Posterior mean:
#     0.4994327990
#     1.4475588167
#     4.2679250710
#
# Posterior varience:
#     0.0054051439,    0.0000026521,   -0.0090914668
#     0.0000026521,    0.0092172015,   -0.0025211990
#    -0.0090914668,   -0.0025211990,    0.0309318159
#
# Predictive distribution ~ N(0.70724, 0.20578)
# --------------------------------------------------
# Add data point (-0.51799, -0.91901)
#
# Posterior mean:
#     0.4732006348
#     1.4957716793
#     4.2633759699
#
# Posterior varience:
#     0.0053622710,    0.0000814494,   -0.0090989017
#     0.0000814494,    0.0090723777,   -0.0025075342
#    -0.0090989017,   -0.0025075342,    0.0309305266
#
# Predictive distribution ~ N(0.84234, 0.20479)
# --------------------------------------------------
# Add data point (0.81004, 4.93929)
#
# Posterior mean:
#     0.4720050675
#     1.5085305238
#     4.2835898092
#
# Posterior varience:
#     0.0053608528,    0.0000965838,   -0.0090749244
#     0.0000965838,    0.0089108672,   -0.0027634153
#    -0.0090749244,   -0.0027634153,    0.0305251341
#
# Predictive distribution ~ N(4.50469, 0.20671)
# --------------------------------------------------
# Add data point (-0.52198, 1.48733)
#
# Posterior mean:
#     0.4807983894
#     1.4920845109
#     4.2857106144
#
# Posterior varience:
#     0.0053215935,    0.0001700098,   -0.0090843931
#     0.0001700098,    0.0087735396,   -0.0027457061
#    -0.0090843931,   -0.0027457061,    0.0305228504
#
# Predictive distribution ~ N(0.86965, 0.20497)
# --------------------------------------------------
# Add data point (0.56556, 3.32934)
#
# Posterior mean:
#     0.4885501447
#     1.5052108942
#     4.2830126889
#
# Posterior varience:
#     0.0052908731,    0.0001179895,   -0.0090737011
#     0.0001179895,    0.0086854513,   -0.0027276009
#    -0.0090737011,   -0.0027276009,    0.0305191292
#
# Predictive distribution ~ N(2.70979, 0.20531)
# --------------------------------------------------
# Add data point (-0.87532, 1.28839)
#
# Posterior mean:
#     0.4977894089
#     1.5553424124
#     4.1955863244
#
# Posterior varience:
#     0.0052768692,    0.0000420059,   -0.0089411903
#     0.0000420059,    0.0082731703,   -0.0020086076
#    -0.0089411903,   -0.0020086076,    0.0292652478
#
# Predictive distribution ~ N(2.35097, 0.22065)
# --------------------------------------------------
# Add data point (0.36864, 2.40336)
#
# Posterior mean:
#     0.5126187089
#     1.5655946298
#     4.1748381667
#
# Posterior varience:
#     0.0051975274,   -0.0000128469,   -0.0088301805
#    -0.0000128469,    0.0082352478,   -0.0019318611
#    -0.0088301805,   -0.0019318611,    0.0291099304
#
# Predictive distribution ~ N(1.65708, 0.20944)
# --------------------------------------------------
# Add data point (0.05744, -1.30002)
#
# Posterior mean:
#     0.4649586957
#     1.5614092925
#     4.2564143649
#
# Posterior varience:
#     0.0050690059,   -0.0000241333,   -0.0086101995
#    -0.0000241333,    0.0082342567,   -0.0019125431
#    -0.0086101995,   -0.0019125431,    0.0287334048
#
# Predictive distribution ~ N(0.56869, 0.20766)
# --------------------------------------------------
# Add data point (0.48201, 5.89484)
#
# Posterior mean:
#     0.5208334280
#     1.6253914140
#     4.2042059317
#
# Posterior varience:
#     0.0050226965,   -0.0000771621,   -0.0085669288
#    -0.0000771621,    0.0081735335,   -0.0018629939
#    -0.0085669288,   -0.0018629939,    0.0286929734
#
# Predictive distribution ~ N(2.28106, 0.20171)
# --------------------------------------------------
# Add data point (0.76672, 4.28400)
#
# Posterior mean:
#     0.5208173565
#     1.6265187630
#     4.2057266598
#
# Posterior varience:
#     0.0050226708,   -0.0000753609,   -0.0085644991
#    -0.0000753609,    0.0080471881,   -0.0020334264
#    -0.0085644991,   -0.0020334264,    0.0284630699
#
# Predictive distribution ~ N(4.24028, 0.20512)
# --------------------------------------------------
# Add data point (0.60113, 4.03593)
#
# Posterior mean:
#     0.5302833402
#     1.6467687489
#     4.2082326820
#
# Posterior varience:
#     0.0050051591,   -0.0001128227,   -0.0085691351
#    -0.0001128227,    0.0079670484,   -0.0020433440
#    -0.0085691351,   -0.0020433440,    0.0284618425
#
# Predictive distribution ~ N(3.04086, 0.20228)
# --------------------------------------------------
# Add data point (0.95203, 8.98003)
#
# Posterior mean:
#     0.4856869838
#     1.7341273106
#     4.4457833473
#
# Posterior varience:
#     0.0049634519,   -0.0000311237,   -0.0083469742
#    -0.0000311237,    0.0078070104,   -0.0024785289
#    -0.0083469742,   -0.0024785289,    0.0272784617
#
# Predictive distribution ~ N(6.16614, 0.19601)
# --------------------------------------------------
# Add data point (0.96298, 6.27037)
#
# Posterior mean:
#     0.4858023453
#     1.7339140663
#     4.4451848429
#
# Posterior varience:
#     0.0049225442,    0.0000444938,   -0.0081347417
#     0.0000444938,    0.0076672326,   -0.0028708379
#    -0.0081347417,   -0.0028708379,    0.0261773831
#
# Predictive distribution ~ N(6.27764, 0.19131)
# --------------------------------------------------
# Add data point (0.24064, 4.97161)
#
# Posterior mean:
#     0.5799991242
#     1.7702935229
#     4.2908771810
#
# Posterior varience:
#     0.0048122560,    0.0000018997,   -0.0079540741
#     0.0000018997,    0.0076507825,   -0.0028010628
#    -0.0079540741,   -0.0028010628,    0.0258814240
#
# Predictive distribution ~ N(1.25449, 0.18043)
# --------------------------------------------------
# Add data point (-0.25012, 0.18486)
#
# Posterior mean:
#     0.5747421263
#     1.7728365523
#     4.2977428462
#
# Posterior varience:
#     0.0047095341,    0.0000515906,   -0.0078199188
#     0.0000515906,    0.0076267449,   -0.0028659594
#    -0.0078199188,   -0.0028659594,    0.0257062165
#
# Predictive distribution ~ N(0.40019, 0.18108)
# --------------------------------------------------
# Add data point (-0.22717, 1.44180)
#
# Posterior mean:
#     0.5993581614
#     1.7623531160
#     4.2642529381
#
# Posterior varience:
#     0.0046086676,    0.0000945474,   -0.0076826908
#     0.0000945474,    0.0076084505,   -0.0029244018
#    -0.0076826908,   -0.0029244018,    0.0255195190
#
# Predictive distribution ~ N(0.41907, 0.18272)
# --------------------------------------------------
# Add data point (0.46345, -0.49908)
#
# Posterior mean:
#     0.5525700094
#     1.7157166743
#     4.3196802122
#
# Posterior varience:
#     0.0045590502,    0.0000450909,   -0.0076239119
#     0.0000450909,    0.0075591544,   -0.0028658135
#    -0.0076239119,   -0.0028658135,    0.0254498869
#
# Predictive distribution ~ N(2.27555, 0.18160)
# --------------------------------------------------
# Add data point (-0.89134, 0.88770)
#
# Posterior mean:
#     0.5647537037
#     1.7867599580
#     4.1996835607
#
# Posterior varience:
#     0.0045470940,   -0.0000246260,   -0.0075061556
#    -0.0000246260,    0.0071526341,   -0.0021791748
#    -0.0075061556,   -0.0021791748,    0.0242901102
#
# Predictive distribution ~ N(2.30874, 0.19618)
# --------------------------------------------------
# Add data point (0.55558, 3.82607)
#
# Posterior mean:
#     0.5764733093
#     1.8040844485
#     4.1932364262
#
# Posterior varience:
#     0.0045203783,   -0.0000641185,   -0.0074914589
#    -0.0000641185,    0.0070942544,   -0.0021574493
#    -0.0074914589,   -0.0021574493,    0.0242820253
#
# Predictive distribution ~ N(2.87309, 0.18383)
# --------------------------------------------------
# Add data point (-0.09859, 0.99334)
#
# Posterior mean:
#     0.5897294404
#     1.8017494441
#     4.1722751058
#
# Posterior varience:
#     0.0044138009,   -0.0000453453,   -0.0073229328
#    -0.0000453453,    0.0070909477,   -0.0021871344
#    -0.0073229328,   -0.0021871344,    0.0240155426
#
# Predictive distribution ~ N(0.45265, 0.18602)
# --------------------------------------------------
# Add data point (0.49872, 4.11494)
#
# Posterior mean:
#     0.6117350947
#     1.8269851585
#     4.1513762340
#
# Posterior varience:
#     0.0043782101,   -0.0000861602,   -0.0072891321
#    -0.0000861602,    0.0070441418,   -0.0021483723
#    -0.0072891321,   -0.0021483723,    0.0239834419
#
# Predictive distribution ~ N(2.55541, 0.18549)
# --------------------------------------------------
# Add data point (-0.09797, 0.66298)
#
# Posterior mean:
#     0.6161165840
#     1.8261762767
#     4.1444249829
#
# Posterior varience:
#     0.0042788730,   -0.0000678213,   -0.0071315333
#    -0.0000678213,    0.0070407562,   -0.0021774672
#    -0.0071315333,   -0.0021774672,    0.0237334108
#
# Predictive distribution ~ N(0.47698, 0.18748)
# --------------------------------------------------
# Add data point (-0.77310, 1.98833)
#
# Posterior mean:
#     0.6162247078
#     1.8154851291
#     4.1581363286
#
# Posterior varience:
#     0.0042788487,   -0.0000654217,   -0.0071346107
#    -0.0000654217,    0.0068034912,   -0.0018731759
#    -0.0071346107,   -0.0018731759,    0.0233431587
#
# Predictive distribution ~ N(1.69793, 0.19503)
# --------------------------------------------------
# Add data point (0.07784, 3.14331)
#
# Posterior mean:
#     0.6685944439
#     1.8210904078
#     4.0697628188
#
# Posterior varience:
#     0.0041849939,   -0.0000754672,   -0.0069762315
#    -0.0000754672,    0.0068024160,   -0.0018562242
#    -0.0069762315,   -0.0018562242,    0.0230758950
#
# Predictive distribution ~ N(0.83500, 0.19060)
# --------------------------------------------------
# Add data point (-0.45967, 1.23284)
#
# Posterior mean:
#     0.6763307509
#     1.8109620667
#     4.0662488908
#
# Posterior varience:
#     0.0041457617,   -0.0000241046,   -0.0069584117
#    -0.0000241046,    0.0067351723,   -0.0018795537
#    -0.0069584117,   -0.0018795537,    0.0230678011
#
# Predictive distribution ~ N(0.70307, 0.19206)
# --------------------------------------------------
# Add data point (-0.58986, -0.30682)
#
# Posterior mean:
#     0.6643585250
#     1.8429825517
#     4.0512653996
#
# Posterior varience:
#     0.0041301053,    0.0000177695,   -0.0069780061
#     0.0000177695,    0.0066231771,   -0.0018271473
#    -0.0069780061,   -0.0018271473,    0.0230432783
#
# Predictive distribution ~ N(0.98683, 0.19300)
# --------------------------------------------------
# Add data point (-0.45896, 0.88685)
#
# Posterior mean:
#     0.6673099221
#     1.8391910779
#     4.0498349223
#
# Posterior varience:
#     0.0040936925,    0.0000645467,   -0.0069603576
#     0.0000645467,    0.0065630854,   -0.0018498192
#    -0.0069603576,   -0.0018498192,    0.0230347245
#
# Predictive distribution ~ N(0.67628, 0.19308)
# --------------------------------------------------
# Add data point (0.90746, 5.73954)
#
# Posterior mean:
#     0.6667641892
#     1.8407448414
#     4.0534039816
#
# Posterior varience:
#     0.0040810634,    0.0001005032,   -0.0068777641
#     0.0001005032,    0.0064607133,   -0.0020849722
#    -0.0068777641,   -0.0020849722,    0.0224945681
#
# Predictive distribution ~ N(5.67509, 0.19693)
# --------------------------------------------------
# Add data point (-0.09882, 1.18226)
#
# Posterior mean:
#     0.6804826036
#     1.8388319737
#     4.0312979044
#
# Posterior varience:
#     0.0039975630,    0.0001121463,   -0.0067432102
#     0.0001121463,    0.0064590898,   -0.0021037342
#    -0.0067432102,   -0.0021037342,    0.0222777457
#
# Predictive distribution ~ N(0.53814, 0.19191)
# --------------------------------------------------
# Add data point (0.42138, 1.77260)
#
# Posterior mean:
#     0.6746007492
#     1.8337499128
#     4.0388871528
#
# Posterior varience:
#     0.0039555349,    0.0000758331,   -0.0066889822
#     0.0000758331,    0.0064277143,   -0.0020568799
#    -0.0066889822,   -0.0020568799,    0.0222077763
#
# Predictive distribution ~ N(2.16443, 0.19287)
# --------------------------------------------------
# Add data point (0.42314, 3.36695)
#
# Posterior mean:
#     0.6917574786
#     1.8486766477
#     4.0168530684
#
# Posterior varience:
#     0.0039154211,    0.0000409332,   -0.0066374647
#     0.0000409332,    0.0063973506,   -0.0020120586
#    -0.0066374647,   -0.0020120586,    0.0221416134
#
# Predictive distribution ~ N(2.19319, 0.19400)
# --------------------------------------------------
# Add data point (0.63678, 6.02786)
#
# Posterior mean:
#     0.7082812125
#     1.8922812263
#     4.0308581858
#
# Posterior varience:
#     0.0039072572,    0.0000193894,   -0.0066443843
#     0.0000193894,    0.0063404985,   -0.0020303186
#    -0.0066443843,   -0.0020303186,    0.0221357486
#
# Predictive distribution ~ N(3.54773, 0.19133)
# --------------------------------------------------
# Add data point (-0.78905, 2.34006)
#
# Posterior mean:
#     0.7075257424
#     1.8730048956
#     4.0578224690
#
# Posterior varience:
#     0.0039069566,    0.0000117180,   -0.0066336533
#     0.0000117180,    0.0061447576,   -0.0017565105
#    -0.0066336533,   -0.0017565105,    0.0217527380
#
# Predictive distribution ~ N(1.75604, 0.19890)
# --------------------------------------------------
# Add data point (0.23214, 0.73472)
#
# Posterior mean:
#     0.6960523346
#     1.8686653574
#     4.0767795608
#
# Posterior varience:
#     0.0038418820,   -0.0000128949,   -0.0065261330
#    -0.0000128949,    0.0061354483,   -0.0017158436
#    -0.0065261330,   -0.0017158436,    0.0215750861
#
# Predictive distribution ~ N(1.34955, 0.19384)
# --------------------------------------------------
# Add data point (0.28668, 3.71603)
#
# Posterior mean:
#     0.7325298670
#     1.8863970568
#     4.0188361118
#
# Posterior varience:
#     0.0037858417,   -0.0000401360,   -0.0064371147
#    -0.0000401360,    0.0061222064,   -0.0016725718
#    -0.0064371147,   -0.0016725718,    0.0214336832
#
# Predictive distribution ~ N(1.60362, 0.19448)
# --------------------------------------------------
# Add data point (-0.61151, 3.09266)
#
# Posterior mean:
#     0.7468065536
#     1.8415357564
#     4.0452961289
#
# Posterior varience:
#     0.0037758789,   -0.0000088302,   -0.0064555794
#    -0.0000088302,    0.0060238350,   -0.0016145506
#    -0.0064555794,   -0.0016145506,    0.0213994612
#
# Predictive distribution ~ N(1.13341, 0.19752)
# --------------------------------------------------
# Add data point (0.96631, 3.88941)
#
# Posterior mean:
#     0.7732581945
#     1.7911688674
#     3.9052785718
#
# Posterior varience:
#     0.0037511104,    0.0000383319,   -0.0063244709
#     0.0000383319,    0.0059340330,   -0.0018641959
#    -0.0063244709,   -0.0018641959,    0.0207054592
#
# Predictive distribution ~ N(6.15068, 0.20550)
# --------------------------------------------------
# Add data point (-0.22144, -0.07852)
#
# Posterior mean:
#     0.7619813859
#     1.7956601499
#     3.9213646997
#
# Posterior varience:
#     0.0036912509,    0.0000621725,   -0.0062390827
#     0.0000621725,    0.0059245379,   -0.0018982040
#    -0.0062390827,   -0.0018982040,    0.0205836547
#
# Predictive distribution ~ N(0.55664, 0.19677)
# --------------------------------------------------
# Add data point (-0.82548, 2.09915)
#
# Posterior mean:
#     0.7615434602
#     1.7912756216
#     3.9280639567
#
# Posterior varience:
#     0.0036894342,    0.0000439830,   -0.0062112903
#     0.0000439830,    0.0057424235,   -0.0016199458
#    -0.0062112903,   -0.0016199458,    0.0201584953
#
# Predictive distribution ~ N(1.95951, 0.20522)
# --------------------------------------------------
# Add data point (-0.30119, 2.38479)
#
# Posterior mean:
#     0.7896718928
#     1.7747158685
#     3.8928691441
#
# Posterior varience:
#     0.0036409649,    0.0000725178,   -0.0061506446
#     0.0000725178,    0.0057256245,   -0.0016556490
#    -0.0061506446,   -0.0016556490,    0.0200826144
#
# Predictive distribution ~ N(0.60829, 0.19985)
# --------------------------------------------------
# Add data point (-0.20153, 0.31110)
#
# Posterior mean:
#     0.7849747402
#     1.7763136882
#     3.8998265873
#
# Posterior varience:
#     0.0035841217,    0.0000918540,   -0.0060664483
#     0.0000918540,    0.0057190470,   -0.0016842899
#    -0.0060664483,   -0.0016842899,    0.0199579024
#
# Predictive distribution ~ N(0.58538, 0.20051)
# --------------------------------------------------
# Add data point (0.12653, -2.84900)
#
# Posterior mean:
#     0.7145068356
#     1.7604311208
#     4.0198713530
#
# Posterior varience:
#     0.0035212477,    0.0000776830,   -0.0059593400
#     0.0000776830,    0.0057158530,   -0.0016601491
#    -0.0059593400,   -0.0016601491,    0.0197754394
#
# Predictive distribution ~ N(1.00162, 0.19462)
# --------------------------------------------------
# Add data point (0.65912, 4.89719)
#
# Posterior mean:
#     0.7209715862
#     1.7809662684
#     4.0299798662
#
# Posterior varience:
#     0.0035162649,    0.0000618551,   -0.0059671314
#     0.0000618551,    0.0056655761,   -0.0016848981
#    -0.0059671314,   -0.0016848981,    0.0197632566
#
# Predictive distribution ~ N(3.64565, 0.19403)
# --------------------------------------------------
# Add data point (0.90234, 7.37113)
#
# Posterior mean:
#     0.7092419431
#     1.8156345435
#     4.1084302457
#
# Posterior varience:
#     0.0035077002,    0.0000871689,   -0.0059098491
#     0.0000871689,    0.0055907583,   -0.0018542023
#    -0.0059098491,   -0.0018542023,    0.0193801403
#
# Predictive distribution ~ N(5.69271, 0.19280)
# --------------------------------------------------
# Add data point (0.38400, 4.01684)
#
# Posterior mean:
#     0.7377878841
#     1.8365981671
#     4.0681822910
#
# Posterior varience:
#     0.0034696824,    0.0000592493,   -0.0058562464
#     0.0000592493,    0.0055702546,   -0.0018148375
#    -0.0058562464,   -0.0018148375,    0.0193045639
#
# Predictive distribution ~ N(2.04292, 0.18743)
# --------------------------------------------------
# Add data point (-0.84510, -1.16789)
#
# Posterior mean:
#     0.7505936743
#     1.9363840456
#     3.9093023664
#
# Posterior varience:
#     0.0034666849,    0.0000358922,   -0.0058190571
#     0.0000358922,    0.0053882505,   -0.0015250490
#    -0.0058190571,   -0.0015250490,    0.0188431602
#
# Predictive distribution ~ N(1.90614, 0.19352)
# --------------------------------------------------
# Add data point (0.95904, 1.52923)
#
# Posterior mean:
#     0.7948448291
#     1.8455218637
#     3.6690553762
#
# Posterior varience:
#     0.0034491605,    0.0000718756,   -0.0057239141
#     0.0000718756,    0.0053143647,   -0.0017204090
#    -0.0057239141,   -0.0017204090,    0.0183266126
#
# Predictive distribution ~ N(5.93942, 0.19489)
# --------------------------------------------------
# Add data point (0.27455, 0.26757)
#
# Posterior mean:
#     0.7736789007
#     1.8357573730
#     3.7026067787
#
# Posterior varience:
#     0.0034001043,    0.0000492445,   -0.0056461520
#     0.0000492445,    0.0053039243,   -0.0016845350
#    -0.0056461520,   -0.0016845350,    0.0182033473
#
# Predictive distribution ~ N(1.55679, 0.18802)
# --------------------------------------------------
# Add data point (0.72766, 7.85679)
#
# ...
#     0.0010263178,    0.0000284423,   -0.0017414262
#     0.0000284423,    0.0014914967,   -0.0003358524
#    -0.0017414262,   -0.0003358524,    0.0054799036
#
# Predictive distribution ~ N(1.21989, 0.17844)
# --------------------------------------------------
# Add data point (-0.57871, 0.32053)
#
# Posterior mean:
#     0.9339526452
#     2.1037931299
#     3.3758776197
#
# Posterior varience:
#     0.0010252947,    0.0000307137,   -0.0017421173
#     0.0000307137,    0.0014864541,   -0.0003343181
#    -0.0017421173,   -0.0003343181,    0.0054794368
#
# Predictive distribution ~ N(0.84707, 0.17791)
# --------------------------------------------------
# Add data point (-0.41255, 0.79636)
#
# Posterior mean:
#     0.9345792040
#     2.1032336714
#     3.3752900108
#
# Posterior varience:
#     0.0010224140,    0.0000332859,   -0.0017394157
#     0.0000332859,    0.0014841573,   -0.0003367304
#    -0.0017394157,   -0.0003367304,    0.0054769031
#
# Predictive distribution ~ N(0.64136, 0.17802)
# --------------------------------------------------
# Add data point (-0.03438, -1.16145)
#
# Posterior mean:
#     0.9229531391
#     2.1034405675
#     3.3949254453
#
# Posterior varience:
#     0.0010165702,    0.0000333899,   -0.0017295461
#     0.0000333899,    0.0014841555,   -0.0003369061
#    -0.0017295461,   -0.0003369061,    0.0054602342
#
# Predictive distribution ~ N(0.85465, 0.17776)
# --------------------------------------------------
# Add data point (-0.09993, 3.37666)
#
# Posterior mean:
#     0.9376637646
#     2.1016933929
#     3.3706822571
#
# Posterior varience:
#     0.0010109994,    0.0000340515,   -0.0017203654
#     0.0000340515,    0.0014840769,   -0.0003379965
#    -0.0017203654,   -0.0003379965,    0.0054451044
#
# Predictive distribution ~ N(0.76130, 0.17806)
# --------------------------------------------------
# Add data point (0.95125, 7.59339)
#
# Posterior mean:
#     0.9330397925
#     2.1119617526
#     3.3966722613
#
# Posterior varience:
#     0.0010095219,    0.0000373327,   -0.0017120604
#     0.0000373327,    0.0014767904,   -0.0003564390
#    -0.0017120604,   -0.0003564390,    0.0053984248
#
# Predictive distribution ~ N(6.01561, 0.17828)
# --------------------------------------------------
# Add data point (0.50220, 3.74215)
#
# Posterior mean:
#     0.9360586488
#     2.1154492980
#     3.3939921513
#
# Posterior varience:
#     0.0010075028,    0.0000350001,   -0.0017102679
#     0.0000350001,    0.0014740957,   -0.0003543682
#    -0.0017102679,   -0.0003543682,    0.0053968334
#
# Predictive distribution ~ N(2.85443, 0.17621)
# --------------------------------------------------
# Add data point (-0.62084, 1.33234)
#
# Posterior mean:
#     0.9367993938
#     2.1131429401
#     3.3953302690
#
# Posterior varience:
#     0.0010069002,    0.0000368762,   -0.0017113564
#     0.0000368762,    0.0014682543,   -0.0003509791
#    -0.0017113564,   -0.0003509791,    0.0053948671
#
# Predictive distribution ~ N(0.93358, 0.17697)
# --------------------------------------------------
# Add data point (0.09991, 4.81230)
#
# Posterior mean:
#     0.9572148008
#     2.1168430690
#     3.3605497225
#
# Posterior varience:
#     0.0010013134,    0.0000358637,   -0.0017018385
#     0.0000358637,    0.0014680707,   -0.0003492540
#    -0.0017018385,   -0.0003492540,    0.0053786520
#
# Predictive distribution ~ N(1.20225, 0.17667)
# --------------------------------------------------
# Add data point (0.05230, 0.53381)
#
# Posterior mean:
#     0.9541484039
#     2.1165000774
#     3.3657868094
#
# Posterior varience:
#     0.0009956778,    0.0000352333,   -0.0016922134
#     0.0000352333,    0.0014680002,   -0.0003481774
#    -0.0016922134,   -0.0003481774,    0.0053622134
#
# Predictive distribution ~ N(1.07405, 0.17692)
# --------------------------------------------------
# Add data point (-0.57041, 1.01381)
#
# Posterior mean:
#     0.9545602856
#     2.1156129231
#     3.3660301125
#
# Posterior varience:
#     0.0009946590,    0.0000374276,   -0.0016928152
#     0.0000374276,    0.0014632739,   -0.0003468812
#    -0.0016928152,   -0.0003468812,    0.0053618579
#
# Predictive distribution ~ N(0.84298, 0.17729)
# --------------------------------------------------
# Add data point (-0.36937, 0.05190)
#
# Posterior mean:
#     0.9521040778
#     2.1174156999
#     3.3687590829
#
# Posterior varience:
#     0.0009914859,    0.0000397566,   -0.0016892897
#     0.0000397566,    0.0014615645,   -0.0003494688
#    -0.0016892897,   -0.0003494688,    0.0053579408
#
# Predictive distribution ~ N(0.62961, 0.17721)
# --------------------------------------------------
# Add data point (-0.80473, 4.55701)
#
# Posterior mean:
#     0.9497500257
#     2.0935616160
#     3.4048486580
#
# Posterior varience:
#     0.0009913847,    0.0000387308,   -0.0016877378
#     0.0000387308,    0.0014511699,   -0.0003337426
#    -0.0016877378,   -0.0003337426,    0.0053341482
#
# Predictive distribution ~ N(1.46995, 0.17862)
# --------------------------------------------------
# Add data point (-0.44142, 0.55088)
#
# Posterior mean:
#     0.9492474677
#     2.0940808598
#     3.4052388101
#
# Posterior varience:
#     0.0009890369,    0.0000411565,   -0.0016859152
#     0.0000411565,    0.0014486637,   -0.0003356257
#    -0.0016859152,   -0.0003356257,    0.0053327332
#
# Predictive distribution ~ N(0.68839, 0.17744)
# --------------------------------------------------
# Add data point (-0.55974, 1.03088)
#
# Posterior mean:
#     0.9497073011
#     2.0931619433
#     3.4054202340
#
# Posterior varience:
#     0.0009879598,    0.0000433091,   -0.0016863402
#     0.0000433091,    0.0014443620,   -0.0003347764
#    -0.0016863402,   -0.0003347764,    0.0053325656
#
# Predictive distribution ~ N(0.84503, 0.17792)
# --------------------------------------------------
# Add data point (0.66117, 2.59701)
#
# Posterior mean:
#     0.9477881551
#     2.0873107968
#     3.4025123098
#
# Posterior varience:
#     0.0009875221,    0.0000419747,   -0.0016870033
#     0.0000419747,    0.0014402938,   -0.0003367983
#    -0.0016870033,   -0.0003367983,    0.0053315607
#
# Predictive distribution ~ N(3.81522, 0.17839)
# --------------------------------------------------
# Add data point (-0.77811, -0.26258)
#
# Posterior mean:
#     0.9483987115
#     2.0990816784
#     3.3859656534
#
# Posterior varience:
#     0.0009874974,    0.0000414990,   -0.0016863346
#     0.0000414990,    0.0014311228,   -0.0003239065
#    -0.0016863346,   -0.0003239065,    0.0053134383
#
# Predictive distribution ~ N(1.36512, 0.17937)
# --------------------------------------------------
# Add data point (0.35547, 4.10451)
#
# Posterior mean:
#     0.9571701877
#     2.1047424505
#     3.3734050856
#
# Posterior varience:
#     0.0009840051,    0.0000392452,   -0.0016813337
#     0.0000392452,    0.0014296683,   -0.0003206790
#    -0.0016813337,   -0.0003206790,    0.0053062770
#
# Predictive distribution ~ N(2.13162, 0.17832)
# --------------------------------------------------
# Add data point (0.90891, 7.14658)
#
# Posterior mean:
#     0.9540901097
#     2.1136979828
#     3.3935118585
#
# Posterior varience:
#     0.0009832415,    0.0000414655,   -0.0016763487
#     0.0000414655,    0.0014232126,   -0.0003351731
#    -0.0016763487,   -0.0003351731,    0.0052737353
#
# Predictive distribution ~ N(5.67868, 0.17856)
# --------------------------------------------------
# Add data point (-0.23628, 1.37350)
#
# Posterior mean:
#     0.9577102968
#     2.1124079998
#     3.3881517338
#
# Posterior varience:
#     0.0009788744,    0.0000430216,   -0.0016698828
#     0.0000430216,    0.0014226582,   -0.0003374771
#    -0.0016698828,   -0.0003374771,    0.0052641617
#
# Predictive distribution ~ N(0.64775, 0.17727)
# --------------------------------------------------
# Add data point (-0.45081, 1.33456)
#
# Posterior mean:
#     0.9599468801
#     2.1100025994
#     3.3865362458
#
# Posterior varience:
#     0.0009767093,    0.0000453501,   -0.0016683189
#     0.0000453501,    0.0014201538,   -0.0003391590
#    -0.0016683189,   -0.0003391590,    0.0052630321
#
# Predictive distribution ~ N(0.69698, 0.17760)
# --------------------------------------------------
# Add data point (0.97238, 7.33794)
#
# Posterior mean:
#     0.9564410028
#     2.1169662133
#     3.4052943959
#
# Posterior varience:
#     0.0009749735,    0.0000487979,   -0.0016590317
#     0.0000487979,    0.0014133058,   -0.0003576060
#    -0.0016590317,   -0.0003576060,    0.0052133409
#
# Predictive distribution ~ N(6.23470, 0.17843)
# --------------------------------------------------
# Add data point (0.55455, 4.20002)
#
# Posterior mean:
#     0.9592965855
#     2.1211615186
#     3.4038191981
#
# Posterior varience:
#     0.0009735998,    0.0000467796,   -0.0016583220
#     0.0000467796,    0.0014103406,   -0.0003565634
#    -0.0016583220,   -0.0003565634,    0.0052129742
#
# Predictive distribution ~ N(3.18238, 0.17608)
# --------------------------------------------------
# Add data point (0.83331, 7.16042)
#
# Posterior mean:
#     0.9576591203
#     2.1326429083
#     3.4234312574
#
# Posterior varience:
#     0.0009734898,    0.0000475505,   -0.0016570052
#     0.0000475505,    0.0014049356,   -0.0003657961
#    -0.0016570052,   -0.0003657961,    0.0051972033
#
# Predictive distribution ~ N(5.11208, 0.17565)
# --------------------------------------------------
# Add data point (-0.23001, 1.47746)
#
# Posterior mean:
#     0.9618021951
#     2.1312461839
#     3.4172849164
#
# Posterior varience:
#     0.0009691185,    0.0000490241,   -0.0016505203
#     0.0000490241,    0.0014044388,   -0.0003679823
#    -0.0016505203,   -0.0003679823,    0.0051875828
#
# Predictive distribution ~ N(0.65239, 0.17510)
# --------------------------------------------------
# Add data point (-0.10795, -0.38324)
#
# Posterior mean:
#     0.9555730357
#     2.1319509513
#     3.4275087436
#
# Posterior varience:
#     0.0009640233,    0.0000496006,   -0.0016421576
#     0.0000496006,    0.0014043736,   -0.0003689284
#    -0.0016421576,   -0.0003689284,    0.0051738571
#
# Predictive distribution ~ N(0.76537, 0.17511)
# --------------------------------------------------
# Add data point (0.11568, -2.21463)
#
# Posterior mean:
#     0.9367282405
#     2.1278326377
#     3.4596316264
#
# Posterior varience:
#     0.0009588652,    0.0000484734,   -0.0016333652
#     0.0000484734,    0.0014041272,   -0.0003670069
#    -0.0016333652,   -0.0003670069,    0.0051588695
#
# Predictive distribution ~ N(1.22919, 0.17415)
# --------------------------------------------------
# Add data point (-0.88786, 2.05348)
#
# Posterior mean:
#     0.9361419249
#     2.1254864906
#     3.4639834965
#
# Posterior varience:
#     0.0009580834,    0.0000453449,   -0.0016275621
#     0.0000453449,    0.0013916084,   -0.0003437858
#    -0.0016275621,   -0.0003437858,    0.0051157967
#
# Predictive distribution ~ N(1.77963, 0.17669)
# --------------------------------------------------
# Add data point (0.52698, 4.97377)
#
# Posterior mean:
#     0.9420902432
#     2.1331544112
#     3.4596282488
#
# Posterior varience:
#     0.0009564713,    0.0000432667,   -0.0016263817
#     0.0000432667,    0.0013889295,   -0.0003422643
#    -0.0016263817,   -0.0003422643,    0.0051149325
#
# Predictive distribution ~ N(3.02696, 0.17424)
# --------------------------------------------------
# Add data point (0.74650, 6.04366)
#
# Posterior mean:
#     0.9428392760
#     2.1412331612
#     3.4684253159
#
# Posterior varience:
#     0.0009564322,    0.0000428454,   -0.0016268405
#     0.0000428454,    0.0013843857,   -0.0003472120
#    -0.0016268405,   -0.0003472120,    0.0051095448
#
# Predictive distribution ~ N(4.47406, 0.17407)
# --------------------------------------------------
# Add data point (0.38491, 1.70139)
#
# Posterior mean:
#     0.9404013822
#     2.1394868607
#     3.4717678127
#
# Posterior varience:
#     0.0009533533,    0.0000406399,   -0.0016226190
#     0.0000406399,    0.0013828059,   -0.0003441881
#    -0.0016226190,   -0.0003441881,    0.0051037569
#
# Predictive distribution ~ N(2.27828, 0.17397)
# --------------------------------------------------
# Add data point (0.82033, 5.83830)
#
# Posterior mean:
#     0.9399145604
#     2.1438510503
#     3.4788437263
#
# Posterior varience:
#     0.0009532897,    0.0000412093,   -0.0016216957
#     0.0000412093,    0.0013777012,   -0.0003524647
#    -0.0016216957,   -0.0003524647,    0.0050903376
#
# Predictive distribution ~ N(5.03963, 0.17432)
# --------------------------------------------------
# Add data point (0.46398, 1.73427)
#
# Posterior mean:
#     0.9365101143
#     2.1405488847
#     3.4826091471
#
# Posterior varience:
#     0.0009510544,    0.0000390412,   -0.0016192234
#     0.0000390412,    0.0013755982,   -0.0003500667
#    -0.0016192234,   -0.0003500667,    0.0050876031
#
# Predictive distribution ~ N(2.67944, 0.17379)
# --------------------------------------------------
# Add data point (-0.61049, -0.03730)
#
# Posterior mean:
#     0.9347165327
#     2.1457079284
#     3.4798910820
#
# Posterior varience:
#     0.0009504527,    0.0000407720,   -0.0016201353
#     0.0000407720,    0.0013706197,   -0.0003474437
#    -0.0016201353,   -0.0003474437,    0.0050862212
#
# Predictive distribution ~ N(0.92173, 0.17417)
# --------------------------------------------------
# Add data point (0.94452, 4.90705)
#
# Posterior mean:
#     0.9377248244
#     2.1389491333
#     3.4628243922
#
# Posterior varience:
#     0.0009492679,    0.0000434339,   -0.0016134137
#     0.0000434339,    0.0013646391,   -0.0003625454
#    -0.0016134137,   -0.0003625454,    0.0050480880
#
# Predictive distribution ~ N(6.04727, 0.17576)
# --------------------------------------------------
# Add data point (0.27045, -0.29021)
#
# Posterior mean:
#     0.9277352908
#     2.1343753221
#     3.4787297548
#
# Posterior varience:
#     0.0009451793,    0.0000415619,   -0.0016069038
#     0.0000415619,    0.0013637820,   -0.0003595647
#    -0.0016069038,   -0.0003595647,    0.0050377229
#
# Predictive distribution ~ N(1.75941, 0.17381)
# --------------------------------------------------
# Add data point (-0.02237, 0.78900)
#
# Posterior mean:
#     0.9272330657
#     2.1343695362
#     3.4795795348
#
# Posterior varience:
#     0.0009400692,    0.0000415030,   -0.0015982573
#     0.0000415030,    0.0013637813,   -0.0003594651
#    -0.0015982573,   -0.0003594651,    0.0050230929
#
# Predictive distribution ~ N(0.88122, 0.17418)
# --------------------------------------------------
# Add data point (0.86951, 3.53060)
#
# Posterior mean:
#     0.9297241823
#     2.1241182921
#     3.4593368174
#
# Posterior varience:
#     0.0009397620,    0.0000427670,   -0.0015957614
#     0.0000427670,    0.0013585798,   -0.0003697363
#    -0.0015957614,   -0.0003697363,    0.0050028107
#
# Predictive distribution ~ N(5.39210, 0.17552)
# --------------------------------------------------
# Add data point (0.67734, 3.14162)
#
# Posterior mean:
#     0.9286226320
#     2.1204246368
#     3.4572460930
#
# Posterior varience:
#     0.0009394418,    0.0000416934,   -0.0015963691
#     0.0000416934,    0.0013549798,   -0.0003717741
#    -0.0015963691,   -0.0003717741,    0.0050016573
#
# Predictive distribution ~ N(3.95105, 0.17483)
# --------------------------------------------------
# Add data point (-0.23366, -1.51971)
#
# Posterior mean:
#     0.9182613441
#     2.1240550259
#     3.4724511868
#
# Posterior varience:
#     0.0009353656,    0.0000431216,   -0.0015903872
#     0.0000431216,    0.0013544793,   -0.0003738700
#    -0.0015903872,   -0.0003738700,    0.0049928790
#
# Predictive distribution ~ N(0.61154, 0.17415)
# --------------------------------------------------
# Add data point (0.57818, 1.90617)
#
# Posterior mean:
#     0.9148198224
#     2.1184245529
#     3.4735548613
#
# Posterior varience:
#     0.0009343126,    0.0000413990,   -0.0015900495
#     0.0000413990,    0.0013516610,   -0.0003733175
#    -0.0015900495,   -0.0003733175,    0.0049927707
#
# Predictive distribution ~ N(3.30084, 0.17449)
# --------------------------------------------------
# Add data point (-0.22237, 2.30559)
#
# Posterior mean:
#     0.9229968476
#     2.1157426881
#     3.4613817487
#
# Posterior varience:
#     0.0009302171,    0.0000427422,   -0.0015839526
#     0.0000427422,    0.0013512205,   -0.0003753172
#    -0.0015839526,   -0.0003753172,    0.0049836942
#
# Predictive distribution ~ N(0.62368, 0.17495)
# --------------------------------------------------
# Add data point (0.85967, 5.30580)
#
# Posterior mean:
#     0.9229900612
#     2.1157735797
#     3.4614409522
#
# Posterior varience:
#     0.0009299812,    0.0000438164,   -0.0015818938
#     0.0000438164,    0.0013463305,   -0.0003846887
#    -0.0015818938,   -0.0003846887,    0.0049657338
#
# Predictive distribution ~ N(5.30001, 0.17571)
# --------------------------------------------------

# %%
len(x)
# Out:
# 430

# %%
plt.rcParams["figure.figsize"] = (15,10)

plt.subplot(221)
plt.title("Ground truth")
plt.xlim(-2,2)
plt.ylim(-15,20)
data_x = np.linspace(-2,2,30)
plt.plot(data_x,np.poly1d(np.flip(W))(data_x),'k-')
plt.plot(data_x,np.poly1d(np.flip(W))(data_x)+error_gen,'r-')
plt.plot(data_x,np.poly1d(np.flip(W))(data_x)-error_gen,'r-')

plt.subplot(222)
plt.title("Predict result")
plt.xlim(-2,2)
plt.ylim(-15,20)
plt.plot(x,y,'bo')
data_x = np.linspace(-2,2,50)
predict_y = np.poly1d(np.flip(np.reshape(m,n)))(data_x)
plt.plot(data_x,predict_y,'k-')
for i in range(50):
    A = np.array([[data_x[i]**j for j in range(n)]])
    predict_y[i] += (1/a+np.dot(A,np.dot(S_inv,np.transpose(A)))[0][0])
plt.plot(data_x,predict_y,'r-')
for i in range(50):
    A = np.array([[data_x[i]**j for j in range(n)]])
    predict_y[i] -= 2*(1/a+np.dot(A,np.dot(S_inv,np.transpose(A)))[0][0])
plt.plot(data_x,predict_y,'r-')

plt.subplot(223)
plt.title("After 10 incomes")
plt.xlim(-2,2)
plt.ylim(-15,20)
plt.plot(x[:10],y[:10],'bo')
data_x = np.linspace(-2,2,50)
predict_y = np.poly1d(np.flip(np.reshape(m_10,n)))(data_x)
plt.plot(data_x,predict_y,'k-')
for i in range(50):
    A = np.array([[data_x[i]**j for j in range(n)]])
    predict_y[i] += (1/a_10+np.dot(A,np.dot(S_10,np.transpose(A)))[0][0])
plt.plot(data_x,predict_y,'r-')
for i in range(50):
    A = np.array([[data_x[i]**j for j in range(n)]])
    predict_y[i] -= 2*(1/a_10+np.dot(A,np.dot(S_10,np.transpose(A)))[0][0])
plt.plot(data_x,predict_y,'r-')

plt.subplot(224)
plt.title("After 50 incomes")
plt.xlim(-2,2)
plt.ylim(-15,20)
plt.plot(x[:50],y[:50],'bo')
data_x = np.linspace(-2,2,50)
predict_y = np.poly1d(np.flip(np.reshape(m_50,n)))(data_x)
plt.plot(data_x,predict_y,'k-')
for i in range(50):
    A = np.array([[data_x[i]**j for j in range(n)]])
    predict_y[i] += (1/a_50+np.dot(A,np.dot(S_50,np.transpose(A)))[0][0])
plt.plot(data_x,predict_y,'r-')
for i in range(50):
    A = np.array([[data_x[i]**j for j in range(n)]])
    predict_y[i] -= 2*(1/a_50+np.dot(A,np.dot(S_50,np.transpose(A)))[0][0])
plt.plot(data_x,predict_y,'r-')
plt.show()
