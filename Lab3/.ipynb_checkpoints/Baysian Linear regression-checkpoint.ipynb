# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
b = float(input("Precision for initial prior: "))
n = int(input("Basis number: "))
error_gen = float(input("Varience for error(generator): "))
W = np.array([float(s) for s in input("{}X1 W vector: ".format(n)).split(",")])
# Out:
# Precision for initial prior: 1
# Basis number: 3
# Varience for error(generator): 3
# 3X1 W vector: 1,2,3

# %%
W
# Out:
# array([1., 2., 3.])

# %%
def univariate_gaussian_data_generator():
    temp = np.sum(np.random.uniform(0,1,12))-6
    temp = 0 + temp*np.sqrt(error_gen)
    return temp

# %%
def polynomial_basis_linear_model_generator():
    x = float(np.random.uniform(-1,1,1))
    y = 0
    for i in range(len(W)):
        y += W[i]*(x**i)
    return x, y + univariate_gaussian_data_generator()

# %%
N = 0
x = []
y = []
data_mean = 0
prev_data_mean = 0
a = 0
prev_m = np.zeros((n,1))
prev_S = np.zeros((n,n))
while(1):
    N += 1
    new_x, new_y = polynomial_basis_linear_model_generator()
    x.append(new_x)
    y.append(new_y)
    print("Add data point ({:.5f}, {:.5f})\n".format(new_x, new_y))
    
    data_mean = ((N-1)*data_mean+new_y)/N
    a = (((N-1)*(a+prev_data_mean**2)+new_y**2)/N - data_mean**2)
    if a == 0:
        a = 0.001
    else:
        a = 1/a
    
    A = np.array([[new_x**j for j in range(n)]])
    if N == 1:
        S_inv = np.linalg.inv(a*np.transpose(A)*A+b*np.identity(n))
        m = a*np.dot(S_inv,np.transpose(A))*new_y
    else:
        S = np.linalg.inv(S_inv)
        S_inv = np.linalg.inv(a*np.dot(np.transpose(A),A)+S)
        m = np.dot(S_inv, (a*np.transpose(A)*new_y+np.dot(S,m)))
    
    print("Posterior mean:")
    for i in range(m.shape[0]):
        print("{:16.10f}".format(m[i][0]))
    print("")
    
    print("Posterior varience:")
    for i in range(S_inv.shape[0]):
        for j in range(S_inv.shape[1]):
            if j == S_inv.shape[1]-1:
                print("{:16.10f}".format(S_inv[i][j]))
            else:
                print("{:16.10f},".format(S_inv[i][j]), end="")
    print("")
    
    predictive_distribution_mean = np.dot(A,m)[0][0]
    predictive_distribution_varience = 1/a + np.dot(A,np.dot(S_inv,np.transpose(A)))[0][0]
    print("Predictive distribution ~ N({:.5f}, {:.5f})".format(predictive_distribution_mean,predictive_distribution_varience))
    print("--------------------------------------------------")
    
    if (N>=100 and np.linalg.norm(m-prev_m)<0.0001 and np.linalg.norm(S_inv-prev_S)<0.0001):
        break
    
    prev_data_mean = data_mean
    prev_m = m
    prev_S = S_inv
    
    if (N==10):
        m_10 = m
        S_10 = S_inv
        a_10 = a
    if (N==50):
        m_50 = m
        S_50 = S_inv
        a_50 = a
# Out:
# Add data point (0.36810, 2.65910)
#
# Posterior mean:
#     0.0026560363
#     0.0009776751
#     0.0003598778
#
# Posterior varience:
#     0.9990011525,   -0.0003676713,   -0.0001353382
#    -0.0003676713,    0.9998646618,   -0.0000498174
#    -0.0001353382,   -0.0000498174,    0.9999816624
#
# Predictive distribution ~ N(0.00306, 1001.15252)
# --------------------------------------------------
# Add data point (0.34947, 0.01421)
#
# Posterior mean:
#     0.0065240842
#     0.0023293533
#     0.0008322164
#
# Posterior varience:
#     0.6531840373,   -0.1212124705,   -0.0423640692
#    -0.1212124705,    0.9576357933,   -0.0148065263
#    -0.0423640692,   -0.0148065263,    0.9948249896
#
# Predictive distribution ~ N(0.00744, 2.43800)
# --------------------------------------------------
# Add data point (-0.70186, 0.26208)
#
# Posterior mean:
#     0.0924956853
#    -0.0936181677
#     0.0557292031
#
# Posterior varience:
#     0.4129951339,    0.1468473253,   -0.1957361929
#     0.1468473253,    0.6584710395,    0.1563624977
#    -0.1957361929,    0.1563624977,    0.8968895396
#
# Predictive distribution ~ N(0.18566, 1.08561)
# --------------------------------------------------
# Add data point (0.53704, 3.27622)
#
# Posterior mean:
#     0.5695778760
#     0.5041740282
#     0.2167031622
#
# Posterior varience:
#     0.3484429159,    0.0659622851,   -0.2175169810
#     0.0659622851,    0.5571206921,    0.1290707954
#    -0.2175169810,    0.1290707954,    0.8895404082
#
# Predictive distribution ~ N(0.90284, 2.73452)
# --------------------------------------------------
# Add data point (-0.51704, -2.31301)
#
# Posterior mean:
#     0.3482076864
#     0.6662663364
#     0.2568401414
#
# Posterior varience:
#     0.3272802952,    0.0814580393,   -0.2136799528
#     0.0814580393,    0.5457743470,    0.1262612357
#    -0.2136799528,    0.1262612357,    0.8888447105
#
# Predictive distribution ~ N(0.07238, 3.06391)
# --------------------------------------------------
# Add data point (-0.61811, -1.43801)
#
# Posterior mean:
#     0.1314848812
#     0.8967067391
#     0.2037158493
#
# Posterior varience:
#     0.2985377287,    0.1120198835,   -0.2207254896
#     0.1120198835,    0.5132780729,    0.1337527239
#    -0.2207254896,    0.1337527239,    0.8871176696
#
# Predictive distribution ~ N(-0.34495, 1.23879)
# --------------------------------------------------
# Add data point (0.89595, 6.60462)
#
# Posterior mean:
#     0.3086789065
#     1.4395582700
#     0.6921960436
#
# Posterior varience:
#     0.2914026136,    0.0901607482,   -0.2403952409
#     0.0901607482,    0.4463104367,    0.0734924831
#    -0.2403952409,    0.0734924831,    0.8328930199
#
# Predictive distribution ~ N(2.15410, 6.63653)
# --------------------------------------------------
# Add data point (0.68774, 1.68106)
#
# Posterior mean:
#     0.3250065536
#     1.4689749499
#     0.7060979546
#
# Posterior varience:
#     0.2201729948,   -0.0381699827,   -0.3010425478
#    -0.0381699827,    0.2151035768,   -0.0357726421
#    -0.3010425478,   -0.0357726421,    0.7812558513
#
# Predictive distribution ~ N(1.66925, 0.30956)
# --------------------------------------------------
# Add data point (-0.73205, 1.26450)
#
# Posterior mean:
#     0.3510788904
#     1.4044424501
#     0.7493046040
#
# Posterior varience:
#     0.2187903044,   -0.0347476402,   -0.3033339197
#    -0.0347476402,    0.2066328241,   -0.0301011922
#    -0.3033339197,   -0.0301011922,    0.7774586275
#
# Predictive distribution ~ N(-0.27549, 5.42833)
# --------------------------------------------------
# Add data point (0.37514, 4.65388)
#
# Posterior mean:
#     0.8059473662
#     1.5119278394
#     0.1768681893
#
# Posterior varience:
#     0.1985821060,   -0.0395228361,   -0.2779025933
#    -0.0395228361,    0.2055044456,   -0.0240917715
#    -0.2779025933,   -0.0240917715,    0.7454541733
#
# Predictive distribution ~ N(1.39802, 1.29905)
# --------------------------------------------------
# Add data point (0.00286, 0.59279)
#
# Posterior mean:
#     0.7657001806
#     1.5198233789
#     0.2332370038
#
# Posterior varience:
#     0.1618554529,   -0.0323179412,   -0.2264645149
#    -0.0323179412,    0.2040910168,   -0.0341826978
#    -0.2264645149,   -0.0341826978,    0.6734117819
#
# Predictive distribution ~ N(0.77006, 1.03581)
# --------------------------------------------------
# Add data point (-0.97974, 2.03974)
#
# Posterior mean:
#     0.7308127123
#     1.1322433465
#     0.8961858555
#
# Posterior varience:
#     0.1615276089,   -0.0359601027,   -0.2202346614
#    -0.0359601027,    0.1636286631,    0.0350274489
#    -0.2202346614,    0.0350274489,    0.5550290392
#
# Predictive distribution ~ N(0.48175, 1.47736)
# --------------------------------------------------
# Add data point (0.52872, 4.14986)
#
# Posterior mean:
#     0.8768166072
#     1.2410839392
#     0.8122078235
#
# Posterior varience:
#     0.1569285830,   -0.0393885092,   -0.2175894091
#    -0.0393885092,    0.1610729108,    0.0369993882
#    -0.2175894091,    0.0369993882,    0.5535075518
#
# Predictive distribution ~ N(1.76005, 1.41784)
# --------------------------------------------------
# Add data point (-0.21565, -3.43974)
#
# Posterior mean:
#     0.6405197239
#     1.3512460742
#     1.1162485885
#
# Posterior varience:
#     0.1479487441,   -0.0352020882,   -0.2060351428
#    -0.0352020882,    0.1591211920,    0.0316127635
#    -0.2060351428,    0.0316127635,    0.5386407964
#
# Predictive distribution ~ N(0.40104, 2.67621)
# --------------------------------------------------
# Add data point (0.71317, 2.95374)
#
# Posterior mean:
#     0.6623767211
#     1.4654877010
#     1.2257813430
#
# Posterior varience:
#     0.1474440552,   -0.0378399839,   -0.2085643083
#    -0.0378399839,    0.1453335023,    0.0183933821
#    -0.2085643083,    0.0183933821,    0.5259662986
#
# Predictive distribution ~ N(2.33096, 0.61901)
# --------------------------------------------------
# Add data point (-0.31447, 0.78371)
#
# Posterior mean:
#     0.6942909418
#     1.4466857044
#     1.1884339591
#
# Posterior varience:
#     0.1378402879,   -0.0321820046,   -0.1973255698
#    -0.0321820046,    0.1420001511,    0.0117721732
#    -0.1973255698,    0.0117721732,    0.5128142468
#
# Predictive distribution ~ N(0.35687, 1.99267)
# --------------------------------------------------
# Add data point (0.28505, 1.85853)
#
# Posterior mean:
#     0.8137325315
#     1.4564960350
#     1.0269256647
#
# Posterior varience:
#     0.1173105395,   -0.0338682148,   -0.1695653511
#    -0.0338682148,    0.1418616543,    0.0140522577
#    -0.1695653511,    0.0140522577,    0.4752770239
#
# Predictive distribution ~ N(1.31234, 0.60082)
# --------------------------------------------------
# Add data point (-0.87506, 3.22726)
#
# Posterior mean:
#     0.8355564269
#     1.2686462545
#     1.2592038276
#
# Posterior varience:
#     0.1171818797,   -0.0327607727,   -0.1709347145
#    -0.0327607727,    0.1323293158,    0.0258390912
#    -0.1709347145,    0.0258390912,    0.4607024845
#
# Predictive distribution ~ N(0.68962, 2.23868)
# --------------------------------------------------
# Add data point (-0.95748, -0.29876)
#
# Posterior mean:
#     0.8444410068
#     1.4165364784
#     1.0122976334
#
# Posterior varience:
#     0.1171144039,   -0.0338839557,   -0.1690595340
#    -0.0338839557,    0.1136331254,    0.0570528192
#    -0.1690595340,    0.0570528192,    0.4085904342
#
# Predictive distribution ~ N(0.41618, 0.87580)
# --------------------------------------------------
# Add data point (0.86827, 7.26460)
#
# Posterior mean:
#     0.7897933117
#     1.5646958900
#     1.2714041651
#
# Posterior varience:
#     0.1166236272,   -0.0325533745,   -0.1667325655
#    -0.0325533745,    0.1100256881,    0.0507440025
#    -0.1667325655,    0.0507440025,    0.3975573477
#
# Predictive distribution ~ N(3.10687, 3.20894)
# --------------------------------------------------
# Add data point (0.80759, 4.42946)
#
# Posterior mean:
#     0.7528920199
#     1.7438819707
#     1.5390617988
#
# Posterior varience:
#     0.1161844178,   -0.0304206524,   -0.1635468305
#    -0.0304206524,    0.0996695703,    0.0352746427
#    -0.1635468305,    0.0352746427,    0.3744501274
#
# Predictive distribution ~ N(3.16503, 0.74600)
# --------------------------------------------------
# Add data point (-0.77916, -1.79093)
#
# Posterior mean:
#     0.7144675597
#     1.8259048303
#     1.5047109458
#
# Posterior varience:
#     0.1154483710,   -0.0288494483,   -0.1642048446
#    -0.0288494483,    0.0963155961,    0.0366792739
#    -0.1642048446,    0.0366792739,    0.3738618733
#
# Predictive distribution ~ N(0.20529, 2.23178)
# --------------------------------------------------
# Add data point (0.56481, -0.52576)
#
# Posterior mean:
#     0.5377922656
#     1.6851905033
#     1.5962122051
#
# Posterior varience:
#     0.1124451955,   -0.0312413493,   -0.1626494810
#    -0.0312413493,    0.0944105491,    0.0379180547
#    -0.1626494810,    0.0379180547,    0.3730563405
#
# Predictive distribution ~ N(1.99881, 0.72346)
# --------------------------------------------------
# Add data point (0.89024, 4.79108)
#
# Posterior mean:
#     0.5046884945
#     1.7471475862
#     1.7209100974
#
# Posterior varience:
#     0.1114603082,   -0.0293980322,   -0.1589395298
#    -0.0293980322,    0.0909605933,    0.0309745028
#    -0.1589395298,    0.0309745028,    0.3590814042
#
# Predictive distribution ~ N(3.42393, 1.97686)
# --------------------------------------------------
# Add data point (0.76681, 2.43126)
#
# Posterior mean:
#     0.5077672854
#     1.7074113426
#     1.6693778147
#
# Posterior varience:
#     0.1114274397,   -0.0289738167,   -0.1583893823
#    -0.0289738167,    0.0854854791,    0.0238740548
#    -0.1583893823,    0.0238740548,    0.3498731283
#
# Predictive distribution ~ N(2.79860, 0.61488)
# --------------------------------------------------
# Add data point (-0.16638, -0.63028)
#
# Posterior mean:
#     0.4600465407
#     1.7255571565
#     1.7345091556
#
# Posterior varience:
#     0.1054972464,   -0.0267188606,   -0.1502955974
#    -0.0267188606,    0.0846280320,    0.0207963929
#    -0.1502955974,    0.0207963929,    0.3388263798
#
# Predictive distribution ~ N(0.22096, 2.10389)
# --------------------------------------------------
# Add data point (0.64621, 4.48104)
#
# Posterior mean:
#     0.5288819114
#     1.8246151639
#     1.7470282792
#
# Posterior varience:
#     0.1046936055,   -0.0278753455,   -0.1504417560
#    -0.0278753455,    0.0829637846,    0.0205860624
#    -0.1504417560,    0.0205860624,    0.3387997979
#
# Predictive distribution ~ N(2.43750, 0.80399)
# --------------------------------------------------
# Add data point (0.67922, 6.74290)
#
# Posterior mean:
#     0.5604002305
#     1.8977931358
#     1.7852683366
#
# Posterior varience:
#     0.1045699502,   -0.0281624434,   -0.1505917826
#    -0.0281624434,    0.0822972121,    0.0202377367
#    -0.1505917826,    0.0202377367,    0.3386177759
#
# Predictive distribution ~ N(2.67304, 2.16197)
# --------------------------------------------------
# Add data point (0.75589, 3.12088)
#
# Posterior mean:
#     0.5598822740
#     1.9063457390
#     1.7961789259
#
# Posterior varience:
#     0.1045564399,   -0.0279393590,   -0.1503071929
#    -0.0279393590,    0.0786135965,    0.0155385339
#    -0.1503071929,    0.0155385339,    0.3326229846
#
# Predictive distribution ~ N(3.02717, 0.55723)
# --------------------------------------------------
# Add data point (-0.78774, 0.66042)
#
# Posterior mean:
#     0.5675465493
#     1.8878780744
#     1.8062750478
#
# Posterior varience:
#     0.1040331680,   -0.0266784949,   -0.1509964970
#    -0.0266784949,    0.0755754469,    0.0171994655
#    -0.1509964970,    0.0171994655,    0.3317149668
#
# Predictive distribution ~ N(0.20125, 2.11116)
# --------------------------------------------------
# Add data point (0.86084, 3.94474)
#
# Posterior mean:
#     0.5493268400
#     1.9180947588
#     1.8710660008
#
# Posterior varience:
#     0.1026749357,   -0.0244259190,   -0.1461664985
#    -0.0244259190,    0.0718396367,    0.0091890995
#    -0.1461664985,    0.0091890995,    0.3145390502
#
# Predictive distribution ~ N(3.58702, 0.68691)
# --------------------------------------------------
# Add data point (0.93495, 3.92536)
#
# Posterior mean:
#     0.5507134484
#     1.9166259373
#     1.8670918883
#
# Posterior varience:
#     0.1014175139,   -0.0230939435,   -0.1425626430
#    -0.0230939435,    0.0704286873,    0.0053715683
#    -0.1425626430,    0.0053715683,    0.3042101585
#
# Predictive distribution ~ N(3.97476, 1.81925)
# --------------------------------------------------
# Add data point (-0.81228, 2.58767)
#
# Posterior mean:
#     0.6389848980
#     1.6571556471
#     2.0489333885
#
# Posterior varience:
#     0.1004415895,   -0.0202252542,   -0.1445730727
#    -0.0202252542,    0.0619962931,    0.0112811436
#    -0.1445730727,    0.0112811436,    0.3000686207
#
# Predictive distribution ~ N(0.64480, 0.67672)
# --------------------------------------------------
# Add data point (-0.48000, 2.18202)
#
# Posterior mean:
#     0.7200195358
#     1.6071845076
#     1.9636678637
#
# Posterior varience:
#     0.0971053693,   -0.0181679274,   -0.1410626656
#    -0.0181679274,    0.0607276138,    0.0091164021
#    -0.1410626656,    0.0091164021,    0.2963749322
#
# Predictive distribution ~ N(0.40100, 1.76607)
# --------------------------------------------------
# Add data point (-0.74118, -0.11841)
#
# Posterior mean:
#     0.6899631868
#     1.6600399901
#     1.9500439962
#
# Posterior varience:
#     0.0957358411,   -0.0157595487,   -0.1416834420
#    -0.0157595487,    0.0564923682,    0.0102080661
#    -0.1416834420,    0.0102080661,    0.2960935483
#
# Predictive distribution ~ N(0.53083, 0.79003)
# --------------------------------------------------
# Add data point (-0.88247, 0.95968)
#
# Posterior mean:
#     0.6898637444
#     1.6517656008
#     1.9615081206
#
# Posterior varience:
#     0.0957355222,   -0.0157860888,   -0.1416466708
#    -0.0157860888,    0.0542840200,    0.0132677214
#    -0.1416466708,    0.0132677214,    0.2918544115
#
# Predictive distribution ~ N(0.75976, 1.49726)
# --------------------------------------------------
# Add data point (-0.36974, -0.46298)
#
# Posterior mean:
#     0.6191257056
#     1.6810589176
#     2.0532809565
#
# Posterior varience:
#     0.0885586669,   -0.0128140825,   -0.1323356922
#    -0.0128140825,    0.0530532830,    0.0094119537
#    -0.1323356922,    0.0094119537,    0.2797747027
#
# Predictive distribution ~ N(0.27827, 0.93483)
# --------------------------------------------------
# Add data point (-0.31778, -0.26233)
#
# Posterior mean:
#     0.5861818805
#     1.6929962063
#     2.0977816249
#
# Posterior varience:
#     0.0838500680,   -0.0111079083,   -0.1259752954
#    -0.0111079083,    0.0524350459,    0.0071072458
#    -0.1259752954,    0.0071072458,    0.2711830499
#
# Predictive distribution ~ N(0.26003, 1.32992)
# --------------------------------------------------
# Add data point (0.75849, 4.38311)
#
# Posterior mean:
#     0.5901244635
#     1.7367641135
#     2.1451264419
#
# Posterior varience:
#     0.0838411610,   -0.0112067870,   -0.1260822550
#    -0.0112067870,    0.0513373609,    0.0059198531
#    -0.1260822550,    0.0059198531,    0.2698986182
#
# Predictive distribution ~ N(3.14155, 0.97488)
# --------------------------------------------------
# Add data point (-0.64594, 1.91577)
#
# Posterior mean:
#     0.6440402386
#     1.6780491273
#     2.1208924754
#
# Posterior varience:
#     0.0825050174,   -0.0097517091,   -0.1254816875
#    -0.0097517091,    0.0497527620,    0.0052658273
#    -0.1254816875,    0.0052658273,    0.2696286762
#
# Predictive distribution ~ N(0.44504, 1.10473)
# --------------------------------------------------
# Add data point (0.87467, 8.19918)
#
# Posterior mean:
#     0.5931177585
#     1.7654325613
#     2.3183536138
#
# Posterior varience:
#     0.0822538210,   -0.0093206538,   -0.1245076280
#    -0.0093206538,    0.0490130673,    0.0035943325
#    -0.1245076280,    0.0035943325,    0.2658515841
#
# Predictive distribution ~ N(3.91095, 1.92806)
# --------------------------------------------------
# Add data point (-0.42505, -0.25443)
#
# Posterior mean:
#     0.5473947450
#     1.7866033219
#     2.3743258088
#
# Posterior varience:
#     0.0766074287,   -0.0067062500,   -0.1175955514
#    -0.0067062500,    0.0478025408,    0.0003938890
#    -0.1175955514,    0.0003938890,    0.2573901099
#
# Predictive distribution ~ N(0.21696, 0.71374)
# --------------------------------------------------
# Add data point (0.25569, 0.14319)
#
# Posterior mean:
#     0.5055535180
#     1.7831528340
#     2.4370007554
#
# Posterior varience:
#     0.0738404538,   -0.0069344320,   -0.1134508354
#    -0.0069344320,    0.0477837235,    0.0007356881
#    -0.1134508354,    0.0007356881,    0.2511816434
#
# Predictive distribution ~ N(1.12081, 1.62992)
# --------------------------------------------------
# Add data point (-0.73375, 0.57406)
#
# Posterior mean:
#     0.5071424716
#     1.7794493301
#     2.4388919381
#
# Posterior varience:
#     0.0734030697,   -0.0059149851,   -0.1139714128
#    -0.0059149851,    0.0454076155,    0.0019490402
#    -0.1139714128,    0.0019490402,    0.2505620489
#
# Predictive distribution ~ N(0.51454, 0.72339)
# --------------------------------------------------
# Add data point (-0.35115, 1.85386)
#
# Posterior mean:
#     0.5745892624
#     1.7557108719
#     2.3469233079
#
# Posterior varience:
#     0.0709234589,   -0.0050422655,   -0.1105902822
#    -0.0050422655,    0.0451004545,    0.0007590232
#    -0.1105902822,    0.0007590232,    0.2459516303
#
# Predictive distribution ~ N(0.24746, 1.51944)
# --------------------------------------------------
# Add data point (0.88151, 6.17085)
#
# Posterior mean:
#     0.5358343978
#     1.8260289437
#     2.5086549191
#
# Posterior varience:
#     0.0705845292,   -0.0044273006,   -0.1091758626
#    -0.0044273006,    0.0439846425,   -0.0018073453
#    -0.1091758626,   -0.0018073453,    0.2400489810
#
# Predictive distribution ~ N(4.09490, 1.11202)
# --------------------------------------------------
# Add data point (-0.15247, -0.27508)
#
# Posterior mean:
#     0.4996354407
#     1.8319157108
#     2.5630784764
#
# Posterior varience:
#     0.0663740402,   -0.0037425801,   -0.1028455754
#    -0.0037425801,    0.0438732915,   -0.0028367928
#    -0.1028455754,   -0.0028367928,    0.2305316697
#
# Predictive distribution ~ N(0.27991, 1.11751)
# --------------------------------------------------
# Add data point (-0.13582, 0.43499)
#
# Posterior mean:
#     0.5081470807
#     1.8306381729
#     2.5502154170
#
# Posterior varience:
#     0.0623333335,   -0.0031360981,   -0.0967391317
#    -0.0031360981,    0.0437822627,   -0.0037533275
#    -0.0967391317,   -0.0037533275,    0.2213034189
#
# Predictive distribution ~ N(0.30655, 1.04115)
# --------------------------------------------------
# Add data point (0.75932, 5.22959)
#
# Posterior mean:
#     0.5143616887
#     1.8722233808
#     2.5918917702
#
# Posterior varience:
#     0.0623193883,   -0.0032294126,   -0.0968326507
#    -0.0032294126,    0.0431578464,   -0.0043791124
#    -0.0968326507,   -0.0043791124,    0.2206762625
#
# Predictive distribution ~ N(3.43035, 1.24922)
# --------------------------------------------------
# Add data point (0.00238, 1.13452)
#
# Posterior mean:
#     0.5574958675
#     1.8700588589
#     2.5248541511
#
# Posterior varience:
#     0.0579539762,   -0.0030103513,   -0.0900480812
#    -0.0030103513,    0.0431468537,   -0.0047195698
#    -0.0900480812,   -0.0047195698,    0.2101319238
#
# Predictive distribution ~ N(0.56196, 0.88505)
# --------------------------------------------------
# Add data point (0.56007, 2.67228)
#
# Posterior mean:
#     0.5638028618
#     1.8744870375
#     2.5188271689
#
# Posterior varience:
#     0.0573123161,   -0.0034608647,   -0.0894349089
#    -0.0034608647,    0.0428305455,   -0.0042890578
#    -0.0894349089,   -0.0042890578,    0.2095459746
#
# Predictive distribution ~ N(2.40374, 1.22298)
# --------------------------------------------------
# Add data point (0.96806, 4.30146)
#
# Posterior mean:
#     0.5766400036
#     1.8598731488
#     2.4746244549
#
# Posterior varience:
#     0.0564363083,   -0.0024636115,   -0.0864185115
#    -0.0024636115,    0.0416952658,   -0.0077229450
#    -0.0864185115,   -0.0077229450,    0.1991594761
#
# Predictive distribution ~ N(4.69616, 1.00747)
# --------------------------------------------------
# Add data point (-0.31903, 1.88051)
#
# Posterior mean:
#     0.6479704808
#     1.8354929776
#     2.3808203054
#
# Posterior varience:
#     0.0543368953,   -0.0017460494,   -0.0836576488
#    -0.0017460494,    0.0414500090,   -0.0086665852
#    -0.0836576488,   -0.0086665852,    0.1955287648
#
# Predictive distribution ~ N(0.30471, 1.11504)
# --------------------------------------------------
# Add data point (-0.67842, 0.44087)
#
# Posterior mean:
#     0.6470013886
#     1.8374209578
#     2.3801246607
#
# Posterior varience:
#     0.0540508255,   -0.0011769220,   -0.0838629987
#    -0.0011769220,    0.0403177470,   -0.0082580478
#    -0.0838629987,   -0.0082580478,    0.1953813582
#
# Predictive distribution ~ N(0.49592, 1.01025)
# --------------------------------------------------
# Add data point (-0.19440, 2.10785)
#
# Posterior mean:
#     0.7298734339
#     1.8222985022
#     2.2587212846
#
# Posterior varience:
#     0.0515997759,   -0.0007296556,   -0.0802723344
#    -0.0007296556,    0.0402361300,   -0.0089132707
#    -0.0802723344,   -0.0089132707,    0.1901212157
#
# Predictive distribution ~ N(0.46098, 1.06342)
# --------------------------------------------------
# Add data point (0.25965, 1.49519)
#
# Posterior mean:
#     0.7362045163
#     1.8235533217
#     2.2491185166
#
# Posterior varience:
#     0.0495176318,   -0.0011423362,   -0.0771142097
#    -0.0011423362,    0.0401543368,   -0.0082873309
#    -0.0771142097,   -0.0082873309,    0.1853310809
#
# Predictive distribution ~ N(1.36133, 1.01431)
# --------------------------------------------------
# Add data point (-0.28158, 3.46884)
#
# Posterior mean:
#     0.8595307951
#     1.7865870079
#     2.0796464814
#
# Posterior varience:
#     0.0477598729,   -0.0006154585,   -0.0746987393
#    -0.0006154585,    0.0399964084,   -0.0090113537
#    -0.0746987393,   -0.0090113537,    0.1820117990
#
# Predictive distribution ~ N(0.52135, 1.08600)
# --------------------------------------------------
# Add data point (-0.72073, 1.24070)
#
# Posterior mean:
#     0.8650647421
#     1.7665006099
#     2.0951527265
#
# Posterior varience:
#     0.0476714760,   -0.0002946069,   -0.0749464295
#    -0.0002946069,    0.0388318233,   -0.0081123203
#    -0.0749464295,   -0.0081123203,    0.1813177656
#
# Predictive distribution ~ N(0.68022, 0.99755)
# --------------------------------------------------
# Add data point (0.80285, 5.40684)
#
# Posterior mean:
#     0.8638386413
#     1.8025468005
#     2.1449112554
#
# Posterior varience:
#     0.0476708726,   -0.0002768682,   -0.0749219428
#    -0.0002768682,    0.0383103220,   -0.0088322060
#    -0.0749219428,   -0.0088322060,    0.1803240280
#
# Predictive distribution ~ N(3.69353, 1.26040)
# --------------------------------------------------
# Add data point (0.22707, 0.24217)
#
# Posterior mean:
#     0.8087217662
#     1.7925088548
#     2.2301220572
#
# Posterior varience:
#     0.0455587867,   -0.0006615236,   -0.0716566537
#    -0.0006615236,    0.0382402681,   -0.0082375280
#    -0.0716566537,   -0.0082375280,    0.1752758844
#
# Predictive distribution ~ N(1.33074, 0.90408)
# --------------------------------------------------
# Add data point (-0.49949, 3.10102)
#
# Posterior mean:
#     0.8707557723
#     1.7441916680
#     2.1773883521
#
# Posterior varience:
#     0.0448983931,   -0.0001471547,   -0.0710952680
#    -0.0001471547,    0.0378396353,   -0.0086747814
#    -0.0710952680,   -0.0086747814,    0.1747986631
#
# Predictive distribution ~ N(0.54279, 1.18722)
# --------------------------------------------------
# Add data point (0.56799, 2.67483)
#
# Posterior mean:
#     0.8735043199
#     1.7465216645
#     2.1749222784
#
# Posterior varience:
#     0.0443563193,   -0.0006066810,   -0.0706089043
#    -0.0006066810,    0.0374500860,   -0.0082624815
#    -0.0706089043,   -0.0082624815,    0.1743622840
#
# Predictive distribution ~ N(2.56717, 0.88226)
# --------------------------------------------------
# Add data point (-0.70961, 0.32937)
#
# Posterior mean:
#     0.8705290470
#     1.7566229542
#     2.1674920781
#
# Posterior varience:
#     0.0442876456,   -0.0003735285,   -0.0707804042
#    -0.0003735285,    0.0366585143,   -0.0076802255
#    -0.0707804042,   -0.0076802255,    0.1739339943
#
# Predictive distribution ~ N(0.71545, 1.23950)
# --------------------------------------------------
# Add data point (0.03011, -0.95183)
#
# Posterior mean:
#     0.7881449476
#     1.7552752362
#     2.2995198000
#
# Posterior varience:
#     0.0423473354,   -0.0004052699,   -0.0676708873
#    -0.0004052699,    0.0366579951,   -0.0076293571
#    -0.0676708873,   -0.0076293571,    0.1689507216
#
# Predictive distribution ~ N(0.84308, 1.00549)
# --------------------------------------------------
# Add data point (-0.74362, 1.86496)
#
# Posterior mean:
#     0.7935774040
#     1.7221511914
#     2.3321689290
#
# Posterior varience:
#     0.0423217558,   -0.0002493003,   -0.0678246208
#    -0.0002493003,    0.0357069804,   -0.0066919776
#    -0.0678246208,   -0.0066919776,    0.1680267818
#
# Predictive distribution ~ N(0.80257, 1.06691)
# --------------------------------------------------
# Add data point (0.81932, 1.74858)
#
# Posterior mean:
#     0.8004246950
#     1.6729613890
#     2.2529343492
#
# Posterior varience:
#     0.0423101976,   -0.0001662680,   -0.0676908730
#    -0.0001662680,    0.0351104905,   -0.0076527991
#    -0.0676908730,   -0.0076527991,    0.1664790973
#
# Predictive distribution ~ N(3.68349, 1.00560)
# --------------------------------------------------
# Add data point (0.38122, 1.08728)
#
# Posterior mean:
#     0.7797796125
#     1.6652496248
#     2.2825006607
#
# Posterior varience:
#     0.0413237785,   -0.0005347350,   -0.0662781989
#    -0.0005347350,    0.0349728533,   -0.0071251088
#    -0.0662781989,   -0.0071251088,    0.1644559732
#
# Predictive distribution ~ N(1.74631, 1.06398)
# --------------------------------------------------
# Add data point (0.72282, 3.11552)
#
# Posterior mean:
#     0.7793977894
#     1.6639774061
#     2.2816234661
#
# Posterior varience:
#     0.0412839363,   -0.0006674874,   -0.0663697316
#    -0.0006674874,    0.0345305278,   -0.0074300922
#    -0.0663697316,   -0.0074300922,    0.1642456872
#
# Predictive distribution ~ N(3.17422, 0.99822)
# --------------------------------------------------
# Add data point (0.65104, 3.64133)
#
# Posterior mean:
#     0.7889786881
#     1.6780371106
#     2.2804248107
#
# Posterior varience:
#     0.0411337855,   -0.0008878297,   -0.0663509464
#    -0.0008878297,    0.0342071816,   -0.0074025254
#    -0.0663509464,   -0.0074025254,    0.1642433370
#
# Predictive distribution ~ N(2.84801, 1.07677)
# --------------------------------------------------
# Add data point (-0.41644, -1.79061)
#
# Posterior mean:
#     0.7308579160
#     1.7098458919
#     2.3478225791
#
# Posterior varience:
#     0.0403678673,   -0.0004686521,   -0.0654627755
#    -0.0004686521,    0.0339777709,   -0.0078886104
#    -0.0654627755,   -0.0078886104,    0.1632134000
#
# Predictive distribution ~ N(0.42597, 1.17400)
# --------------------------------------------------
# Add data point (-0.24663, 1.57563)
#
# Posterior mean:
#     0.7764394399
#     1.6981967751
#     2.2809025948
#
# Posterior varience:
#     0.0388871874,   -0.0000902397,   -0.0632889326
#    -0.0000902397,    0.0338810613,   -0.0084441721
#    -0.0632889326,   -0.0084441721,    0.1600218978
#
# Predictive distribution ~ N(0.49635, 0.89842)
# --------------------------------------------------
# Add data point (0.08910, 0.54865)
#
# Posterior mean:
#     0.7638166288
#     1.6972555734
#     2.3015491164
#
# Posterior varience:
#     0.0376676177,   -0.0001811752,   -0.0612941415
#    -0.0001811752,    0.0338742809,   -0.0082954334
#    -0.0612941415,   -0.0082954334,    0.1567591144
#
# Predictive distribution ~ N(0.93331, 1.20641)
# --------------------------------------------------
# Add data point (-0.73202, -0.02135)
#
# Posterior mean:
#     0.7597209173
#     1.7215732366
#     2.2777643641
#
# Posterior varience:
#     0.0376414635,   -0.0000258883,   -0.0614460252
#    -0.0000258883,    0.0329522890,   -0.0073936466
#    -0.0614460252,   -0.0073936466,    0.1558770898
#
# Predictive distribution ~ N(0.72004, 0.93709)
# --------------------------------------------------
# Add data point (0.81072, 6.82443)
#
# Posterior mean:
#     0.7536912951
#     1.7691580977
#     2.3540867082
#
# Posterior varience:
#     0.0376362053,    0.0000156089,   -0.0613794670
#     0.0000156089,    0.0326247993,   -0.0079189141
#    -0.0613794670,   -0.0079189141,    0.1550346024
#
# Predictive distribution ~ N(3.73525, 1.45412)
# --------------------------------------------------
# Add data point (0.22104, -1.25976)
#
# Posterior mean:
#     0.6534128674
#     1.7493572105
#     2.5149081706
#
# Posterior varience:
#     0.0362574874,   -0.0002566315,   -0.0591683491
#    -0.0002566315,    0.0325710430,   -0.0074823087
#    -0.0591683491,   -0.0074823087,    0.1514885234
#
# Predictive distribution ~ N(1.16297, 0.86907)
# --------------------------------------------------
# Add data point (-0.82837, 1.81046)
#
# Posterior mean:
#     0.6504728813
#     1.7263185998
#     2.5511903986
#
# Posterior varience:
#     0.0362436930,   -0.0003647278,   -0.0589981141
#    -0.0003647278,    0.0317239677,   -0.0061482969
#    -0.0589981141,   -0.0061482969,    0.1493876623
#
# Predictive distribution ~ N(0.97106, 1.23443)
# --------------------------------------------------
# Add data point (0.75620, 6.22797)
#
# Posterior mean:
#     0.6561782855
#     1.7777606337
#     2.6069032303
#
# Posterior varience:
#     0.0362391698,   -0.0004055112,   -0.0590422834
#    -0.0004055112,    0.0313562495,   -0.0065465436
#    -0.0590422834,   -0.0065465436,    0.1489563526
#
# Predictive distribution ~ N(3.49126, 1.09888)
# --------------------------------------------------
# Add data point (-0.84125, 0.96621)
#
# Posterior mean:
#     0.6563840305
#     1.7790027916
#     2.6048519642
#
# Posterior varience:
#     0.0362119485,   -0.0005698561,   -0.0587708887
#    -0.0005698561,    0.0303640396,   -0.0049080348
#    -0.0587708887,   -0.0049080348,    0.1462505632
#
# Predictive distribution ~ N(1.00325, 0.99139)
# --------------------------------------------------
# Add data point (0.22023, -1.78269)
#
# Posterior mean:
#     0.5787098799
#     1.7652628995
#     2.7281510888
#
# Posterior varience:
#     0.0353389692,   -0.0007242787,   -0.0573851306
#    -0.0007242787,    0.0303367236,   -0.0046629061
#    -0.0573851306,   -0.0046629061,    0.1440508255
#
# Predictive distribution ~ N(1.09979, 1.26455)
# --------------------------------------------------
# Add data point (0.08356, -0.59379)
#
# Posterior mean:
#     0.5277067261
#     1.7626627280
#     2.8111666055
#
# Posterior varience:
#     0.0340105143,   -0.0007920041,   -0.0552228649
#    -0.0007920041,    0.0303332709,   -0.0045526725
#    -0.0552228649,   -0.0045526725,    0.1405314037
#
# Predictive distribution ~ N(0.69462, 0.91439)
# --------------------------------------------------
# Add data point (0.58393, 0.56166)
#
# Posterior mean:
#     0.5030007019
#     1.7368661566
#     2.8278914526
#
# Posterior varience:
#     0.0338244027,   -0.0009863308,   -0.0550968758
#    -0.0009863308,    0.0301303664,   -0.0044211222
#    -0.0550968758,   -0.0044211222,    0.1404461149
#
# Predictive distribution ~ N(2.48145, 1.16364)
# --------------------------------------------------
# Add data point (-0.04315, -0.06556)
#
# Posterior mean:
#     0.4851656482
#     1.7380781799
#     2.8567559084
#
# Posterior varience:
#     0.0326173342,   -0.0009043017,   -0.0531433424
#    -0.0009043017,    0.0301247919,   -0.0045538792
#    -0.0531433424,   -0.0045538792,    0.1372844939
#
# Predictive distribution ~ N(0.41549, 0.94326)
# --------------------------------------------------
# Add data point (-0.10209, 2.05367)
#
# Posterior mean:
#     0.5345614852
#     1.7318920627
#     2.7780321811
#
# Posterior varience:
#     0.0316918009,   -0.0007883919,   -0.0516682903
#    -0.0007883919,    0.0301102759,   -0.0047386082
#    -0.0516682903,   -0.0047386082,    0.1349336562
#
# Predictive distribution ~ N(0.38671, 1.11627)
# --------------------------------------------------
# Add data point (-0.29257, -0.20880)
#
# Posterior mean:
#     0.5213738929
#     1.7366891770
#     2.7966062103
#
# Posterior varience:
#     0.0309274406,   -0.0005103485,   -0.0505917291
#    -0.0005103485,    0.0300091349,   -0.0051302178
#    -0.0505917291,   -0.0051302178,    0.1334173763
#
# Predictive distribution ~ N(0.25265, 0.98863)
# --------------------------------------------------
# Add data point (0.54983, 3.07047)
#
# Posterior mean:
#     0.5321851633
#     1.7468569741
#     2.7873959768
#
# Posterior varience:
#     0.0307057721,   -0.0007188235,   -0.0504028874
#    -0.0007188235,    0.0298130680,   -0.0049526157
#    -0.0504028874,   -0.0049526157,    0.1332565002
#
# Predictive distribution ~ N(2.33532, 1.06293)
# --------------------------------------------------
# Add data point (-0.42341, -1.11223)
#
# Posterior mean:
#     0.5034248075
#     1.7654812384
#     2.8193528642
#
# Posterior varience:
#     0.0302557972,   -0.0004274344,   -0.0499029006
#    -0.0004274344,    0.0296243740,   -0.0052763908
#    -0.0499029006,   -0.0052763908,    0.1327009430
#
# Predictive distribution ~ N(0.26134, 1.07257)
# --------------------------------------------------
# Add data point (-0.45120, -0.13545)
#
# Posterior mean:
#     0.4950559921
#     1.7716140262
#     2.8278112499
#
# Posterior varience:
#     0.0298478879,   -0.0001285127,   -0.0494906255
#    -0.0001285127,    0.0294053199,   -0.0055785119
#    -0.0494906255,   -0.0055785119,    0.1322842554
#
# Predictive distribution ~ N(0.27140, 1.00866)
# --------------------------------------------------
# Add data point (0.95447, 2.04466)
#
# Posterior mean:
#     0.5340994884
#     1.7135219842
#     2.6608300426
#
# Posterior varience:
#     0.0296271861,    0.0001998652,   -0.0485467281
#     0.0001998652,    0.0289167330,   -0.0069829182
#    -0.0485467281,   -0.0069829182,    0.1282473950
#
# Predictive distribution ~ N(4.59366, 1.06508)
# --------------------------------------------------
# Add data point (-0.77382, 1.38420)
#
# Posterior mean:
#     0.5343274811
#     1.6985948275
#     2.6798878524
#
# Posterior varience:
#     0.0296270286,    0.0002101774,   -0.0485598939
#     0.0002101774,    0.0282415709,   -0.0061209247
#    -0.0485598939,   -0.0061209247,    0.1271468701
#
# Predictive distribution ~ N(0.82464, 1.02737)
# --------------------------------------------------
# Add data point (-0.70891, 1.46884)
#
# Posterior mean:
#     0.5382160997
#     1.6810565824
#     2.6949662174
#
# Posterior varience:
#     0.0296021102,    0.0003225632,   -0.0486565167
#     0.0003225632,    0.0277346939,   -0.0056851414
#    -0.0486565167,   -0.0056851414,    0.1267722089
#
# Predictive distribution ~ N(0.70085, 1.03243)
# --------------------------------------------------
# Add data point (0.51354, 4.90933)
#
# Posterior mean:
#     0.5808971487
#     1.7139852800
#     2.6492424615
#
# Posterior varience:
#     0.0293436844,    0.0001231861,   -0.0483796679
#     0.0001231861,    0.0275808732,   -0.0054715508
#    -0.0483796679,   -0.0054715508,    0.1264756236
#
# Predictive distribution ~ N(2.15977, 1.10957)
# --------------------------------------------------
# Add data point (0.52396, 2.36191)
#
# Posterior mean:
#     0.5836022622
#     1.7161780925
#     2.6464705290
#
# Posterior varience:
#     0.0290634135,   -0.0001040064,   -0.0480924741
#    -0.0001040064,    0.0273967070,   -0.0052387464
#    -0.0480924741,   -0.0052387464,    0.1261813359
#
# Predictive distribution ~ N(2.20936, 0.92752)
# --------------------------------------------------
# Add data point (0.13632, -1.11779)
#
# Posterior mean:
#     0.5374011177
#     1.7103798949
#     2.7227108214
#
# Posterior varience:
#     0.0284079376,   -0.0001862679,   -0.0470108197
#    -0.0001862679,    0.0273863833,   -0.0051029999
#    -0.0470108197,   -0.0051029999,    0.1243964093
#
# Predictive distribution ~ N(0.82117, 1.20876)
# --------------------------------------------------
# Add data point (0.35562, 1.44291)
#
# Posterior mean:
#     0.5361760259
#     1.7098926587
#     2.7245210623
#
# Posterior varience:
#     0.0278247927,   -0.0004181928,   -0.0461491432
#    -0.0004181928,    0.0272941435,   -0.0047602991
#    -0.0461491432,   -0.0047602991,    0.1231231644
#
# Predictive distribution ~ N(1.48879, 0.85964)
# --------------------------------------------------
# Add data point (-0.79765, 3.01543)
#
# Posterior mean:
#     0.5341215916
#     1.6668627825
#     2.7859224553
#
# Posterior varience:
#     0.0278236202,   -0.0004427507,   -0.0461141004
#    -0.0004427507,    0.0267797821,   -0.0040263321
#    -0.0461141004,   -0.0040263321,    0.1220758317
#
# Predictive distribution ~ N(0.97709, 1.23499)
# --------------------------------------------------
# Add data point (0.97844, 6.65244)
#
# Posterior mean:
#     0.5072896547
#     1.7019388940
#     2.8929115278
#
# Posterior varience:
#     0.0275766234,   -0.0001198636,   -0.0451292309
#    -0.0001198636,    0.0263576871,   -0.0053138050
#    -0.0451292309,   -0.0053138050,    0.1181487848
#
# Predictive distribution ~ N(4.94204, 1.13264)
# --------------------------------------------------
# Add data point (0.53245, 2.77944)
#
# Posterior mean:
#     0.5157275857
#     1.7090522110
#     2.8846201796
#
# Posterior varience:
#     0.0273490772,   -0.0003116888,   -0.0449056376
#    -0.0003116888,    0.0261959752,   -0.0051253121
#    -0.0449056376,   -0.0051253121,    0.1179290757
#
# Predictive distribution ~ N(2.24352, 0.95172)
# --------------------------------------------------
# Add data point (-0.82627, 1.46911)
#
# Posterior mean:
#     0.5146345026
#     1.6999329378
#     2.8988930287
#
# Posterior varience:
#     0.0273406577,   -0.0003819300,   -0.0447957011
#    -0.0003819300,    0.0256099738,   -0.0042081436
#    -0.0447957011,   -0.0042081436,    0.1164935878
#
# Predictive distribution ~ N(1.08916, 1.10394)
# --------------------------------------------------
# Add data point (-0.61386, 2.55666)
#
# Posterior mean:
#     0.5368391757
#     1.6632088456
#     2.9023909828
#
# Posterior varience:
#     0.0272215106,   -0.0001848737,   -0.0448144706
#    -0.0001848737,    0.0252840643,   -0.0041771009
#    -0.0448144706,   -0.0041771009,    0.1164906310
#
# Predictive distribution ~ N(0.60955, 0.95952)
# --------------------------------------------------
# Add data point (-0.56289, 0.59796)
#
# Posterior mean:
#     0.5377729994
#     1.6620890400
#     2.9019958897
#
# Posterior varience:
#     0.0270637859,    0.0000042637,   -0.0447477386
#     0.0000042637,    0.0250572581,   -0.0042571234
#    -0.0447477386,   -0.0042571234,    0.1164623972
#
# Predictive distribution ~ N(0.52168, 1.09203)
# --------------------------------------------------
# Add data point (-0.18668, 2.09335)
#
# Posterior mean:
#     0.5852030184
#     1.6531220107
#     2.8278025042
#
# Posterior varience:
#     0.0263783312,    0.0001338544,   -0.0436755019
#     0.0001338544,    0.0250327579,   -0.0044598384
#    -0.0436755019,   -0.0044598384,    0.1147851289
#
# Predictive distribution ~ N(0.37515, 0.94825)
# --------------------------------------------------
# Add data point (0.75258, 3.54544)
#
# Posterior mean:
#     0.5853807404
#     1.6547995785
#     2.8296363737
#
# Posterior varience:
#     0.0263756277,    0.0001083350,   -0.0437033990
#     0.0001083350,    0.0247918729,   -0.0047231670
#    -0.0437033990,   -0.0047231670,    0.1144972656
#
# Predictive distribution ~ N(3.43338, 1.12244)
# --------------------------------------------------
# Add data point (-0.15760, -1.42546)
#
# Posterior mean:
#     0.5408195367
#     1.6617046450
#     2.9003669732
#
# Posterior varience:
#     0.0257569471,    0.0002042039,   -0.0427213868
#     0.0002042039,    0.0247770174,   -0.0048753366
#    -0.0427213868,   -0.0048753366,    0.1129385485
#
# Predictive distribution ~ N(0.35097, 1.03180)
# --------------------------------------------------
# Add data point (0.81149, 3.57714)
#
# Posterior mean:
#     0.5412910920
#     1.6580561099
#     2.8944580079
#
# Posterior varience:
#     0.0257522542,    0.0002405141,   -0.0426625808
#     0.0002405141,    0.0244960766,   -0.0053303327
#    -0.0426625808,   -0.0053303327,    0.1122016618
#
# Predictive distribution ~ N(3.79284, 1.03997)
# --------------------------------------------------
# Add data point (-0.91872, -0.57373)
#
# Posterior mean:
#     0.5606950770
#     1.7076181971
#     2.7890165752
#
# Posterior varience:
#     0.0256523334,   -0.0000147058,   -0.0421196104
#    -0.0000147058,    0.0238441884,   -0.0039434657
#    -0.0421196104,   -0.0039434657,    0.1092511555
#
# Predictive distribution ~ N(1.34595, 1.09528)
# --------------------------------------------------
# Add data point (0.85024, 4.54794)
#
# Posterior mean:
#     0.5583340850
#     1.7161653959
#     2.8054677303
#
# Posterior varience:
#     0.0256304664,    0.0000644568,   -0.0419672428
#     0.0000644568,    0.0235576062,   -0.0044950626
#    -0.0419672428,   -0.0044950626,    0.1081894736
#
# Predictive distribution ~ N(4.04556, 1.05629)
# --------------------------------------------------
# Add data point (-0.35255, -2.76240)
#
# Posterior mean:
#     0.5057431442
#     1.7388597959
#     2.8749356597
#
# Posterior varience:
#     0.0252805081,    0.0002154732,   -0.0415049792
#     0.0002154732,    0.0234924386,   -0.0046945417
#    -0.0415049792,   -0.0046945417,    0.1075788647
#
# Predictive distribution ~ N(0.25004, 1.18784)
# --------------------------------------------------
# Add data point (-0.80789, 1.77055)
#
# Posterior mean:
#     0.5039659877
#     1.7192989437
#     2.9040625227
#
# Posterior varience:
#     0.0252760649,    0.0001665677,   -0.0414321572
#     0.0001665677,    0.0229541449,   -0.0038930017
#    -0.0414321572,   -0.0038930017,    0.1063853409
#
# Predictive distribution ~ N(1.01040, 0.88358)
# --------------------------------------------------
# Add data point (-0.47940, -2.22527)
#
# Posterior mean:
#     0.4737875040
#     1.7418876911
#     2.9331667939
#
# Posterior varience:
#     0.0250921822,    0.0003042048,   -0.0412548198
#     0.0003042048,    0.0228511229,   -0.0040257396
#    -0.0412548198,   -0.0040257396,    0.1062143159
#
# Predictive distribution ~ N(0.31284, 1.33584)
# --------------------------------------------------
# Add data point (-0.94625, -0.29862)
#
# Posterior mean:
#     0.4986463015
#     1.7929437263
#     2.8150526834
#
# Posterior varience:
#     0.0249198516,   -0.0000497351,   -0.0404360077
#    -0.0000497351,    0.0221241862,   -0.0023440290
#    -0.0404360077,   -0.0023440290,    0.1023238112
#
# Predictive distribution ~ N(1.32265, 0.84985)
# --------------------------------------------------
# Add data point (-0.23932, -0.75228)
#
# Posterior mean:
#     0.4819486357
#     1.7969887200
#     2.8401662758
#
# Posterior varience:
#     0.0245357174,    0.0000433210,   -0.0398582630
#     0.0000433210,    0.0221016435,   -0.0024839872
#    -0.0398582630,   -0.0024839872,    0.1014548726
#
# Predictive distribution ~ N(0.21456, 1.33115)
# --------------------------------------------------
# Add data point (0.44572, 0.48309)
#
# Posterior mean:
#     0.4531478739
#     1.7807141696
#     2.8761918467
#
# Posterior varience:
#     0.0241844489,   -0.0001551716,   -0.0394188771
#    -0.0001551716,    0.0219894806,   -0.0022357018
#    -0.0394188771,   -0.0022357018,    0.1009052647
#
# Predictive distribution ~ N(1.81824, 0.78758)
# --------------------------------------------------
# Add data point (0.85092, 5.78526)
#
# Posterior mean:
#     0.4478183529
#     1.8008206336
#     2.9138717194
#
# Posterior varience:
#     0.0241706527,   -0.0001031232,   -0.0393213376
#    -0.0001031232,    0.0217931200,   -0.0026036850
#    -0.0393213376,   -0.0026036850,    0.1002156575
#
# Predictive distribution ~ N(4.09001, 1.46021)
# --------------------------------------------------
# Add data point (0.15733, -0.18194)
#
# Posterior mean:
#     0.4173879501
#     1.7965396490
#     2.9627711518
#
# Posterior varience:
#     0.0234546497,   -0.0002038514,   -0.0381707731
#    -0.0002038514,    0.0217789494,   -0.0024418222
#    -0.0381707731,   -0.0024418222,    0.0983667845
#
# Predictive distribution ~ N(0.77338, 0.74981)
# --------------------------------------------------
# Add data point (-0.63429, 0.71261)
#
# Posterior mean:
#     0.4188239071
#     1.7939213373
#     2.9632867525
#
# Posterior varience:
#     0.0234059842,   -0.0001151151,   -0.0381882471
#    -0.0001151151,    0.0216171485,   -0.0024099602
#    -0.0381882471,   -0.0024099602,    0.0983605102
#
# Predictive distribution ~ N(0.47317, 1.39044)
# --------------------------------------------------
# Add data point (0.89357, 2.58917)
#
# Posterior mean:
#     0.4356752553
#     1.7534226936
#     2.8737528507
#
# Posterior varience:
#     0.0233386352,    0.0000467439,   -0.0378304111
#     0.0000467439,    0.0212281546,   -0.0032699433
#    -0.0378304111,   -0.0032699433,    0.0964592703
#
# Predictive distribution ~ N(4.29708, 0.76540)
# --------------------------------------------------
# Add data point (0.21427, 0.11565)
#
# Posterior mean:
#     0.4229423730
#     1.7508038141
#     2.8938448065
#
# Posterior varience:
#     0.0230061537,   -0.0000216403,   -0.0373057693
#    -0.0000216403,    0.0212140894,   -0.0031620358
#    -0.0373057693,   -0.0031620358,    0.0956314075
#
# Predictive distribution ~ N(0.93094, 1.40449)
# --------------------------------------------------
# Add data point (-0.95184, 2.37936)
#
# Posterior mean:
#     0.4090893644
#     1.7211251372
#     2.9611605621
#
# Posterior varience:
#     0.0228570817,   -0.0003410122,   -0.0365813851
#    -0.0003410122,    0.0205298672,   -0.0016101157
#    -0.0365813851,   -0.0016101157,    0.0921114166
#
# Predictive distribution ~ N(1.45368, 0.77404)
# --------------------------------------------------
# Add data point (0.38067, 3.93373)
#
# Posterior mean:
#     0.4387504289
#     1.7334493907
#     2.9205715677
#
# Posterior varience:
#     0.0226452765,   -0.0004290179,   -0.0362915453
#    -0.0004290179,    0.0204933006,   -0.0014896864
#    -0.0362915453,   -0.0014896864,    0.0917147919
#
# Predictive distribution ~ N(1.52183, 1.43357)
# --------------------------------------------------
# Add data point (-0.98460, 4.94989)
#
# Posterior mean:
#     0.3902067318
#     1.6450913638
#     3.1372984129
#
# Posterior varience:
#     0.0224716225,   -0.0007450985,   -0.0355162546
#    -0.0007450985,    0.0199179786,   -0.0000785218
#    -0.0355162546,   -0.0000785218,    0.0882534509
#
# Predictive distribution ~ N(1.81186, 0.84061)
# --------------------------------------------------
# Add data point (-0.29373, 0.53859)
#
# Posterior mean:
#     0.3956614181
#     1.6432563955
#     3.1295500534
#
# Posterior varience:
#     0.0221750007,   -0.0006453142,   -0.0350949045
#    -0.0006453142,    0.0198844110,   -0.0002202649
#    -0.0350949045,   -0.0002202649,    0.0876549248
#
# Predictive distribution ~ N(0.18300, 1.29831)
# --------------------------------------------------
# Add data point (-0.52994, 1.76143)
#
# Posterior mean:
#     0.4173957276
#     1.6239531761
#     3.1117635206
#
# Posterior varience:
#     0.0219723221,   -0.0004653062,   -0.0349290401
#    -0.0004653062,    0.0197245377,   -0.0003675766
#    -0.0349290401,   -0.0003675766,    0.0875191876
#
# Predictive distribution ~ N(0.43070, 0.79059)
# --------------------------------------------------
# Add data point (0.79527, 3.90941)
#
# Posterior mean:
#     0.4173109486
#     1.6265540989
#     3.1152566521
#
# Posterior varience:
#     0.0219721439,   -0.0004598409,   -0.0349217000
#    -0.0004598409,    0.0195568695,   -0.0005927610
#    -0.0349217000,   -0.0005927610,    0.0872167570
#
# Predictive distribution ~ N(3.68110, 1.33944)
# --------------------------------------------------
# Add data point (0.91032, 5.78270)
#
# Posterior mean:
#     0.4068357339
#     1.6504560199
#     3.1674713931
#
# Posterior varience:
#     0.0219127758,   -0.0003243771,   -0.0346257736
#    -0.0003243771,    0.0192477736,   -0.0012679938
#    -0.0346257736,   -0.0012679938,    0.0857416829
#
# Predictive distribution ~ N(4.53411, 0.91716)
# --------------------------------------------------
# Add data point (0.11889, 1.27095)
#
# Posterior mean:
#     0.4184172134
#     1.6515099289
#     3.1492936190
#
# Posterior varience:
#     0.0215153166,   -0.0003605457,   -0.0340019395
#    -0.0003605457,    0.0192444823,   -0.0012112252
#    -0.0340019395,   -0.0012112252,    0.0847625406
#
# Predictive distribution ~ N(0.65927, 1.15020)
# --------------------------------------------------
# Add data point (0.13999, -2.55968)
#
# Posterior mean:
#     0.3536819390
#     1.6443208918
#     3.2504821371
#
# Posterior varience:
#     0.0211037012,   -0.0004062568,   -0.0333585383
#    -0.0004062568,    0.0192394060,   -0.0011397736
#    -0.0333585383,   -0.0011397736,    0.0837568321
#
# Predictive distribution ~ N(0.64757, 1.05053)
# --------------------------------------------------
# Add data point (-0.19316, -0.01594)
#
# Posterior mean:
#     0.3502552484
#     1.6450367385
#     3.2556405750
#
# Posterior varience:
#     0.0207094306,   -0.0003238924,   -0.0327650150
#    -0.0003238924,    0.0192221998,   -0.0012637625
#    -0.0327650150,   -0.0012637625,    0.0828633598
#
# Predictive distribution ~ N(0.15397, 1.00783)
# --------------------------------------------------
# Add data point (-0.61148, -1.26792)
#
# Posterior mean:
#     0.3357506012
#     1.6660663674
#     3.2573310509
#
# Posterior varience:
#     0.0206408045,   -0.0002243945,   -0.0327570168
#    -0.0002243945,    0.0190779424,   -0.0012753587
#    -0.0327570168,   -0.0012753587,    0.0828624276
#
# Predictive distribution ~ N(0.53493, 1.09166)
# --------------------------------------------------
# ...
#     0.0103780435,   -0.0001129118,   -0.0176574943
#    -0.0001129118,    0.0116949749,    0.0006741993
#    -0.0176574943,    0.0006741993,    0.0501688943
#
# Predictive distribution ~ N(0.58169, 1.01960)
# --------------------------------------------------
# Add data point (0.77555, 4.47886)
#
# Posterior mean:
#     0.8355708419
#     1.7140745648
#     2.8006604514
#
# Posterior varience:
#     0.0103779376,   -0.0001099083,   -0.0176533109
#    -0.0001099083,    0.0116097948,    0.0005555551
#    -0.0176533109,    0.0005555551,    0.0500036390
#
# Predictive distribution ~ N(3.84946, 1.02889)
# --------------------------------------------------
# Add data point (0.57994, 5.57363)
#
# Posterior mean:
#     0.8472820219
#     1.7322959362
#     2.7992867950
#
# Posterior varience:
#     0.0103596445,   -0.0001383704,   -0.0176511652
#    -0.0001383704,    0.0115655107,    0.0005588935
#    -0.0176511652,    0.0005588935,    0.0500033873
#
# Predictive distribution ~ N(2.79339, 1.04715)
# --------------------------------------------------
# Add data point (-0.48574, -1.38986)
#
# Posterior mean:
#     0.8345327424
#     1.7437465424
#     2.8117562068
#
# Posterior varience:
#     0.0103208158,   -0.0001034969,   -0.0176131888
#    -0.0001034969,    0.0115341895,    0.0005247855
#    -0.0176131888,    0.0005247855,    0.0499662446
#
# Predictive distribution ~ N(0.65094, 1.00990)
# --------------------------------------------------
# Add data point (0.09276, -1.24191)
#
# Posterior mean:
#     0.8124987062
#     1.7416407108
#     2.8489172366
#
# Posterior varience:
#     0.0102218682,   -0.0001129535,   -0.0174463109
#    -0.0001129535,    0.0115332857,    0.0005407343
#    -0.0174463109,    0.0005407343,    0.0496848003
#
# Predictive distribution ~ N(0.99858, 1.04307)
# --------------------------------------------------
# Add data point (0.72978, 4.38604)
#
# Posterior mean:
#     0.8131627003
#     1.7483699502
#     2.8562870399
#
# Posterior varience:
#     0.0102211513,   -0.0001202188,   -0.0174542679
#    -0.0001202188,    0.0114596551,    0.0004600947
#    -0.0174542679,    0.0004600947,    0.0495964845
#
# Predictive distribution ~ N(3.61031, 1.00242)
# --------------------------------------------------
# Add data point (0.94722, 7.53641)
#
# Posterior mean:
#     0.8012436434
#     1.7722961841
#     2.9152706002
#
# Posterior varience:
#     0.0101947225,   -0.0000671657,   -0.0173234800
#    -0.0000671657,    0.0113531567,    0.0001975521
#    -0.0173234800,    0.0001975521,    0.0489492577
#
# Predictive distribution ~ N(5.09566, 1.16607)
# --------------------------------------------------
# Add data point (-0.76066, 0.93217)
#
# Posterior mean:
#     0.8011918960
#     1.7742954727
#     2.9127452519
#
# Posterior varience:
#     0.0101946671,   -0.0000650264,   -0.0173261823
#    -0.0000650264,    0.0112705024,    0.0003019546
#    -0.0173261823,    0.0003019546,    0.0488173845
#
# Predictive distribution ~ N(1.13689, 0.89229)
# --------------------------------------------------
# Add data point (-0.12289, 4.21266)
#
# Posterior mean:
#     0.8318026591
#     1.7698443464
#     2.8615496128
#
# Posterior varience:
#     0.0101097978,   -0.0000526855,   -0.0171842408
#    -0.0000526855,    0.0112687079,    0.0002813148
#    -0.0171842408,    0.0002813148,    0.0485799914
#
# Predictive distribution ~ N(0.65752, 1.16433)
# --------------------------------------------------
# Add data point (0.43292, 3.85853)
#
# Posterior mean:
#     0.8451676092
#     1.7793402769
#     2.8460607672
#
# Posterior varience:
#     0.0100565747,   -0.0000905011,   -0.0171225597
#    -0.0000905011,    0.0112418396,    0.0003251399
#    -0.0171225597,    0.0003251399,    0.0485085082
#
# Predictive distribution ~ N(2.14891, 0.88574)
# --------------------------------------------------
# Add data point (0.69115, 6.74935)
#
# Posterior mean:
#     0.8500238376
#     1.8003038847
#     2.8628481667
#
# Posterior varience:
#     0.0100539159,   -0.0001019785,   -0.0171317507
#    -0.0001019785,    0.0111922933,    0.0002854638
#    -0.0171317507,    0.0002854638,    0.0484767361
#
# Predictive distribution ~ N(3.46183, 1.23876)
# --------------------------------------------------
# Add data point (-0.92266, 1.02811)
#
# Posterior mean:
#     0.8531856454
#     1.8075632214
#     2.8458335399
#
# Posterior varience:
#     0.0100304598,   -0.0001558326,   -0.0170055261
#    -0.0001558326,    0.0110686473,    0.0005752685
#    -0.0170055261,    0.0005752685,    0.0477974840
#
# Predictive distribution ~ N(1.60809, 0.83831)
# --------------------------------------------------
# Add data point (0.48374, 4.69275)
#
# Posterior mean:
#     0.8640727840
#     1.8172795163
#     2.8357356493
#
# Posterior varience:
#     0.0100021640,   -0.0001810853,   -0.0169792816
#    -0.0001810853,    0.0110461104,    0.0005986905
#    -0.0169792816,    0.0005986905,    0.0477731421
#
# Predictive distribution ~ N(2.40673, 1.26197)
# --------------------------------------------------
# Add data point (0.07734, 1.90581)
#
# Posterior mean:
#     0.8749509269
#     1.8180241994
#     2.8174188445
#
# Posterior varience:
#     0.0098805353,   -0.0001894116,   -0.0167744811
#    -0.0001894116,    0.0110455404,    0.0006127105
#    -0.0167744811,    0.0006127105,    0.0474282955
#
# Predictive distribution ~ N(1.03241, 0.80351)
# --------------------------------------------------
# Add data point (-0.36648, -0.54506)
#
# Posterior mean:
#     0.8681780280
#     1.8216804931
#     2.8267716860
#
# Posterior varience:
#     0.0098344893,   -0.0001645540,   -0.0167108951
#    -0.0001645540,    0.0110321212,    0.0005783842
#    -0.0167108951,    0.0005783842,    0.0473404882
#
# Predictive distribution ~ N(0.58023, 1.28656)
# --------------------------------------------------
# Add data point (0.57251, 3.83018)
#
# Posterior mean:
#     0.8734605593
#     1.8295379949
#     2.8257021291
#
# Posterior varience:
#     0.0098118008,   -0.0001983019,   -0.0167063013
#    -0.0001983019,    0.0109819228,    0.0005852171
#    -0.0167063013,    0.0005852171,    0.0473395581
#
# Predictive distribution ~ N(2.84706, 0.80092)
# --------------------------------------------------
# Add data point (0.82811, 3.66657)
#
# Posterior mean:
#     0.8743896899
#     1.8247628491
#     2.8173600176
#
# Posterior varience:
#     0.0098092530,   -0.0001852079,   -0.0166834262
#    -0.0001852079,    0.0109146276,    0.0004676532
#    -0.0166834262,    0.0004676532,    0.0471341757
#
# Predictive distribution ~ N(4.31754, 1.28425)
# --------------------------------------------------
# Add data point (-0.48652, 2.44237)
#
# Posterior mean:
#     0.8877933163
#     1.8126332513
#     2.8043984580
#
# Posterior varience:
#     0.0097646689,   -0.0001448615,   -0.0166403125
#    -0.0001448615,    0.0108781162,    0.0004286376
#    -0.0166403125,    0.0004286376,    0.0470924839
#
# Predictive distribution ~ N(0.66972, 0.79408)
# --------------------------------------------------
# Add data point (-0.76038, 1.36705)
#
# Posterior mean:
#     0.8878401253
#     1.8111258482
#     2.8062921524
#
# Posterior varience:
#     0.0097646187,   -0.0001432420,   -0.0166423471
#    -0.0001432420,    0.0108259626,    0.0004941561
#    -0.0166423471,    0.0004941561,    0.0470101754
#
# Predictive distribution ~ N(1.13324, 1.27929)
# --------------------------------------------------
# Add data point (-0.29723, -1.83907)
#
# Posterior mean:
#     0.8639235642
#     1.8206426048
#     2.8425419682
#
# Posterior varience:
#     0.0096827843,   -0.0001106789,   -0.0165183126
#    -0.0001106789,    0.0108130053,    0.0004448010
#    -0.0165183126,    0.0004448010,    0.0468221790
#
# Predictive distribution ~ N(0.57390, 0.84925)
# --------------------------------------------------
# Add data point (0.96664, 7.07724)
#
# Posterior mean:
#     0.8559322490
#     1.8353155911
#     2.8802728576
#
# Posterior varience:
#     0.0096567364,   -0.0000628519,   -0.0163953275
#    -0.0000628519,    0.0107251892,    0.0002189861
#    -0.0163953275,    0.0002189861,    0.0462415067
#
# Predictive distribution ~ N(5.32130, 1.31702)
# --------------------------------------------------
# Add data point (-0.88498, 2.95631)
#
# Posterior mean:
#     0.8501771519
#     1.8180539302
#     2.9163799948
#
# Posterior varience:
#     0.0096444789,   -0.0000996165,   -0.0163184250
#    -0.0000996165,    0.0106149185,    0.0004496453
#    -0.0163184250,    0.0004496453,    0.0457590246
#
# Predictive distribution ~ N(1.52532, 0.79786)
# --------------------------------------------------
# Add data point (0.96024, 4.85394)
#
# Posterior mean:
#     0.8519430916
#     1.8146787413
#     2.9079302990
#
# Posterior varience:
#     0.0096219581,   -0.0000565731,   -0.0162106668
#    -0.0000565731,    0.0105326508,    0.0002436903
#    -0.0162106668,    0.0002436903,    0.0452434219
#
# Predictive distribution ~ N(5.27578, 1.34153)
# --------------------------------------------------
# Add data point (-0.48525, -0.13393)
#
# Posterior mean:
#     0.8460510002
#     1.8198412478
#     2.9136640442
#
# Posterior varience:
#     0.0095784598,   -0.0000184609,   -0.0161683375
#    -0.0000184609,    0.0104992579,    0.0002066024
#    -0.0161683375,    0.0002066024,    0.0452022301
#
# Predictive distribution ~ N(0.64905, 0.78195)
# --------------------------------------------------
# Add data point (0.64250, 2.35377)
#
# Posterior mean:
#     0.8441197186
#     1.8152921106
#     2.9119117458
#
# Posterior varience:
#     0.0095719972,   -0.0000336836,   -0.0161742012
#    -0.0000336836,    0.0104634008,    0.0001927905
#    -0.0161742012,    0.0001927905,    0.0451969098
#
# Predictive distribution ~ N(3.21250, 1.29429)
# --------------------------------------------------
# Add data point (0.90494, 4.31971)
#
# Posterior mean:
#     0.8466169225
#     1.8088241478
#     2.8977441997
#
# Posterior varience:
#     0.0095552336,    0.0000097354,   -0.0160790954
#     0.0000097354,    0.0103509420,   -0.0000535414
#    -0.0160790954,   -0.0000535414,    0.0446573398
#
# Predictive distribution ~ N(4.85648, 0.81769)
# --------------------------------------------------
# Add data point (0.77910, 2.44892)
#
# Posterior mean:
#     0.8468609662
#     1.7988700604
#     2.8841454460
#
# Posterior varience:
#     0.0095552029,    0.0000109887,   -0.0160773832
#     0.0000109887,    0.0102998223,   -0.0001233784
#    -0.0160773832,   -0.0001233784,    0.0445619321
#
# Predictive distribution ~ N(3.99903, 1.26491)
# --------------------------------------------------
# Add data point (0.85732, 3.11724)
#
# Posterior mean:
#     0.8506921265
#     1.7839841628
#     2.8559583819
#
# Posterior varience:
#     0.0095490029,    0.0000350787,   -0.0160317678
#     0.0000350787,    0.0102062211,   -0.0003006161
#    -0.0160317678,   -0.0003006161,    0.0442263253
#
# Predictive distribution ~ N(4.47923, 0.81769)
# --------------------------------------------------
# Add data point (0.96439, 4.63338)
#
# Posterior mean:
#     0.8531294145
#     1.7795929483
#     2.8446074560
#
# Posterior varience:
#     0.0095271408,    0.0000744671,   -0.0159299521
#     0.0000744671,    0.0101352558,   -0.0004840555
#    -0.0159299521,   -0.0004840555,    0.0437521495
#
# Predictive distribution ~ N(5.21495, 1.29762)
# --------------------------------------------------
# Add data point (0.89304, 5.73403)
#
# Posterior mean:
#     0.8494124500
#     1.7900352898
#     2.8667489882
#
# Posterior varience:
#     0.0095158378,    0.0001062215,   -0.0158626213
#     0.0001062215,    0.0100460459,   -0.0006732128
#    -0.0158626213,   -0.0006732128,    0.0433510679
#
# Predictive distribution ~ N(4.73429, 0.85575)
# --------------------------------------------------
# Add data point (-0.00832, -0.66557)
#
# Posterior mean:
#     0.8377720078
#     1.7900076785
#     2.8861467774
#
# Posterior varience:
#     0.0094420214,    0.0001060464,   -0.0157396127
#     0.0001060464,    0.0100460455,   -0.0006729210
#    -0.0157396127,   -0.0006729210,    0.0431460846
#
# Predictive distribution ~ N(0.82307, 1.22612)
# --------------------------------------------------
# Add data point (0.49392, 2.27248)
#
# Posterior mean:
#     0.8367211210
#     1.7890963351
#     2.8871775301
#
# Posterior varience:
#     0.0094033066,    0.0000724723,   -0.0157016395
#     0.0000724723,    0.0100169296,   -0.0006399902
#    -0.0157016395,   -0.0006399902,    0.0431088391
#
# Predictive distribution ~ N(2.42472, 0.82586)
# --------------------------------------------------
# Add data point (0.03713, 0.64641)
#
# Posterior mean:
#     0.8347352498
#     1.7890024761
#     2.8904926874
#
# Posterior varience:
#     0.0093318270,    0.0000690940,   -0.0155823137
#     0.0000690940,    0.0100167699,   -0.0006343504
#    -0.0155823137,   -0.0006343504,    0.0429096398
#
# Predictive distribution ~ N(0.90515, 1.23197)
# --------------------------------------------------
# Add data point (0.50984, -0.47736)
#
# Posterior mean:
#     0.8159789924
#     1.7713239102
#     2.9072567581
#
# Posterior varience:
#     0.0092983138,    0.0000375063,   -0.0155523600
#     0.0000375063,    0.0099869972,   -0.0006061178
#    -0.0155523600,   -0.0006061178,    0.0428828676
#
# Predictive distribution ~ N(2.47477, 0.84339)
# --------------------------------------------------
# Add data point (0.57886, 5.10826)
#
# Posterior mean:
#     0.8236142365
#     1.7817587845
#     2.9044056421
#
# Posterior varience:
#     0.0092846309,    0.0000188063,   -0.0155472506
#     0.0000188063,    0.0099614405,   -0.0005991350
#    -0.0155472506,   -0.0005991350,    0.0428809597
#
# Predictive distribution ~ N(2.82818, 1.23381)
# --------------------------------------------------
# Add data point (-0.62606, 0.90023)
#
# Posterior mean:
#     0.8238215010
#     1.7813381125
#     2.9045122371
#
# Posterior varience:
#     0.0092723658,    0.0000437001,   -0.0155535585
#     0.0000437001,    0.0099109152,   -0.0005863323
#    -0.0155535585,   -0.0005863323,    0.0428777156
#
# Predictive distribution ~ N(0.84702, 0.82395)
# --------------------------------------------------
# Add data point (-0.02810, 2.54741)
#
# Posterior mean:
#     0.8371418923
#     1.7809995928
#     2.8822083002
#
# Posterior varience:
#     0.0092027405,    0.0000454695,   -0.0154369764
#     0.0000454695,    0.0099108702,   -0.0005892951
#    -0.0154369764,   -0.0005892951,    0.0426825082
#
# Predictive distribution ~ N(0.78936, 1.23118)
# --------------------------------------------------
# Add data point (-0.02747, 3.12143)
#
# Posterior mean:
#     0.8629708791
#     1.7803610364
#     2.8389571189
#
# Posterior varience:
#     0.0091009126,    0.0000479870,   -0.0152664635
#     0.0000479870,    0.0099108080,   -0.0005935106
#    -0.0152664635,   -0.0005935106,    0.0423969808
#
# Predictive distribution ~ N(0.81621, 0.82927)
# --------------------------------------------------
# Add data point (-0.16247, 1.30174)
#
# Posterior mean:
#     0.8676038334
#     1.7795198229
#     2.8314661869
#
# Posterior varience:
#     0.0090392652,    0.0000591804,   -0.0151667870
#     0.0000591804,    0.0099087756,   -0.0006116090
#    -0.0151667870,   -0.0006116090,    0.0422358157
#
# Predictive distribution ~ N(0.65323, 1.22495)
# --------------------------------------------------
# Add data point (0.24445, 1.23064)
#
# Posterior mean:
#     0.8652336442
#     1.7788085764
#     2.8351876642
#
# Posterior varience:
#     0.0089591973,    0.0000351536,   -0.0150410709
#     0.0000351536,    0.0099015656,   -0.0005738841
#    -0.0150410709,   -0.0005738841,    0.0420384266
#
# Predictive distribution ~ N(1.46949, 0.82897)
# --------------------------------------------------
# Add data point (0.48554, 0.49266)
#
# Posterior mean:
#     0.8568094708
#     1.7715057444
#     2.8435789376
#
# Posterior varience:
#     0.0089351793,    0.0000143327,   -0.0150171467
#     0.0000143327,    0.0098835162,   -0.0005531445
#    -0.0150171467,   -0.0005531445,    0.0420145959
#
# Predictive distribution ~ N(2.38733, 1.22773)
# --------------------------------------------------
# Add data point (0.74832, 3.76164)
#
# Posterior mean:
#     0.8568010270
#     1.7713940002
#     2.8434515224
#
# Posterior varience:
#     0.0089348357,    0.0000097854,   -0.0150223317
#     0.0000097854,    0.0098233378,   -0.0006217623
#    -0.0150223317,   -0.0006217623,    0.0419363552
#
# Predictive distribution ~ N(3.77466, 0.83769)
# --------------------------------------------------
# Add data point (-0.56445, 0.76182)
#
# Posterior mean:
#     0.8567974692
#     1.7713989232
#     2.8434526477
#
# Posterior varience:
#     0.0089207229,    0.0000293136,   -0.0150178678
#     0.0000293136,    0.0097963164,   -0.0006279391
#    -0.0150178678,   -0.0006279391,    0.0419349432
#
# Predictive distribution ~ N(0.76286, 1.21632)
# --------------------------------------------------

# %%
len(x)
# Out:
# 280

# %%
plt.rcParams["figure.figsize"] = (15,10)

plt.subplot(221)
plt.title("Ground truth")
plt.xlim(-2,2)
plt.ylim(-15,20)
data_x = np.linspace(-2,2,30)
plt.plot(data_x,np.poly1d(np.flip(W))(data_x),'k-')
plt.plot(data_x,np.poly1d(np.flip(W))(data_x)+error_gen,'r-')
plt.plot(data_x,np.poly1d(np.flip(W))(data_x)-error_gen,'r-')

plt.subplot(222)
plt.title("Predict result")
plt.xlim(-2,2)
plt.ylim(-15,20)
plt.plot(x,y,'bo')
data_x = np.linspace(-2,2,50)
predict_y = np.poly1d(np.flip(np.reshape(m,n)))(data_x)
plt.plot(data_x,predict_y,'k-')
for i in range(50):
    A = np.array([[data_x[i]**j for j in range(n)]])
    predict_y[i] += (1/a+np.dot(A,np.dot(S_inv,np.transpose(A)))[0][0])
plt.plot(data_x,predict_y,'r-')
for i in range(50):
    A = np.array([[data_x[i]**j for j in range(n)]])
    predict_y[i] -= 2*(1/a+np.dot(A,np.dot(S_inv,np.transpose(A)))[0][0])
plt.plot(data_x,predict_y,'r-')

plt.subplot(223)
plt.title("After 10 incomes")
plt.xlim(-2,2)
plt.ylim(-15,20)
plt.plot(x[:10],y[:10],'bo')
data_x = np.linspace(-2,2,50)
predict_y = np.poly1d(np.flip(np.reshape(m_10,n)))(data_x)
plt.plot(data_x,predict_y,'k-')
for i in range(50):
    A = np.array([[data_x[i]**j for j in range(n)]])
    predict_y[i] += (1/a_10+np.dot(A,np.dot(S_10,np.transpose(A)))[0][0])
plt.plot(data_x,predict_y,'r-')
for i in range(50):
    A = np.array([[data_x[i]**j for j in range(n)]])
    predict_y[i] -= 2*(1/a_10+np.dot(A,np.dot(S_10,np.transpose(A)))[0][0])
plt.plot(data_x,predict_y,'r-')

plt.subplot(224)
plt.title("After 50 incomes")
plt.xlim(-2,2)
plt.ylim(-15,20)
plt.plot(x[:50],y[:50],'bo')
data_x = np.linspace(-2,2,50)
predict_y = np.poly1d(np.flip(np.reshape(m_50,n)))(data_x)
plt.plot(data_x,predict_y,'k-')
for i in range(50):
    A = np.array([[data_x[i]**j for j in range(n)]])
    predict_y[i] += (1/a_50+np.dot(A,np.dot(S_50,np.transpose(A)))[0][0])
plt.plot(data_x,predict_y,'r-')
for i in range(50):
    A = np.array([[data_x[i]**j for j in range(n)]])
    predict_y[i] -= 2*(1/a_50+np.dot(A,np.dot(S_50,np.transpose(A)))[0][0])
plt.plot(data_x,predict_y,'r-')
plt.show()
